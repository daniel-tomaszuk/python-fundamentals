# %%
import csv
from collections import namedtuple

FILE_SAMPLE_CHARS_COUNT = 500


def get_csv_dialect(fname: str):
    with open(fname) as f:
        file_sample = f.read(FILE_SAMPLE_CHARS_COUNT)
        dialect = csv.Sniffer().sniff(file_sample)
        return dialect


def get_data_row_factory(fname: str):
    with open(fname) as f:
        dialect = get_csv_dialect(fname)
        headers = next(f).strip("\n").split(dialect.delimiter)
        return namedtuple("DataRow", ",".join(str(h).casefold().replace(" ", "_") for h in headers))


class CsvFileReader:
    """
    CSV files reader. 
    Acts as a context manager that handles the file iterator.
    """
    _FILE_SAMPLE_CHARS_COUNT = FILE_SAMPLE_CHARS_COUNT
    
    def __init__(self, fname: str):
        self._fname = fname
        self._reader = None
        self._file = None
        self._dialect = self._get_csv_dialect()
        self.DataRow = self._get_data_row_factory()

    def __enter__(self):
        self._file = open(self._fname)
        self._reader = csv.reader(self._file, self._dialect)
        next(self._reader)  # ignore the headers
        return self

    def __exit__(self, exc_type, exc_value, exc_tb):
        self._file.close()
        return False

    def __iter__(self):
        return self

    def __next__(self):
        if self._file.closed:
            raise StopIteration

        return self.DataRow(*next(self._reader))

    def _get_data_row_factory(self):
        return get_data_row_factory(self._fname)

    def _get_csv_dialect(self):
        return get_csv_dialect(self._fname)

# %%
with CsvFileReader("personal_info.csv") as file:
    print(next(file))
    print(next(file))
    print(next(file))
    print(next(file))
    for row in file:
        print(row)
# Out:
# DataRow(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# DataRow(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# DataRow(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# DataRow(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# DataRow(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# DataRow(ssn='105-27-5541', first_name='Federico', last_name='Aggett', gender='Male', language='Chinese')
# DataRow(ssn='105-85-7486', first_name='Angelina', last_name='McAvey', gender='Female', language='Punjabi')
# DataRow(ssn='105-91-5022', first_name='Moselle', last_name='Apfel', gender='Female', language='Latvian')
# DataRow(ssn='105-91-7777', first_name='Audi', last_name='Roach', gender='Female', language='Estonian')
# DataRow(ssn='106-35-1938', first_name='Mackenzie', last_name='Nussey', gender='Male', language='Swedish')
# DataRow(ssn='106-36-3293', first_name='Martino', last_name='Tregoning', gender='Male', language='Tok Pisin')
# DataRow(ssn='110-84-3641', first_name='Amberly', last_name='Huws', gender='Female', language='Papiamento')
# DataRow(ssn='111-35-1034', first_name='Giacopo', last_name='Timperley', gender='Male', language='Gagauz')
# DataRow(ssn='114-06-6912', first_name='Jule', last_name='Velte', gender='Male', language='Dutch')
# DataRow(ssn='114-66-0984', first_name='Casandra', last_name='Juares', gender='Female', language='Lithuanian')
# DataRow(ssn='114-74-8701', first_name='Levey', last_name='Baradel', gender='Male', language='Icelandic')
# DataRow(ssn='116-10-7235', first_name='Chiquita', last_name='Danbi', gender='Female', language='Dari')
# DataRow(ssn='116-77-4915', first_name='Herold', last_name='Fearon', gender='Male', language='Italian')
# DataRow(ssn='117-39-6617', first_name='Auroora', last_name='Yong', gender='Female', language='Swahili')
# DataRow(ssn='117-77-9748', first_name='Lucien', last_name='Smalman', gender='Male', language='Hebrew')
# DataRow(ssn='117-78-6202', first_name='Dareen', last_name='Jiggins', gender='Female', language='Polish')
# DataRow(ssn='118-21-0357', first_name='Laina', last_name='Bayly', gender='Female', language='Bulgarian')
# DataRow(ssn='118-95-7100', first_name='Alexi', last_name='Leglise', gender='Female', language='Lithuanian')
# DataRow(ssn='119-07-8817', first_name='Blondie', last_name='Powderham', gender='Female', language='Croatian')
# DataRow(ssn='120-33-5535', first_name='Eugen', last_name='Shark', gender='Male', language='Dhivehi')
# DataRow(ssn='120-98-4054', first_name='Lorry', last_name='Hitter', gender='Male', language='Kazakh')
# DataRow(ssn='121-98-3948', first_name='Sal', last_name='Le Lievre', gender='Male', language='Croatian')
# DataRow(ssn='123-05-3229', first_name='Spenser', last_name='Shucksmith', gender='Male', language='Bosnian')
# DataRow(ssn='123-62-2832', first_name='Kare', last_name='Barhams', gender='Female', language='Tajik')
# DataRow(ssn='123-88-3381', first_name='Christiane', last_name='Hynes', gender='Female', language='Danish')
# DataRow(ssn='125-07-9434', first_name='Florella', last_name='Mathevon', gender='Female', language='Armenian')
# DataRow(ssn='127-49-2473', first_name='Quinta', last_name='Rippingall', gender='Female', language='Haitian Creole')
# DataRow(ssn='127-52-8001', first_name='Wilona', last_name='Noirel', gender='Female', language='Aymara')
# DataRow(ssn='127-68-4232', first_name='Tresa', last_name='Verheyden', gender='Female', language='Icelandic')
# DataRow(ssn='127-93-3548', first_name='Mellicent', last_name='Ingham', gender='Female', language='Lao')
# DataRow(ssn='128-42-4599', first_name='Neddy', last_name="O'Griffin", gender='Male', language='Croatian')
# DataRow(ssn='128-53-0369', first_name='Chucho', last_name='Rikel', gender='Male', language='Croatian')
# DataRow(ssn='128-53-7952', first_name='Tobie', last_name='Newhouse', gender='Male', language='Luxembourgish')
# DataRow(ssn='128-56-6040', first_name='Jinny', last_name='Stebbings', gender='Female', language='Armenian')
# DataRow(ssn='128-60-4388', first_name='Norton', last_name='Shailer', gender='Male', language='Czech')
# DataRow(ssn='129-67-0291', first_name='Danella', last_name='Linacre', gender='Female', language='Dzongkha')
# DataRow(ssn='131-81-4310', first_name='Jemie', last_name='Manilo', gender='Female', language='Finnish')
# DataRow(ssn='132-26-3507', first_name='Shalom', last_name='Arendsen', gender='Male', language='Hindi')
# DataRow(ssn='134-05-0120', first_name='Simone', last_name='Cruickshanks', gender='Female', language='Filipino')
# DataRow(ssn='135-86-9625', first_name='Tilly', last_name='Meir', gender='Female', language='Gagauz')
# DataRow(ssn='137-13-1889', first_name='Tedman', last_name="O'Donnelly", gender='Male', language='Bislama')
# DataRow(ssn='138-65-4579', first_name='Davidson', last_name='Gregoraci', gender='Male', language='Luxembourgish')
# DataRow(ssn='138-67-1198', first_name='Pam', last_name='Tofful', gender='Female', language='Bislama')
# DataRow(ssn='138-88-5288', first_name='Joletta', last_name='Babcock', gender='Female', language='Burmese')
# DataRow(ssn='139-04-8189', first_name='Stirling', last_name='Creak', gender='Male', language='Italian')
# DataRow(ssn='139-94-5865', first_name='Donalt', last_name='Plewes', gender='Male', language='Haitian Creole')
# DataRow(ssn='139-99-6417', first_name='Susanetta', last_name='Nazaret', gender='Female', language='Punjabi')
# DataRow(ssn='140-33-9727', first_name='Price', last_name='Butterwick', gender='Male', language='Belarusian')
# DataRow(ssn='140-58-8263', first_name='Tim', last_name='Bergin', gender='Female', language='Maori')
# DataRow(ssn='141-15-0543', first_name='Candy', last_name='Murtagh', gender='Female', language='Montenegrin')
# DataRow(ssn='141-88-9721', first_name='Cyrille', last_name='Capponer', gender='Male', language='Tswana')
# DataRow(ssn='142-77-4616', first_name='Barron', last_name='Victoria', gender='Male', language='Assamese')
# DataRow(ssn='142-87-3416', first_name='Margaux', last_name='Wintringham', gender='Female', language='Tajik')
# DataRow(ssn='143-17-4714', first_name='Hallie', last_name='Jeggo', gender='Female', language='Greek')
# DataRow(ssn='145-10-8454', first_name='Donny', last_name='Laba', gender='Male', language='Japanese')
# DataRow(ssn='145-35-5124', first_name='Leon', last_name='Boyson', gender='Male', language='Dhivehi')
# DataRow(ssn='145-78-3985', first_name='Baron', last_name='Cocci', gender='Male', language='Mongolian')
# DataRow(ssn='146-81-3446', first_name='Korry', last_name='Billham', gender='Female', language='Hebrew')
# DataRow(ssn='147-33-1463', first_name='Bendicty', last_name='Gentry', gender='Male', language='Papiamento')
# DataRow(ssn='147-47-8577', first_name='Janessa', last_name='Growy', gender='Female', language='Gujarati')
# DataRow(ssn='147-63-3462', first_name='Aime', last_name='Di Antonio', gender='Female', language='Tok Pisin')
# DataRow(ssn='148-60-7519', first_name='Jordan', last_name='Readwood', gender='Female', language='Khmer')
# DataRow(ssn='149-18-7272', first_name='Andrey', last_name='Bettley', gender='Male', language='Papiamento')
# DataRow(ssn='149-45-6482', first_name='Wheeler', last_name='Harbottle', gender='Male', language='Georgian')
# DataRow(ssn='150-64-6357', first_name='Helenka', last_name='Summerell', gender='Female', language='Bosnian')
# DataRow(ssn='150-89-3343', first_name='Bram', last_name='Beetlestone', gender='Male', language='Dzongkha')
# DataRow(ssn='151-54-3946', first_name='Piggy', last_name='Fishly', gender='Male', language='Nepali')
# DataRow(ssn='151-70-0641', first_name='Urbain', last_name='Balint', gender='Male', language='Malagasy')
# DataRow(ssn='151-78-1397', first_name='Portia', last_name='Belshaw', gender='Female', language='Sotho')
# DataRow(ssn='152-71-3526', first_name='Mel', last_name='Atkirk', gender='Female', language='Swedish')
# DataRow(ssn='153-67-1309', first_name='Annelise', last_name='Yushin', gender='Female', language='French')
# DataRow(ssn='154-17-7912', first_name='Ainslee', last_name='Branche', gender='Female', language='Hindi')
# DataRow(ssn='156-18-7547', first_name='Trey', last_name='Payne', gender='Male', language='West Frisian')
# DataRow(ssn='156-91-6848', first_name='Carol', last_name='Cromar', gender='Female', language='Amharic')
# DataRow(ssn='157-17-9982', first_name='Ardyce', last_name='Kuhnel', gender='Female', language='Danish')
# DataRow(ssn='157-38-7090', first_name='Johannes', last_name='Bugge', gender='Male', language='Afrikaans')
# DataRow(ssn='157-51-5269', first_name='Melisse', last_name='Petkov', gender='Female', language='Punjabi')
# DataRow(ssn='161-36-9710', first_name='Melina', last_name='MacDavitt', gender='Female', language='Polish')
# DataRow(ssn='161-53-4778', first_name='Kiri', last_name='Ciccone', gender='Female', language='Kyrgyz')
# DataRow(ssn='163-68-8070', first_name='Vassily', last_name='MacCarlich', gender='Male', language='Filipino')
# DataRow(ssn='163-98-1022', first_name='Babbette', last_name='Crystal', gender='Female', language='Lithuanian')
# DataRow(ssn='164-11-9849', first_name='Clemence', last_name='Aujean', gender='Female', language='Albanian')
# DataRow(ssn='166-10-4488', first_name='Lester', last_name='Keyson', gender='Male', language='Bislama')
# DataRow(ssn='167-39-2377', first_name='Reyna', last_name='Ullyatt', gender='Female', language='Portuguese')
# DataRow(ssn='168-02-5324', first_name='Dane', last_name='Cornick', gender='Male', language='Tajik')
# DataRow(ssn='168-19-8754', first_name='Teddie', last_name='Ingliss', gender='Male', language='Norwegian')
# DataRow(ssn='168-81-0838', first_name='Toby', last_name='Pond-Jones', gender='Female', language='Aymara')
# DataRow(ssn='168-89-6661', first_name='Vergil', last_name='Cecere', gender='Male', language='Tetum')
# DataRow(ssn='170-65-3388', first_name='Salvidor', last_name='Larcher', gender='Male', language='Burmese')
# DataRow(ssn='171-27-7781', first_name='Phillida', last_name='Cleeve', gender='Female', language='Lao')
# DataRow(ssn='172-23-7739', first_name='Everett', last_name='Turneaux', gender='Male', language='Kyrgyz')
# DataRow(ssn='172-77-4263', first_name='Alex', last_name='Udie', gender='Male', language='French')
# DataRow(ssn='172-89-7546', first_name='Trude', last_name='Gillson', gender='Female', language='Norwegian')
# DataRow(ssn='173-99-7372', first_name='Hedwiga', last_name='Gee', gender='Female', language='Danish')
# DataRow(ssn='174-13-2047', first_name='Rey', last_name='Dallywater', gender='Female', language='Zulu')
# DataRow(ssn='174-35-3812', first_name='Sayer', last_name='Astling', gender='Male', language='Kyrgyz')
# DataRow(ssn='174-51-9992', first_name='Drucie', last_name='Travers', gender='Female', language='Swati')
# DataRow(ssn='174-87-2537', first_name='Benton', last_name='Nolte', gender='Male', language='Persian')
# DataRow(ssn='176-82-1359', first_name='Corny', last_name='Rothera', gender='Female', language='Thai')
# DataRow(ssn='176-99-5851', first_name='Olivero', last_name='Janse', gender='Male', language='Moldovan')
# DataRow(ssn='179-88-2790', first_name='Errick', last_name='Charsley', gender='Male', language='Japanese')
# DataRow(ssn='181-07-4434', first_name='Ferdinande', last_name='Probet', gender='Female', language='Catalan')
# DataRow(ssn='181-28-8337', first_name='Fan', last_name='Hillyatt', gender='Female', language='Moldovan')
# DataRow(ssn='181-88-6077', first_name='Ebba', last_name='Wozencroft', gender='Female', language='German')
# DataRow(ssn='182-15-5082', first_name='Lavinie', last_name='Niess', gender='Female', language='Swahili')
# DataRow(ssn='182-81-4541', first_name='Sunny', last_name='Ferrarini', gender='Male', language='Swedish')
# DataRow(ssn='183-10-5024', first_name='Curran', last_name='Squires', gender='Male', language='Romanian')
# DataRow(ssn='184-60-6243', first_name='Fern', last_name='Demogeot', gender='Female', language='Tok Pisin')
# DataRow(ssn='184-84-1003', first_name='Bary', last_name='Buzin', gender='Male', language='Aymara')
# DataRow(ssn='184-92-3560', first_name='Kore', last_name='Eastes', gender='Female', language='Fijian')
# DataRow(ssn='184-94-5241', first_name='Manfred', last_name='McCrillis', gender='Male', language='Swati')
# DataRow(ssn='185-50-0434', first_name='Alexa', last_name='Emblin', gender='Female', language='Quechua')
# DataRow(ssn='185-84-9868', first_name='Shandy', last_name='Ilyin', gender='Female', language='Northern Sotho')
# DataRow(ssn='186-65-7773', first_name='Hazlett', last_name='Arney', gender='Male', language='Marathi')
# DataRow(ssn='188-20-9317', first_name='Clifford', last_name='Sedgemore', gender='Male', language='Thai')
# DataRow(ssn='188-40-4336', first_name='Belita', last_name='Camolli', gender='Female', language='Telugu')
# DataRow(ssn='189-26-5696', first_name='Arnold', last_name='Pepis', gender='Male', language='Tok Pisin')
# DataRow(ssn='189-49-1458', first_name='Vernen', last_name='Ivanyushkin', gender='Male', language='Quechua')
# DataRow(ssn='190-05-6987', first_name='Gorden', last_name='Clemonts', gender='Male', language='West Frisian')
# DataRow(ssn='190-53-4517', first_name='Hadlee', last_name='Rohan', gender='Male', language='Swahili')
# DataRow(ssn='191-15-3194', first_name='Calhoun', last_name='Mugford', gender='Male', language='Thai')
# DataRow(ssn='192-54-0695', first_name='Trev', last_name='Ruppeli', gender='Male', language='Maori')
# DataRow(ssn='192-67-3201', first_name='Edvard', last_name='Cattel', gender='Male', language='Hebrew')
# DataRow(ssn='194-76-5816', first_name='Jacquelynn', last_name='Shurey', gender='Female', language='Amharic')
# DataRow(ssn='195-23-5731', first_name='Talyah', last_name='Canny', gender='Female', language='Portuguese')
# DataRow(ssn='196-69-3796', first_name='Marijo', last_name='Tester', gender='Female', language='Oriya')
# DataRow(ssn='198-70-6443', first_name='Judah', last_name='Duggan', gender='Male', language='Macedonian')
# DataRow(ssn='199-45-0804', first_name='Consolata', last_name='Pigram', gender='Female', language='Guarana')
# DataRow(ssn='199-54-4639', first_name='Ellene', last_name='Dowrey', gender='Female', language='Nepali')
# DataRow(ssn='200-81-7151', first_name='Merilyn', last_name='Tink', gender='Female', language='Bengali')
# DataRow(ssn='201-53-1249', first_name='Jammal', last_name='Dohmer', gender='Male', language='Danish')
# DataRow(ssn='202-84-1146', first_name='Dore', last_name='Woodrup', gender='Male', language='Afrikaans')
# DataRow(ssn='203-35-7648', first_name='Budd', last_name='Artiss', gender='Male', language='Norwegian')
# DataRow(ssn='205-69-7375', first_name='Cacilia', last_name='Kneesha', gender='Female', language='Indonesian')
# DataRow(ssn='205-87-2423', first_name='Oralla', last_name='Kearle', gender='Female', language='Zulu')
# DataRow(ssn='206-28-6674', first_name='Con', last_name='Mansbridge', gender='Male', language='Haitian Creole')
# DataRow(ssn='206-83-8848', first_name='Ardyth', last_name='Arger', gender='Female', language='Gagauz')
# DataRow(ssn='208-74-2166', first_name='Tiebold', last_name='Gherarducci', gender='Male', language='Croatian')
# DataRow(ssn='208-80-5879', first_name='Rockie', last_name='Fryd', gender='Male', language='Korean')
# DataRow(ssn='209-50-8146', first_name='Kenna', last_name='Meryett', gender='Female', language='Czech')
# DataRow(ssn='209-58-4708', first_name='Stephanus', last_name='Creboe', gender='Male', language='Latvian')
# DataRow(ssn='210-91-4729', first_name='Tamarra', last_name='Minchella', gender='Female', language='Greek')
# DataRow(ssn='211-04-1734', first_name='Jeana', last_name='Girardeau', gender='Female', language='Dzongkha')
# DataRow(ssn='211-13-5247', first_name='Wes', last_name='Weinberg', gender='Male', language='French')
# DataRow(ssn='211-15-5182', first_name='Gene', last_name='Bassilashvili', gender='Female', language='Swedish')
# DataRow(ssn='211-19-6826', first_name='Noni', last_name='Meynell', gender='Female', language='Portuguese')
# DataRow(ssn='212-40-0215', first_name='Giffie', last_name='Strauss', gender='Male', language='Azeri')
# DataRow(ssn='212-41-1496', first_name='Agnese', last_name='Lawes', gender='Female', language='Tamil')
# DataRow(ssn='213-28-1395', first_name='Catlaina', last_name='Patullo', gender='Female', language='Bengali')
# DataRow(ssn='214-29-1189', first_name='Chandler', last_name='Gonsalvo', gender='Male', language='Haitian Creole')
# DataRow(ssn='214-96-8581', first_name='Earlie', last_name='de Nore', gender='Male', language='Georgian')
# DataRow(ssn='214-99-7584', first_name='Barny', last_name='Witherden', gender='Male', language='Czech')
# DataRow(ssn='216-89-3812', first_name='Florian', last_name='Jaze', gender='Male', language='Croatian')
# DataRow(ssn='216-97-3104', first_name='Elvira', last_name='McDougal', gender='Female', language='Bislama')
# DataRow(ssn='217-71-3922', first_name='Hayes', last_name='Vallentin', gender='Male', language='Bengali')
# DataRow(ssn='217-81-5416', first_name='Gusta', last_name='Cruise', gender='Female', language='Tsonga')
# DataRow(ssn='218-14-4448', first_name='Keary', last_name='Druhan', gender='Male', language='Dutch')
# DataRow(ssn='218-25-9873', first_name='Westbrooke', last_name='Succamore', gender='Male', language='Fijian')
# DataRow(ssn='218-31-1615', first_name='Trenton', last_name='Eggerton', gender='Male', language='Dari')
# DataRow(ssn='218-49-7300', first_name='Justinn', last_name='Sherebrooke', gender='Female', language='English')
# DataRow(ssn='220-16-0476', first_name='Baxy', last_name='Brothwood', gender='Male', language='Kyrgyz')
# DataRow(ssn='220-38-0208', first_name='Jess', last_name='Fulun', gender='Female', language='Gagauz')
# DataRow(ssn='222-39-8571', first_name='Fidelia', last_name='Domonkos', gender='Female', language='Fijian')
# DataRow(ssn='223-67-9203', first_name='Markus', last_name='Radband', gender='Male', language='Bosnian')
# DataRow(ssn='223-98-0846', first_name='Josy', last_name='Hadwick', gender='Female', language='Papiamento')
# DataRow(ssn='224-12-3436', first_name='Alister', last_name='Eakle', gender='Male', language='Estonian')
# DataRow(ssn='224-30-9267', first_name='Flori', last_name='Bagnal', gender='Female', language='Swedish')
# DataRow(ssn='224-54-6919', first_name='Kelly', last_name='Shipman', gender='Male', language='Icelandic')
# DataRow(ssn='224-84-2271', first_name='Weider', last_name='Carlisle', gender='Male', language='Swedish')
# DataRow(ssn='224-99-0668', first_name='Brandy', last_name='Steed', gender='Male', language='Croatian')
# DataRow(ssn='225-08-5789', first_name='Tamra', last_name='Becken', gender='Female', language='Telugu')
# DataRow(ssn='225-64-2735', first_name='Graig', last_name='Rasher', gender='Male', language='Maltese')
# DataRow(ssn='226-76-4452', first_name='Van', last_name='Gervaise', gender='Male', language='Greek')
# DataRow(ssn='227-72-7247', first_name='Mauricio', last_name='Gush', gender='Male', language='Tajik')
# DataRow(ssn='228-16-7922', first_name='Tabby', last_name='Chitty', gender='Male', language='Spanish')
# DataRow(ssn='228-55-2042', first_name='Jaquith', last_name='Durtnel', gender='Female', language='Czech')
# DataRow(ssn='228-90-5077', first_name='Jonathon', last_name='Klugel', gender='Male', language='Hindi')
# DataRow(ssn='229-44-9909', first_name='Barnabas', last_name='Heppenspall', gender='Male', language='Icelandic')
# DataRow(ssn='230-09-1794', first_name='Xerxes', last_name='Mathivon', gender='Male', language='Danish')
# DataRow(ssn='230-48-0684', first_name='Clay', last_name='Peaurt', gender='Male', language='Dhivehi')
# DataRow(ssn='230-99-1485', first_name='Markus', last_name='Revill', gender='Male', language='Moldovan')
# DataRow(ssn='231-66-9264', first_name='Gisele', last_name='Castelow', gender='Female', language='Hiri Motu')
# DataRow(ssn='232-18-5397', first_name='Clare', last_name='McGairl', gender='Female', language='Bengali')
# DataRow(ssn='233-27-2377', first_name='Arlyne', last_name='Stenning', gender='Female', language='Dari')
# DataRow(ssn='235-10-3518', first_name='Winfield', last_name='Purvis', gender='Male', language='Estonian')
# DataRow(ssn='236-31-8333', first_name='Wendeline', last_name='Millins', gender='Female', language='Kashmiri')
# DataRow(ssn='236-37-2567', first_name='Ariel', last_name='Murrigan', gender='Female', language='West Frisian')
# DataRow(ssn='237-48-6737', first_name='Eal', last_name='Ducastel', gender='Male', language='Indonesian')
# DataRow(ssn='237-80-7039', first_name='Ardyce', last_name='Hunn', gender='Female', language='Maltese')
# DataRow(ssn='238-13-8034', first_name='Estrellita', last_name='Heavy', gender='Female', language='Azeri')
# DataRow(ssn='238-39-9999', first_name='Pauly', last_name='Griffin', gender='Female', language='Georgian')
# DataRow(ssn='239-09-9133', first_name='Tom', last_name='Roggeman', gender='Male', language='Sotho')
# DataRow(ssn='239-37-4122', first_name='Jodee', last_name='Elsdon', gender='Female', language='Guarana')
# DataRow(ssn='240-08-8805', first_name='Gates', last_name='McGiffin', gender='Female', language='Finnish')
# DataRow(ssn='240-32-8915', first_name='Cathee', last_name='Tarbard', gender='Female', language='Papiamento')
# DataRow(ssn='240-67-6258', first_name='Kalina', last_name='Lloyds', gender='Female', language='Hindi')
# DataRow(ssn='242-22-9624', first_name='Felice', last_name='Surr', gender='Male', language='Afrikaans')
# DataRow(ssn='243-37-9496', first_name='Verine', last_name='Etchells', gender='Female', language='Burmese')
# DataRow(ssn='243-44-4611', first_name='Shani', last_name="O'Tierney", gender='Female', language='Aymara')
# DataRow(ssn='244-34-2210', first_name='Lek', last_name='Heino', gender='Male', language='New Zealand Sign Language')
# DataRow(ssn='244-52-7593', first_name='Erda', last_name='Paulusch', gender='Female', language='Gujarati')
# DataRow(ssn='244-79-3004', first_name='Renault', last_name='Stollard', gender='Male', language='Amharic')
# DataRow(ssn='244-81-0671', first_name='Viviyan', last_name='Udell', gender='Female', language='Moldovan')
# DataRow(ssn='245-60-5880', first_name='Oby', last_name='Hauxby', gender='Male', language='French')
# DataRow(ssn='245-77-4110', first_name='Alasdair', last_name='McAndrew', gender='Male', language='Czech')
# DataRow(ssn='247-08-9326', first_name='Minni', last_name='Scurman', gender='Female', language='Kannada')
# DataRow(ssn='247-86-5288', first_name='Lilly', last_name='Holby', gender='Female', language='Bosnian')
# DataRow(ssn='248-07-9757', first_name='Sean', last_name='Ham', gender='Male', language='Luxembourgish')
# DataRow(ssn='248-23-0150', first_name='Welbie', last_name='Gilley', gender='Male', language='Korean')
# DataRow(ssn='249-19-5514', first_name='Yehudi', last_name='Pharoah', gender='Male', language='Latvian')
# DataRow(ssn='253-61-8401', first_name='Genny', last_name='Juara', gender='Female', language='Tswana')
# DataRow(ssn='254-10-6071', first_name='Dwight', last_name='Eastcourt', gender='Male', language='Oriya')
# DataRow(ssn='254-92-9669', first_name='Tom', last_name='Larking', gender='Male', language='Icelandic')
# DataRow(ssn='255-81-0958', first_name='Darryl', last_name='Sparkes', gender='Female', language='Estonian')
# DataRow(ssn='256-54-7507', first_name='Angus', last_name='Cullip', gender='Male', language='Spanish')
# DataRow(ssn='256-57-0666', first_name='Rip', last_name='Grube', gender='Male', language='Ndebele')
# DataRow(ssn='257-12-6834', first_name='Derward', last_name='Paladini', gender='Male', language='Thai')
# DataRow(ssn='257-59-8603', first_name='Cyrillus', last_name='Sanchiz', gender='Male', language='Romanian')
# DataRow(ssn='257-77-3669', first_name='Ynez', last_name='Hain', gender='Female', language='Kazakh')
# DataRow(ssn='258-22-6416', first_name='Veriee', last_name='Klein', gender='Female', language='Northern Sotho')
# DataRow(ssn='259-38-5920', first_name='Jethro', last_name='Rustidge', gender='Male', language='Fijian')
# DataRow(ssn='261-14-9490', first_name='Lorry', last_name='Boshere', gender='Male', language='Oriya')
# DataRow(ssn='262-09-2144', first_name='Leigh', last_name='Paxforde', gender='Male', language='Portuguese')
# DataRow(ssn='262-46-7573', first_name='Lorene', last_name='Vagg', gender='Female', language='Punjabi')
# DataRow(ssn='262-55-4066', first_name='Kaitlynn', last_name='Bleazard', gender='Female', language='Estonian')
# DataRow(ssn='262-66-7030', first_name='Gray', last_name='Bissatt', gender='Female', language='Khmer')
# DataRow(ssn='264-39-3910', first_name='Elysia', last_name='Favell', gender='Female', language='Hindi')
# DataRow(ssn='266-86-9980', first_name='Rita', last_name='Leving', gender='Female', language='Latvian')
# DataRow(ssn='267-75-6383', first_name='Ardath', last_name='Pitts', gender='Female', language='Romanian')
# DataRow(ssn='269-01-2640', first_name='Russell', last_name='Dabner', gender='Male', language='Danish')
# DataRow(ssn='271-04-0134', first_name='Eadith', last_name='Jerg', gender='Female', language='Gagauz')
# DataRow(ssn='271-81-9938', first_name='James', last_name='Robbins', gender='Male', language='Bengali')
# DataRow(ssn='271-93-3051', first_name='Augustin', last_name='Agiolfinger', gender='Male', language='Latvian')
# DataRow(ssn='272-50-7309', first_name='Sig', last_name='Ather', gender='Male', language='Catalan')
# DataRow(ssn='272-81-7979', first_name='Sherlocke', last_name='Giddings', gender='Male', language='Georgian')
# DataRow(ssn='273-49-8218', first_name='Haze', last_name='Starkings', gender='Male', language='Portuguese')
# DataRow(ssn='274-50-3806', first_name='Shurlocke', last_name='Aron', gender='Male', language='Punjabi')
# DataRow(ssn='274-76-9883', first_name='Fawn', last_name='MacNamara', gender='Female', language='Bengali')
# DataRow(ssn='276-05-2973', first_name='Cly', last_name='Yerlett', gender='Male', language='Kazakh')
# DataRow(ssn='278-55-5842', first_name='Korie', last_name='Di Pietro', gender='Female', language='German')
# DataRow(ssn='278-64-4853', first_name='Diane-marie', last_name='Broggini', gender='Female', language='Tsonga')
# DataRow(ssn='279-12-7167', first_name='Elbertina', last_name='Alders', gender='Female', language='Amharic')
# DataRow(ssn='279-40-5540', first_name='Montague', last_name='Knowler', gender='Male', language='Chinese')
# DataRow(ssn='279-49-5682', first_name='Kleon', last_name='Tembridge', gender='Male', language='Gagauz')
# DataRow(ssn='280-53-7447', first_name='Suzette', last_name='Prahl', gender='Female', language='Romanian')
# DataRow(ssn='280-98-4410', first_name='Ealasaid', last_name='Devon', gender='Female', language='Tok Pisin')
# DataRow(ssn='281-23-3458', first_name='Bettina', last_name='Danilov', gender='Female', language='Sotho')
# DataRow(ssn='282-83-9206', first_name='Jackie', last_name='McPhater', gender='Male', language='Gagauz')
# DataRow(ssn='283-04-6835', first_name='Tobey', last_name='Joule', gender='Female', language='Dzongkha')
# DataRow(ssn='286-26-4004', first_name='Augustus', last_name='Doodson', gender='Male', language='Romanian')
# DataRow(ssn='287-57-9688', first_name='Joachim', last_name='Moncreiff', gender='Male', language='Catalan')
# DataRow(ssn='287-66-2660', first_name='Larissa', last_name='Airy', gender='Female', language='Bislama')
# DataRow(ssn='288-54-7233', first_name='Hedy', last_name='Eaklee', gender='Female', language='English')
# DataRow(ssn='288-87-6462', first_name='Stanislaus', last_name='Haylor', gender='Male', language='Kannada')
# DataRow(ssn='289-03-9882', first_name='Giusto', last_name='Baszniak', gender='Male', language='Yiddish')
# DataRow(ssn='289-09-8686', first_name='Heath', last_name='Stallan', gender='Male', language='Malayalam')
# DataRow(ssn='290-25-7300', first_name='Bowie', last_name='Bancroft', gender='Male', language='Thai')
# DataRow(ssn='290-82-4968', first_name='Ingram', last_name='Kincade', gender='Male', language='Moldovan')
# DataRow(ssn='293-54-3694', first_name='Theodora', last_name='Geddes', gender='Female', language='Maori')
# DataRow(ssn='294-27-9936', first_name='Cari', last_name='Bradane', gender='Female', language='Japanese')
# DataRow(ssn='294-53-1911', first_name='Ginelle', last_name='Jaquet', gender='Female', language='Persian')
# DataRow(ssn='295-63-7693', first_name='Fonzie', last_name='Fattorini', gender='Male', language='Estonian')
# DataRow(ssn='296-32-7910', first_name='Harlene', last_name='Morrill', gender='Female', language='Swati')
# DataRow(ssn='296-88-0097', first_name='Herculie', last_name='Branthwaite', gender='Male', language='Hungarian')
# DataRow(ssn='296-90-4908', first_name='Holt', last_name='Angel', gender='Male', language='Tamil')
# DataRow(ssn='297-63-1154', first_name='Maribelle', last_name='Gowanson', gender='Female', language='Montenegrin')
# DataRow(ssn='298-06-3497', first_name='Moshe', last_name='Thomassin', gender='Male', language='Polish')
# DataRow(ssn='298-69-9168', first_name='Shea', last_name='Canon', gender='Male', language='Finnish')
# DataRow(ssn='298-70-6018', first_name='Minny', last_name='Van der Baaren', gender='Female', language='Afrikaans')
# DataRow(ssn='298-79-7640', first_name='Mycah', last_name='Hillam', gender='Male', language='Swahili')
# DataRow(ssn='299-03-6911', first_name='Janela', last_name='Ferrone', gender='Female', language='Gagauz')
# DataRow(ssn='299-38-0483', first_name='Robb', last_name='Posner', gender='Male', language='Italian')
# DataRow(ssn='299-77-1060', first_name='Bellina', last_name='Galbreth', gender='Female', language='Norwegian')
# DataRow(ssn='300-59-3610', first_name='Tam', last_name='Howles', gender='Male', language='Pashto')
# DataRow(ssn='300-76-8770', first_name='Danielle', last_name='Rowth', gender='Female', language='Italian')
# DataRow(ssn='300-80-7209', first_name='Gabbie', last_name='Burney', gender='Female', language='Dutch')
# DataRow(ssn='301-26-4306', first_name='Emmye', last_name='Whelpdale', gender='Female', language='Tajik')
# DataRow(ssn='301-51-0522', first_name='Kenneth', last_name='Methley', gender='Male', language='Papiamento')
# DataRow(ssn='302-64-4858', first_name='Hakeem', last_name='Zelley', gender='Male', language='Afrikaans')
# DataRow(ssn='304-48-4312', first_name='Edeline', last_name='Van de Vlies', gender='Female', language='Montenegrin')
# DataRow(ssn='305-07-1498', first_name='Ruddy', last_name="O'Crotty", gender='Male', language='Spanish')
# DataRow(ssn='306-23-2423', first_name='Ree', last_name='Meader', gender='Female', language='Polish')
# DataRow(ssn='306-86-2930', first_name='Kassie', last_name='Neaverson', gender='Female', language='Luxembourgish')
# DataRow(ssn='308-58-0964', first_name='Talbert', last_name='Osipov', gender='Male', language='Tetum')
# DataRow(ssn='309-04-0364', first_name='Dov', last_name='Speight', gender='Male', language='Tajik')
# DataRow(ssn='309-38-8085', first_name='Nell', last_name='Scrigmour', gender='Female', language='Persian')
# DataRow(ssn='310-60-2027', first_name='Zacherie', last_name='Parken', gender='Male', language='Albanian')
# DataRow(ssn='311-46-9296', first_name='Alic', last_name='Pabel', gender='Male', language='Fijian')
# DataRow(ssn='312-38-7084', first_name='Ezri', last_name='Paolicchi', gender='Male', language='Malagasy')
# DataRow(ssn='312-59-3476', first_name='Sadye', last_name='Beloe', gender='Female', language='Icelandic')
# DataRow(ssn='312-77-3647', first_name='Hussein', last_name='Blything', gender='Male', language='Hebrew')
# DataRow(ssn='313-02-7822', first_name='Spence', last_name='Climer', gender='Male', language='Maori')
# DataRow(ssn='313-52-7312', first_name='Farrand', last_name='MacKenzie', gender='Female', language='French')
# DataRow(ssn='315-12-5664', first_name='Vere', last_name='Morlon', gender='Female', language='German')
# DataRow(ssn='315-26-2241', first_name='Cammy', last_name='Harland', gender='Female', language='Bulgarian')
# DataRow(ssn='315-44-9671', first_name='Ximenez', last_name='Maghull', gender='Male', language='Macedonian')
# DataRow(ssn='315-78-5587', first_name='Helsa', last_name='Lumber', gender='Female', language='Tok Pisin')
# DataRow(ssn='317-28-1600', first_name='Rodrick', last_name='Abrahams', gender='Male', language='Assamese')
# DataRow(ssn='317-43-2055', first_name='Jocelyn', last_name='Gildroy', gender='Female', language='Punjabi')
# DataRow(ssn='318-58-5314', first_name='Stephan', last_name='Peatt', gender='Male', language='New Zealand Sign Language')
# DataRow(ssn='319-43-0465', first_name='Boothe', last_name='Vanin', gender='Male', language='West Frisian')
# DataRow(ssn='320-90-1419', first_name='Em', last_name='Darwood', gender='Male', language='Icelandic')
# DataRow(ssn='320-97-9147', first_name='Roch', last_name='Wahlberg', gender='Female', language='Thai')
# DataRow(ssn='323-28-6705', first_name='Christiano', last_name='Stoffler', gender='Male', language='Kyrgyz')
# DataRow(ssn='323-33-8689', first_name='Dulcinea', last_name='Lundberg', gender='Female', language='Dutch')
# DataRow(ssn='324-39-5230', first_name='Alexandrina', last_name='Dahlbom', gender='Female', language='Moldovan')
# DataRow(ssn='324-73-8895', first_name='Walliw', last_name='Alstead', gender='Female', language='Guarana')
# DataRow(ssn='324-75-6098', first_name='Rafael', last_name='Robinett', gender='Male', language='Portuguese')
# DataRow(ssn='326-64-9957', first_name='Jorgan', last_name='Renowden', gender='Male', language='Swati')
# DataRow(ssn='327-52-0546', first_name='Carlota', last_name='Hovey', gender='Female', language='English')
# DataRow(ssn='327-88-7554', first_name='Malynda', last_name='Kingerby', gender='Female', language='Swahili')
# DataRow(ssn='330-99-3055', first_name='Marinna', last_name='Dally', gender='Female', language='Azeri')
# DataRow(ssn='332-83-6591', first_name='Forrester', last_name='Cullabine', gender='Male', language='Dzongkha')
# DataRow(ssn='333-52-5097', first_name='Florentia', last_name='Espinazo', gender='Female', language='Tetum')
# DataRow(ssn='333-95-5025', first_name='Rebeca', last_name='Walesa', gender='Female', language='Zulu')
# DataRow(ssn='335-35-1520', first_name='Ervin', last_name='Hugues', gender='Male', language='Armenian')
# DataRow(ssn='336-48-2579', first_name='Renee', last_name='Crank', gender='Female', language='Armenian')
# DataRow(ssn='339-27-8046', first_name='Julita', last_name='Jouhan', gender='Female', language='Bosnian')
# DataRow(ssn='339-71-2687', first_name='Marlie', last_name='Corpe', gender='Female', language='Persian')
# DataRow(ssn='341-10-6840', first_name='Cyrille', last_name='Critchlow', gender='Male', language='Portuguese')
# DataRow(ssn='342-05-9057', first_name='Beatrix', last_name='Relton', gender='Female', language='Latvian')
# DataRow(ssn='342-55-0538', first_name='Hilliary', last_name='Suddards', gender='Female', language='Dzongkha')
# DataRow(ssn='342-90-9333', first_name='Geri', last_name='Yesinov', gender='Male', language='Norwegian')
# DataRow(ssn='343-20-8407', first_name='Bradford', last_name='Niemiec', gender='Male', language='Chinese')
# DataRow(ssn='343-81-3179', first_name='Reinhard', last_name='Bortolutti', gender='Male', language='Kannada')
# DataRow(ssn='345-74-2160', first_name='Camile', last_name='Pengelly', gender='Female', language='Lao')
# DataRow(ssn='347-09-3254', first_name='Dulciana', last_name='Hexum', gender='Female', language='Lao')
# DataRow(ssn='347-64-8652', first_name='Dusty', last_name='Morat', gender='Female', language='Japanese')
# DataRow(ssn='348-73-4312', first_name='Elberta', last_name='Howden', gender='Female', language='Khmer')
# DataRow(ssn='348-74-3224', first_name='Dorthy', last_name='Abreheart', gender='Female', language='Bosnian')
# DataRow(ssn='349-53-8864', first_name='Muffin', last_name='Lord', gender='Female', language='Georgian')
# DataRow(ssn='349-67-7502', first_name='Ari', last_name='Yitzhakov', gender='Male', language='Zulu')
# DataRow(ssn='350-20-9593', first_name='Eldridge', last_name='Crispin', gender='Male', language='Dutch')
# DataRow(ssn='350-80-4646', first_name='Harp', last_name='Du Plantier', gender='Male', language='Dutch')
# DataRow(ssn='351-73-2802', first_name='Cybill', last_name='Parnham', gender='Female', language='Latvian')
# DataRow(ssn='355-21-9711', first_name='Daryn', last_name='Battin', gender='Female', language='Georgian')
# DataRow(ssn='355-52-9767', first_name='Kacy', last_name='Offen', gender='Female', language='Kurdish')
# DataRow(ssn='355-96-7706', first_name='Lauritz', last_name='Lucock', gender='Male', language='Mongolian')
# DataRow(ssn='356-39-9199', first_name='Arney', last_name='Polglaze', gender='Male', language='Marathi')
# DataRow(ssn='357-37-6094', first_name='Chrisse', last_name='Kirton', gender='Male', language='Latvian')
# DataRow(ssn='358-84-7049', first_name='Emalee', last_name='McCleary', gender='Female', language='Thai')
# DataRow(ssn='360-69-6230', first_name='Grannie', last_name='Champ', gender='Male', language='Belarusian')
# DataRow(ssn='361-06-1530', first_name='Luis', last_name='Ashborne', gender='Male', language='Mongolian')
# DataRow(ssn='361-42-7068', first_name='Ashia', last_name='Ferran', gender='Female', language='West Frisian')
# DataRow(ssn='361-49-4597', first_name='Adan', last_name='Janssen', gender='Male', language='Swedish')
# DataRow(ssn='361-83-5004', first_name='Wilona', last_name='Sink', gender='Female', language='Sotho')
# DataRow(ssn='362-09-8563', first_name='Carri', last_name='Peterffy', gender='Female', language='Icelandic')
# DataRow(ssn='362-12-7902', first_name='Weber', last_name='Legrand', gender='Male', language='Swahili')
# DataRow(ssn='364-25-0166', first_name='Arnuad', last_name='Planque', gender='Male', language='Hindi')
# DataRow(ssn='364-65-2174', first_name='Bernarr', last_name='Wollard', gender='Male', language='Irish Gaelic')
# DataRow(ssn='366-61-0607', first_name='Bethena', last_name='Joicey', gender='Female', language='Haitian Creole')
# DataRow(ssn='367-22-8998', first_name='Blake', last_name='Mustin', gender='Female', language='Kyrgyz')
# DataRow(ssn='367-62-4426', first_name='Sigismondo', last_name='Lerohan', gender='Male', language='Georgian')
# DataRow(ssn='370-01-6977', first_name='Hugues', last_name='Jeffryes', gender='Male', language='Georgian')
# DataRow(ssn='370-24-5876', first_name='Sergei', last_name='Risby', gender='Male', language='Bulgarian')
# DataRow(ssn='370-72-6509', first_name='Wrennie', last_name='McCrorie', gender='Female', language='Papiamento')
# DataRow(ssn='371-28-5892', first_name='Malia', last_name='Hanse', gender='Female', language='Tsonga')
# DataRow(ssn='371-44-0582', first_name='Clemmy', last_name='Cogzell', gender='Male', language='Estonian')
# DataRow(ssn='371-62-3727', first_name='Cymbre', last_name='Chinnock', gender='Female', language='Dutch')
# DataRow(ssn='371-88-9249', first_name='Nealon', last_name='Oxtaby', gender='Male', language='German')
# DataRow(ssn='372-44-7487', first_name='Jolyn', last_name='Bertome', gender='Female', language='Catalan')
# DataRow(ssn='372-62-7057', first_name='Eleanora', last_name='Vazquez', gender='Female', language='Gujarati')
# DataRow(ssn='373-67-2734', first_name='Ileana', last_name='Luty', gender='Female', language='Italian')
# DataRow(ssn='374-47-0262', first_name='Bank', last_name='Evitts', gender='Male', language='Aymara')
# DataRow(ssn='378-08-0805', first_name='Carroll', last_name='Harty', gender='Female', language='Swedish')
# DataRow(ssn='378-60-2472', first_name='Eddie', last_name='Howieson', gender='Female', language='Albanian')
# DataRow(ssn='378-66-0449', first_name='Kelby', last_name='Wincer', gender='Male', language='Pashto')
# DataRow(ssn='378-79-0193', first_name='Kenny', last_name='Josefsen', gender='Male', language='Danish')
# DataRow(ssn='378-88-6805', first_name='Vittoria', last_name='Oldroyd', gender='Female', language='Moldovan')
# DataRow(ssn='379-07-8748', first_name='Dyanna', last_name='Noto', gender='Female', language='Polish')
# DataRow(ssn='380-33-9730', first_name='Katinka', last_name='Piet', gender='Female', language='Malay')
# DataRow(ssn='380-35-3854', first_name='Cathleen', last_name='Sizland', gender='Female', language='Bislama')
# DataRow(ssn='383-18-4058', first_name='Frederigo', last_name='Cooksey', gender='Male', language='Indonesian')
# DataRow(ssn='384-30-6793', first_name='Kipp', last_name='Burnyate', gender='Male', language='English')
# DataRow(ssn='384-94-2772', first_name='Ramsay', last_name='Dolbey', gender='Male', language='Tok Pisin')
# DataRow(ssn='385-30-1777', first_name='Aubrey', last_name='Wetherill', gender='Female', language='Tswana')
# DataRow(ssn='385-34-7828', first_name='Dori', last_name='Quogan', gender='Female', language='Afrikaans')
# DataRow(ssn='385-98-0431', first_name='Kassi', last_name='Rashleigh', gender='Female', language='Tswana')
# DataRow(ssn='386-15-7960', first_name='Steffie', last_name='Tedahl', gender='Female', language='Punjabi')
# DataRow(ssn='386-34-4088', first_name='Adamo', last_name='Wogden', gender='Male', language='Arabic')
# DataRow(ssn='386-68-9884', first_name='Francis', last_name='Foch', gender='Male', language='Dzongkha')
# DataRow(ssn='386-97-3523', first_name='Siusan', last_name='Durkin', gender='Female', language='Kurdish')
# DataRow(ssn='389-31-0910', first_name='Mac', last_name='Westrey', gender='Male', language='Armenian')
# DataRow(ssn='389-51-1424', first_name='Isadore', last_name='Orbine', gender='Male', language='Pashto')
# DataRow(ssn='389-84-8254', first_name='Chiquita', last_name='Jolliman', gender='Female', language='Marathi')
# DataRow(ssn='390-74-3062', first_name='Cara', last_name='Ingree', gender='Female', language='Indonesian')
# DataRow(ssn='391-14-9280', first_name='Faun', last_name='Chillistone', gender='Female', language='Montenegrin')
# DataRow(ssn='391-47-4578', first_name='Fiann', last_name='Fellman', gender='Female', language='Assamese')
# DataRow(ssn='391-73-2830', first_name='Padget', last_name='Manthorpe', gender='Male', language='Marathi')
# DataRow(ssn='393-22-6585', first_name='Reinold', last_name='Ellif', gender='Male', language='Nepali')
# DataRow(ssn='396-51-1559', first_name='Natasha', last_name='Dafter', gender='Female', language='Maori')
# DataRow(ssn='397-16-5372', first_name='Alonzo', last_name='Mc Mechan', gender='Male', language='Polish')
# DataRow(ssn='397-29-8349', first_name='Madelle', last_name='Mapledorum', gender='Female', language='Tok Pisin')
# DataRow(ssn='397-87-8282', first_name='Kyrstin', last_name='Waldock', gender='Female', language='Belarusian')
# DataRow(ssn='399-31-2815', first_name='Durward', last_name='Giamitti', gender='Male', language='Tok Pisin')
# DataRow(ssn='399-63-8810', first_name='Bobbee', last_name='Postians', gender='Female', language='Papiamento')
# DataRow(ssn='399-81-6133', first_name='Viv', last_name='Borsay', gender='Female', language='Chinese')
# DataRow(ssn='400-21-8654', first_name='Travus', last_name='Miranda', gender='Male', language='Kannada')
# DataRow(ssn='400-77-6007', first_name='Dannie', last_name='Shurmer', gender='Male', language='Tajik')
# DataRow(ssn='402-61-3479', first_name='Mariele', last_name='Meyrick', gender='Female', language='Telugu')
# DataRow(ssn='402-65-2055', first_name='Martie', last_name='Crawshaw', gender='Male', language='Marathi')
# DataRow(ssn='402-88-5570', first_name='Torry', last_name='Bossons', gender='Male', language='Chinese')
# DataRow(ssn='403-65-1535', first_name='Cathy', last_name='Gabe', gender='Female', language='Hiri Motu')
# DataRow(ssn='404-57-4023', first_name='Pattin', last_name='Jarmain', gender='Male', language='Hindi')
# DataRow(ssn='405-25-1422', first_name='Raquel', last_name='Dukelow', gender='Female', language='Gujarati')
# DataRow(ssn='406-15-5123', first_name='Janot', last_name='Pulhoster', gender='Female', language='Dari')
# DataRow(ssn='406-24-4867', first_name='Renaud', last_name='Fleetwood', gender='Male', language='Papiamento')
# DataRow(ssn='406-49-0634', first_name='Lolita', last_name='Dailey', gender='Female', language='Czech')
# DataRow(ssn='407-30-0910', first_name='Gerhard', last_name='Crielly', gender='Male', language='Bislama')
# DataRow(ssn='407-80-7367', first_name='Sigismundo', last_name='Pothbury', gender='Male', language='Latvian')
# DataRow(ssn='407-99-6159', first_name='Flynn', last_name='Jirasek', gender='Male', language='Afrikaans')
# DataRow(ssn='408-83-7943', first_name='Wallie', last_name='Klosterman', gender='Male', language='Hungarian')
# DataRow(ssn='408-98-3291', first_name='Karia', last_name='Riquet', gender='Female', language='Italian')
# DataRow(ssn='409-58-2034', first_name='Fiann', last_name='Corsar', gender='Female', language='Swahili')
# DataRow(ssn='409-90-8946', first_name='Doralia', last_name='Proughten', gender='Female', language='Estonian')
# DataRow(ssn='410-38-4237', first_name='Gibbie', last_name='Seamer', gender='Male', language='Tok Pisin')
# DataRow(ssn='410-76-5092', first_name='Spencer', last_name='Dallon', gender='Male', language='Swati')
# DataRow(ssn='411-21-4276', first_name='Mari', last_name='Livick', gender='Female', language='Pashto')
# DataRow(ssn='411-43-4217', first_name='Cull', last_name='Noddle', gender='Male', language='Spanish')
# DataRow(ssn='411-79-4655', first_name='Caterina', last_name='Coey', gender='Female', language='French')
# DataRow(ssn='412-50-9133', first_name='Dianemarie', last_name='Withey', gender='Female', language='Czech')
# DataRow(ssn='412-59-0452', first_name='Seamus', last_name='Petrusch', gender='Male', language='Spanish')
# DataRow(ssn='412-59-8022', first_name='Brenna', last_name='Follin', gender='Female', language='Gagauz')
# DataRow(ssn='412-79-8951', first_name='Giorgi', last_name='Sisnett', gender='Male', language='Tamil')
# DataRow(ssn='413-14-3928', first_name='Shaine', last_name='Liebrecht', gender='Male', language='Sotho')
# DataRow(ssn='413-56-5613', first_name='Anjanette', last_name='Carnock', gender='Female', language='Nepali')
# DataRow(ssn='415-42-0898', first_name='Karlik', last_name='Adlam', gender='Male', language='Mongolian')
# DataRow(ssn='415-74-2251', first_name='Pattin', last_name='Greson', gender='Male', language='Italian')
# DataRow(ssn='416-37-7763', first_name='Emelia', last_name='Hancell', gender='Female', language='German')
# DataRow(ssn='416-38-3607', first_name='Jerry', last_name='Christin', gender='Male', language='Hebrew')
# DataRow(ssn='416-80-6367', first_name='Myrna', last_name='Christoffe', gender='Female', language='Tok Pisin')
# DataRow(ssn='416-87-0469', first_name='Dannel', last_name='Whyffen', gender='Male', language='Estonian')
# DataRow(ssn='418-72-1888', first_name='Roddy', last_name='Worman', gender='Male', language='Bosnian')
# DataRow(ssn='418-99-6659', first_name='Grenville', last_name='Gulliver', gender='Male', language='Ndebele')
# DataRow(ssn='420-46-7789', first_name='Steffie', last_name='Britto', gender='Female', language='New Zealand Sign Language')
# DataRow(ssn='420-52-3813', first_name='Arnaldo', last_name='Balsdone', gender='Male', language='Zulu')
# DataRow(ssn='421-01-2511', first_name='Mikaela', last_name='Andrivot', gender='Female', language='English')
# DataRow(ssn='421-13-9794', first_name='Minne', last_name='Measey', gender='Female', language='Danish')
# DataRow(ssn='421-20-3448', first_name='Alie', last_name='Gerauld', gender='Female', language='Khmer')
# DataRow(ssn='421-88-7316', first_name='Cherie', last_name='Yeudall', gender='Female', language='Dutch')
# DataRow(ssn='422-67-4000', first_name='Corby', last_name='Boyington', gender='Male', language='Sotho')
# DataRow(ssn='423-62-1820', first_name='Ruddy', last_name='Ingerson', gender='Male', language='Maori')
# DataRow(ssn='423-88-4721', first_name='Trip', last_name='Postlewhite', gender='Male', language='Polish')
# DataRow(ssn='424-22-9138', first_name='Farand', last_name='Huggon', gender='Female', language='Indonesian')
# DataRow(ssn='424-91-0692', first_name='Jeanie', last_name='Titchard', gender='Female', language='Swati')
# DataRow(ssn='424-92-0863', first_name='Halley', last_name='Mendenhall', gender='Female', language='Thai')
# DataRow(ssn='426-09-8331', first_name='Enrico', last_name='Balentyne', gender='Male', language='Arabic')
# DataRow(ssn='426-33-4523', first_name='Bibbie', last_name='Lardge', gender='Female', language='Spanish')
# DataRow(ssn='426-52-3410', first_name='Deeyn', last_name='Feldberg', gender='Female', language='Lithuanian')
# DataRow(ssn='426-61-5374', first_name='Adolph', last_name='Effemy', gender='Male', language='Norwegian')
# DataRow(ssn='427-12-4625', first_name='Ethelin', last_name='Huck', gender='Female', language='Bosnian')
# ...
# DataRow(ssn='773-53-7438', first_name='Flo', last_name='Sirmond', gender='Female', language='Khmer')
# DataRow(ssn='773-82-1734', first_name='Maris', last_name='Currin', gender='Female', language='Armenian')
# DataRow(ssn='774-08-5376', first_name='Pam', last_name='Matterface', gender='Female', language='Swahili')
# DataRow(ssn='775-09-9949', first_name='Orlando', last_name='Gresley', gender='Male', language='Danish')
# DataRow(ssn='777-05-1491', first_name='Devora', last_name='Ashbridge', gender='Female', language='Somali')
# DataRow(ssn='777-68-2978', first_name='Mignon', last_name='Skottle', gender='Female', language='Northern Sotho')
# DataRow(ssn='777-94-4586', first_name='Siward', last_name='Blues', gender='Male', language='Thai')
# DataRow(ssn='778-74-8262', first_name='Sonia', last_name='Grishakin', gender='Female', language='Bulgarian')
# DataRow(ssn='779-59-1449', first_name='Gertrude', last_name='Ledamun', gender='Female', language='Hungarian')
# DataRow(ssn='780-69-8282', first_name='Sibeal', last_name='Dawney', gender='Female', language='Czech')
# DataRow(ssn='781-88-2076', first_name='Gelya', last_name='Stell', gender='Female', language='Czech')
# DataRow(ssn='782-46-9660', first_name='Malina', last_name='Julyan', gender='Female', language='Burmese')
# DataRow(ssn='782-60-6848', first_name='Jehu', last_name='Scholig', gender='Male', language='Polish')
# DataRow(ssn='783-22-9258', first_name='Modestine', last_name='Cuttings', gender='Female', language='Assamese')
# DataRow(ssn='784-88-0730', first_name='Baxie', last_name='Judd', gender='Male', language='Maltese')
# DataRow(ssn='785-14-5978', first_name='Trista', last_name='Watkinson', gender='Female', language='Moldovan')
# DataRow(ssn='786-56-3561', first_name='Wait', last_name='Boyda', gender='Male', language='Norwegian')
# DataRow(ssn='786-63-6223', first_name='Adham', last_name='Toope', gender='Male', language='Belarusian')
# DataRow(ssn='787-05-9008', first_name='Ricki', last_name='Jurges', gender='Female', language='Arabic')
# DataRow(ssn='787-09-5697', first_name='Chelsea', last_name='Pashby', gender='Female', language='Northern Sotho')
# DataRow(ssn='787-10-7877', first_name='Torrence', last_name='Tapping', gender='Male', language='Hiri Motu')
# DataRow(ssn='788-15-2625', first_name='Drusilla', last_name='Bannester', gender='Female', language='Gujarati')
# DataRow(ssn='789-70-1821', first_name='Denni', last_name='De Biasio', gender='Female', language='Azeri')
# DataRow(ssn='790-04-1283', first_name='Christyna', last_name='Morrissey', gender='Female', language='Quechua')
# DataRow(ssn='792-71-8046', first_name='Carly', last_name='Hazley', gender='Female', language='Guarana')
# DataRow(ssn='794-24-3802', first_name='Esther', last_name='Sayton', gender='Female', language='Somali')
# DataRow(ssn='795-56-6486', first_name='Stevena', last_name='Vatcher', gender='Female', language='Gagauz')
# DataRow(ssn='795-77-5263', first_name='Burty', last_name='Frosdick', gender='Male', language='Marathi')
# DataRow(ssn='797-05-2289', first_name='Fanchon', last_name='Petrushanko', gender='Female', language='Finnish')
# DataRow(ssn='797-25-9814', first_name='Aleksandr', last_name='Swalwell', gender='Male', language='Pashto')
# DataRow(ssn='797-65-2382', first_name='Marianne', last_name='Huccaby', gender='Female', language='Swedish')
# DataRow(ssn='797-87-7992', first_name='Lonna', last_name='Plumridge', gender='Female', language='Armenian')
# DataRow(ssn='798-34-1082', first_name='Henka', last_name='Synder', gender='Female', language='Italian')
# DataRow(ssn='798-65-5644', first_name='Irita', last_name='Heady', gender='Female', language='Montenegrin')
# DataRow(ssn='800-06-9721', first_name='Carter', last_name='Waldron', gender='Male', language='Estonian')
# DataRow(ssn='801-08-8313', first_name='Aida', last_name='Whitemarsh', gender='Female', language='Chinese')
# DataRow(ssn='801-92-6460', first_name='Levi', last_name='Downgate', gender='Male', language='Belarusian')
# DataRow(ssn='801-99-2773', first_name='Justinian', last_name='Carlesso', gender='Male', language='Japanese')
# DataRow(ssn='804-46-0617', first_name='Geneva', last_name='Crinion', gender='Female', language='Hungarian')
# DataRow(ssn='807-13-5922', first_name='Vivi', last_name='Edinboro', gender='Female', language='Sotho')
# DataRow(ssn='807-24-6202', first_name='Lanette', last_name='Elvins', gender='Female', language='Hiri Motu')
# DataRow(ssn='807-25-6136', first_name='Sammy', last_name='Linnard', gender='Female', language='Dutch')
# DataRow(ssn='807-35-8936', first_name='Georgi', last_name='Widd', gender='Male', language='Afrikaans')
# DataRow(ssn='807-50-8539', first_name='Jaquith', last_name='Erdes', gender='Female', language='Dhivehi')
# DataRow(ssn='807-60-5615', first_name='Michale', last_name='Druery', gender='Male', language='Dhivehi')
# DataRow(ssn='808-55-8658', first_name='Ursulina', last_name='Kunze', gender='Female', language='Chinese')
# DataRow(ssn='808-80-2542', first_name='Gustaf', last_name='Hullot', gender='Male', language='Persian')
# DataRow(ssn='811-65-2750', first_name='Minetta', last_name='Dusting', gender='Female', language='Spanish')
# DataRow(ssn='812-11-9403', first_name='Carmina', last_name='Turnell', gender='Female', language='West Frisian')
# DataRow(ssn='813-42-4142', first_name='Killy', last_name='Threadgould', gender='Male', language='Polish')
# DataRow(ssn='813-47-5215', first_name='Willi', last_name='Collet', gender='Male', language='Gujarati')
# DataRow(ssn='815-83-0300', first_name='Romeo', last_name='Rayworth', gender='Male', language='Thai')
# DataRow(ssn='816-31-3858', first_name='Elvera', last_name='Walmsley', gender='Female', language='Montenegrin')
# DataRow(ssn='816-47-4782', first_name='Wilmer', last_name='Maides', gender='Male', language='Aymara')
# DataRow(ssn='816-90-2049', first_name='Berry', last_name='Delagnes', gender='Female', language='Bengali')
# DataRow(ssn='817-04-1950', first_name='Fletcher', last_name='McGrouther', gender='Male', language='Albanian')
# DataRow(ssn='817-25-7437', first_name='Randall', last_name='Fibbitts', gender='Male', language='Yiddish')
# DataRow(ssn='817-80-8930', first_name='Lib', last_name='Skein', gender='Female', language='Arabic')
# DataRow(ssn='818-61-0770', first_name='Stanly', last_name='Casseldine', gender='Male', language='Belarusian')
# DataRow(ssn='819-52-5886', first_name='Paulette', last_name='McAree', gender='Female', language='Arabic')
# DataRow(ssn='819-64-1414', first_name='Malynda', last_name='Hundall', gender='Female', language='Filipino')
# DataRow(ssn='820-96-1105', first_name='Andy', last_name='Sayce', gender='Female', language='Pashto')
# DataRow(ssn='822-05-9037', first_name='Meggi', last_name='Mapes', gender='Female', language='Moldovan')
# DataRow(ssn='822-30-4861', first_name='Phyllis', last_name='Cronk', gender='Female', language='Fijian')
# DataRow(ssn='823-27-0762', first_name='Marten', last_name='McCord', gender='Male', language='Indonesian')
# DataRow(ssn='823-75-5753', first_name='Thibaut', last_name='Van Schafflaer', gender='Male', language='Chinese')
# DataRow(ssn='824-89-4169', first_name='Tamqrah', last_name='Goroni', gender='Female', language='Swedish')
# DataRow(ssn='826-97-8029', first_name='Llewellyn', last_name='Shimwell', gender='Male', language='Belarusian')
# DataRow(ssn='827-62-4599', first_name='Phyllys', last_name='Akast', gender='Female', language='Armenian')
# DataRow(ssn='830-23-1573', first_name='Carine', last_name='Abramin', gender='Female', language='Bislama')
# DataRow(ssn='831-44-3286', first_name='Leesa', last_name='Finci', gender='Female', language='Nepali')
# DataRow(ssn='833-01-1428', first_name='Ashlan', last_name='Zannotti', gender='Female', language='Finnish')
# DataRow(ssn='835-54-3785', first_name='Nathaniel', last_name='Wegman', gender='Male', language='Azeri')
# DataRow(ssn='836-40-1837', first_name='Brocky', last_name='Kewzick', gender='Male', language='Armenian')
# DataRow(ssn='836-99-3309', first_name='Cobby', last_name='Mutter', gender='Male', language='Georgian')
# DataRow(ssn='837-76-5619', first_name='Alleyn', last_name='Parade', gender='Male', language='Croatian')
# DataRow(ssn='838-69-1351', first_name='Alwin', last_name='Hazzard', gender='Male', language='Kannada')
# DataRow(ssn='840-41-7929', first_name='Sherlock', last_name='Pinshon', gender='Male', language='Khmer')
# DataRow(ssn='841-64-8517', first_name='Hugues', last_name='Kenealy', gender='Male', language='Korean')
# DataRow(ssn='842-90-7557', first_name='Brit', last_name='Weall', gender='Female', language='West Frisian')
# DataRow(ssn='844-15-4668', first_name='Eleonora', last_name='Delete', gender='Female', language='Hiri Motu')
# DataRow(ssn='844-50-7305', first_name='Merralee', last_name='Orae', gender='Female', language='Macedonian')
# DataRow(ssn='846-07-1407', first_name='Tobias', last_name='Blakelock', gender='Male', language='German')
# DataRow(ssn='846-09-9851', first_name='Shani', last_name='Penrose', gender='Female', language='New Zealand Sign Language')
# DataRow(ssn='846-59-9961', first_name='Saleem', last_name='Osmant', gender='Male', language='Croatian')
# DataRow(ssn='847-34-4817', first_name='Orazio', last_name='Coners', gender='Male', language='Yiddish')
# DataRow(ssn='847-61-7656', first_name='Brit', last_name='Lodovichi', gender='Male', language='Bislama')
# DataRow(ssn='848-58-3386', first_name='Julianne', last_name='Lygo', gender='Female', language='Japanese')
# DataRow(ssn='848-74-2886', first_name='Helyn', last_name='Witheford', gender='Female', language='Bislama')
# DataRow(ssn='848-76-8808', first_name='Durward', last_name='Nuscha', gender='Male', language='Nepali')
# DataRow(ssn='849-31-1551', first_name='Lisabeth', last_name='Mattessen', gender='Female', language='German')
# DataRow(ssn='849-64-6624', first_name='Hallie', last_name='Proschke', gender='Female', language='Fijian')
# DataRow(ssn='849-98-2973', first_name='Hurley', last_name='Newart', gender='Male', language='Hindi')
# DataRow(ssn='851-94-2162', first_name='Rodi', last_name='Mulrenan', gender='Female', language='Catalan')
# DataRow(ssn='852-15-7707', first_name='Mario', last_name='Lelande', gender='Male', language='Nepali')
# DataRow(ssn='853-11-8953', first_name='Brice', last_name='Kyd', gender='Male', language='Dari')
# DataRow(ssn='853-47-3648', first_name='Olag', last_name='Belhome', gender='Male', language='Maltese')
# DataRow(ssn='854-68-7635', first_name='Eyde', last_name='McCunn', gender='Female', language='Moldovan')
# DataRow(ssn='854-71-2983', first_name='Rikki', last_name='Loveland', gender='Male', language='Dutch')
# DataRow(ssn='854-79-5334', first_name='Bevan', last_name='Kolczynski', gender='Male', language='Swahili')
# DataRow(ssn='856-18-3980', first_name='Neale', last_name='Sesser', gender='Male', language='Maltese')
# DataRow(ssn='856-27-9112', first_name='Virgilio', last_name='Kirrage', gender='Male', language='Pashto')
# DataRow(ssn='856-67-4080', first_name='Aggy', last_name='Cobley', gender='Female', language='Dhivehi')
# DataRow(ssn='857-37-5902', first_name='Jenni', last_name='Swinyard', gender='Female', language='Hindi')
# DataRow(ssn='858-03-7735', first_name='Allayne', last_name='Wardingley', gender='Male', language='Kazakh')
# DataRow(ssn='858-27-9190', first_name='Yuri', last_name='Sixsmith', gender='Male', language='Norwegian')
# DataRow(ssn='860-67-0256', first_name='Bendicty', last_name='Lindgren', gender='Male', language='Tajik')
# DataRow(ssn='860-89-2570', first_name='Otto', last_name='Burgwin', gender='Male', language='Finnish')
# DataRow(ssn='861-50-6716', first_name='Norina', last_name='Yerbury', gender='Female', language='Indonesian')
# DataRow(ssn='862-20-0653', first_name='Wilfrid', last_name='Kid', gender='Male', language='Swedish')
# DataRow(ssn='864-22-9364', first_name='Lyell', last_name='Petrollo', gender='Male', language='Latvian')
# DataRow(ssn='864-91-7489', first_name='Guthrie', last_name='Pilsworth', gender='Male', language='Bislama')
# DataRow(ssn='866-18-1440', first_name='Zachary', last_name='Branchflower', gender='Male', language='Papiamento')
# DataRow(ssn='866-53-0625', first_name='Francene', last_name='Ehlerding', gender='Female', language='Latvian')
# DataRow(ssn='867-11-6007', first_name='Kennett', last_name='Barhims', gender='Male', language='Malayalam')
# DataRow(ssn='867-13-6844', first_name='Clo', last_name='Skacel', gender='Female', language='Armenian')
# DataRow(ssn='867-88-2360', first_name='Gasper', last_name='Dohrmann', gender='Male', language='Dzongkha')
# DataRow(ssn='868-32-1805', first_name='Joanna', last_name='Raycroft', gender='Female', language='Bosnian')
# DataRow(ssn='870-12-6609', first_name='Jourdain', last_name='Comino', gender='Male', language='Guarana')
# DataRow(ssn='870-93-1121', first_name='Elisha', last_name='Wonham', gender='Male', language='Hebrew')
# DataRow(ssn='871-99-3191', first_name='Susann', last_name='Walrond', gender='Female', language='Amharic')
# DataRow(ssn='872-18-9267', first_name='Roddy', last_name='Honeywood', gender='Male', language='Maltese')
# DataRow(ssn='872-49-1288', first_name='Salaidh', last_name='Barthod', gender='Female', language='Finnish')
# DataRow(ssn='873-36-4733', first_name='Locke', last_name='Staries', gender='Male', language='Moldovan')
# DataRow(ssn='875-18-9454', first_name='Eustace', last_name='Kinnear', gender='Male', language='Hiri Motu')
# DataRow(ssn='875-75-0495', first_name='Frasquito', last_name='Lammas', gender='Male', language='Polish')
# DataRow(ssn='878-12-8265', first_name='Nance', last_name='Doble', gender='Female', language='Dhivehi')
# DataRow(ssn='880-22-4449', first_name='Zebadiah', last_name='Halliburton', gender='Male', language='Azeri')
# DataRow(ssn='881-19-5974', first_name='Lodovico', last_name='Gabby', gender='Male', language='Northern Sotho')
# DataRow(ssn='881-88-7308', first_name='Maitilde', last_name='Davis', gender='Female', language='Tsonga')
# DataRow(ssn='881-95-7180', first_name='Homerus', last_name='Lamar', gender='Male', language='Macedonian')
# DataRow(ssn='882-49-5290', first_name='Tamarah', last_name='Stenson', gender='Female', language='Armenian')
# DataRow(ssn='884-61-1852', first_name='Wylie', last_name='Glennon', gender='Male', language='Romanian')
# DataRow(ssn='887-41-7878', first_name='Bruce', last_name='Danieli', gender='Male', language='Tamil')
# DataRow(ssn='887-83-9002', first_name='Mab', last_name='Bozworth', gender='Female', language='Tok Pisin')
# DataRow(ssn='888-50-7008', first_name='Mayor', last_name='Gouley', gender='Male', language='Dzongkha')
# DataRow(ssn='888-53-7684', first_name='Lanny', last_name='Perfect', gender='Male', language='Estonian')
# DataRow(ssn='888-82-4928', first_name='Billye', last_name='Legat', gender='Female', language='Icelandic')
# DataRow(ssn='890-28-9962', first_name='Kingston', last_name='Spitell', gender='Male', language='Quechua')
# DataRow(ssn='893-12-0901', first_name='Dicky', last_name='Rohlfing', gender='Male', language='Oriya')
# DataRow(ssn='893-17-7318', first_name='Nani', last_name='Bonelle', gender='Female', language='Kyrgyz')
# DataRow(ssn='894-81-0628', first_name='Ree', last_name='Mordue', gender='Female', language='Tswana')
# DataRow(ssn='895-26-1658', first_name='Nance', last_name='Danzelman', gender='Female', language='Icelandic')
# DataRow(ssn='895-26-5515', first_name='Frank', last_name='Mason', gender='Male', language='Northern Sotho')
# DataRow(ssn='897-76-7070', first_name='Glynnis', last_name='Tillerton', gender='Female', language='Nepali')
# DataRow(ssn='898-03-3165', first_name='Sela', last_name='Vaillant', gender='Female', language='Arabic')
# DataRow(ssn='898-86-8860', first_name='Hershel', last_name='Few', gender='Male', language='Gagauz')
# DataRow(ssn='899-09-1766', first_name='Joe', last_name='Myderscough', gender='Male', language='Filipino')
# DataRow(ssn='899-39-7179', first_name='Rani', last_name='Naisbitt', gender='Female', language='Greek')
# DataRow(ssn='899-39-7378', first_name='Lindsay', last_name='Colledge', gender='Female', language='Croatian')
# DataRow(ssn='899-47-6116', first_name='Tiphanie', last_name='Kevlin', gender='Female', language='Tetum')

# %%
with CsvFileReader("cars.csv") as file:
    print(next(file))
    print(next(file))
    print(next(file))
    print(next(file))
    for row in file:
        print(row)
# Out:
# DataRow(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# DataRow(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# DataRow(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# DataRow(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# DataRow(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# DataRow(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# DataRow(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# DataRow(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')
# DataRow(car='Citroen DS-21 Pallas', mpg='0', cylinders='4', displacement='133.0', horsepower='115.0', weight='3090.', acceleration='17.5', model='70', origin='Europe')
# DataRow(car='Chevrolet Chevelle Concours (sw)', mpg='0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4142.', acceleration='11.5', model='70', origin='US')
# DataRow(car='Ford Torino (sw)', mpg='0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4034.', acceleration='11.0', model='70', origin='US')
# DataRow(car='Plymouth Satellite (sw)', mpg='0', cylinders='8', displacement='383.0', horsepower='175.0', weight='4166.', acceleration='10.5', model='70', origin='US')
# DataRow(car='AMC Rebel SST (sw)', mpg='0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3850.', acceleration='11.0', model='70', origin='US')
# DataRow(car='Dodge Challenger SE', mpg='15.0', cylinders='8', displacement='383.0', horsepower='170.0', weight='3563.', acceleration='10.0', model='70', origin='US')
# DataRow(car="Plymouth 'Cuda 340", mpg='14.0', cylinders='8', displacement='340.0', horsepower='160.0', weight='3609.', acceleration='8.0', model='70', origin='US')
# DataRow(car='Ford Mustang Boss 302', mpg='0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3353.', acceleration='8.0', model='70', origin='US')
# DataRow(car='Chevrolet Monte Carlo', mpg='15.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='3761.', acceleration='9.5', model='70', origin='US')
# DataRow(car='Buick Estate Wagon (sw)', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='3086.', acceleration='10.0', model='70', origin='US')
# DataRow(car='Toyota Corolla Mark ii', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2372.', acceleration='15.0', model='70', origin='Japan')
# DataRow(car='Plymouth Duster', mpg='22.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2833.', acceleration='15.5', model='70', origin='US')
# DataRow(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='199.0', horsepower='97.00', weight='2774.', acceleration='15.5', model='70', origin='US')
# DataRow(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='85.00', weight='2587.', acceleration='16.0', model='70', origin='US')
# DataRow(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='70', origin='Japan')
# DataRow(car='Volkswagen 1131 Deluxe Sedan', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1835.', acceleration='20.5', model='70', origin='Europe')
# DataRow(car='Peugeot 504', mpg='25.0', cylinders='4', displacement='110.0', horsepower='87.00', weight='2672.', acceleration='17.5', model='70', origin='Europe')
# DataRow(car='Audi 100 LS', mpg='24.0', cylinders='4', displacement='107.0', horsepower='90.00', weight='2430.', acceleration='14.5', model='70', origin='Europe')
# DataRow(car='Saab 99e', mpg='25.0', cylinders='4', displacement='104.0', horsepower='95.00', weight='2375.', acceleration='17.5', model='70', origin='Europe')
# DataRow(car='BMW 2002', mpg='26.0', cylinders='4', displacement='121.0', horsepower='113.0', weight='2234.', acceleration='12.5', model='70', origin='Europe')
# DataRow(car='AMC Gremlin', mpg='21.0', cylinders='6', displacement='199.0', horsepower='90.00', weight='2648.', acceleration='15.0', model='70', origin='US')
# DataRow(car='Ford F250', mpg='10.0', cylinders='8', displacement='360.0', horsepower='215.0', weight='4615.', acceleration='14.0', model='70', origin='US')
# DataRow(car='Chevy C20', mpg='10.0', cylinders='8', displacement='307.0', horsepower='200.0', weight='4376.', acceleration='15.0', model='70', origin='US')
# DataRow(car='Dodge D200', mpg='11.0', cylinders='8', displacement='318.0', horsepower='210.0', weight='4382.', acceleration='13.5', model='70', origin='US')
# DataRow(car='Hi 1200D', mpg='9.0', cylinders='8', displacement='304.0', horsepower='193.0', weight='4732.', acceleration='18.5', model='70', origin='US')
# DataRow(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='71', origin='Japan')
# DataRow(car='Chevrolet Vega 2300', mpg='28.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2264.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Toyota Corolla', mpg='25.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2228.', acceleration='14.0', model='71', origin='Japan')
# DataRow(car='Ford Pinto', mpg='25.0', cylinders='4', displacement='98.00', horsepower='0', weight='2046.', acceleration='19.0', model='71', origin='US')
# DataRow(car='Volkswagen Super Beetle 117', mpg='0', cylinders='4', displacement='97.00', horsepower='48.00', weight='1978.', acceleration='20.0', model='71', origin='Europe')
# DataRow(car='AMC Gremlin', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2634.', acceleration='13.0', model='71', origin='US')
# DataRow(car='Plymouth Satellite Custom', mpg='16.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3439.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Chevrolet Chevelle Malibu', mpg='17.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3329.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Ford Torino 500', mpg='19.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3302.', acceleration='15.5', model='71', origin='US')
# DataRow(car='AMC Matador', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='3288.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4209.', acceleration='12.0', model='71', origin='US')
# DataRow(car='Pontiac Catalina Brougham', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4464.', acceleration='11.5', model='71', origin='US')
# DataRow(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4154.', acceleration='13.5', model='71', origin='US')
# DataRow(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4096.', acceleration='13.0', model='71', origin='US')
# DataRow(car='Dodge Monaco (sw)', mpg='12.0', cylinders='8', displacement='383.0', horsepower='180.0', weight='4955.', acceleration='11.5', model='71', origin='US')
# DataRow(car='Ford Country Squire (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4746.', acceleration='12.0', model='71', origin='US')
# DataRow(car='Pontiac Safari (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='5140.', acceleration='12.0', model='71', origin='US')
# DataRow(car='AMC Hornet Sportabout (sw)', mpg='18.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='2962.', acceleration='13.5', model='71', origin='US')
# DataRow(car='Chevrolet Vega (sw)', mpg='22.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2408.', acceleration='19.0', model='71', origin='US')
# DataRow(car='Pontiac Firebird', mpg='19.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3282.', acceleration='15.0', model='71', origin='US')
# DataRow(car='Ford Mustang', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3139.', acceleration='14.5', model='71', origin='US')
# DataRow(car='Mercury Capri 2000', mpg='23.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2220.', acceleration='14.0', model='71', origin='US')
# DataRow(car='Opel 1900', mpg='28.0', cylinders='4', displacement='116.0', horsepower='90.00', weight='2123.', acceleration='14.0', model='71', origin='Europe')
# DataRow(car='Peugeot 304', mpg='30.0', cylinders='4', displacement='79.00', horsepower='70.00', weight='2074.', acceleration='19.5', model='71', origin='Europe')
# DataRow(car='Fiat 124B', mpg='30.0', cylinders='4', displacement='88.00', horsepower='76.00', weight='2065.', acceleration='14.5', model='71', origin='Europe')
# DataRow(car='Toyota Corolla 1200', mpg='31.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1773.', acceleration='19.0', model='71', origin='Japan')
# DataRow(car='Datsun 1200', mpg='35.0', cylinders='4', displacement='72.00', horsepower='69.00', weight='1613.', acceleration='18.0', model='71', origin='Japan')
# DataRow(car='Volkswagen Model 111', mpg='27.0', cylinders='4', displacement='97.00', horsepower='60.00', weight='1834.', acceleration='19.0', model='71', origin='Europe')
# DataRow(car='Plymouth Cricket', mpg='26.0', cylinders='4', displacement='91.00', horsepower='70.00', weight='1955.', acceleration='20.5', model='71', origin='US')
# DataRow(car='Toyota Corolla Hardtop', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2278.', acceleration='15.5', model='72', origin='Japan')
# DataRow(car='Dodge Colt Hardtop', mpg='25.0', cylinders='4', displacement='97.50', horsepower='80.00', weight='2126.', acceleration='17.0', model='72', origin='US')
# DataRow(car='Volkswagen Type 3', mpg='23.0', cylinders='4', displacement='97.00', horsepower='54.00', weight='2254.', acceleration='23.5', model='72', origin='Europe')
# DataRow(car='Chevrolet Vega', mpg='20.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2408.', acceleration='19.5', model='72', origin='US')
# DataRow(car='Ford Pinto Runabout', mpg='21.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2226.', acceleration='16.5', model='72', origin='US')
# DataRow(car='Chevrolet Impala', mpg='13.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4274.', acceleration='12.0', model='72', origin='US')
# DataRow(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4385.', acceleration='12.0', model='72', origin='US')
# DataRow(car='Plymouth Fury III', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4135.', acceleration='13.5', model='72', origin='US')
# DataRow(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4129.', acceleration='13.0', model='72', origin='US')
# DataRow(car='AMC Ambassador SST', mpg='17.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='72', origin='US')
# DataRow(car='Mercury Marquis', mpg='11.0', cylinders='8', displacement='429.0', horsepower='208.0', weight='4633.', acceleration='11.0', model='72', origin='US')
# DataRow(car='Buick LeSabre Custom', mpg='13.0', cylinders='8', displacement='350.0', horsepower='155.0', weight='4502.', acceleration='13.5', model='72', origin='US')
# DataRow(car='Oldsmobile Delta 88 Royale', mpg='12.0', cylinders='8', displacement='350.0', horsepower='160.0', weight='4456.', acceleration='13.5', model='72', origin='US')
# DataRow(car='Chrysler Newport Royal', mpg='13.0', cylinders='8', displacement='400.0', horsepower='190.0', weight='4422.', acceleration='12.5', model='72', origin='US')
# DataRow(car='Mazda RX2 Coupe', mpg='19.0', cylinders='3', displacement='70.00', horsepower='97.00', weight='2330.', acceleration='13.5', model='72', origin='Japan')
# DataRow(car='AMC Matador (sw)', mpg='15.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3892.', acceleration='12.5', model='72', origin='US')
# DataRow(car='Chevrolet Chevelle Concours (sw)', mpg='13.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='4098.', acceleration='14.0', model='72', origin='US')
# DataRow(car='Ford Gran Torino (sw)', mpg='13.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4294.', acceleration='16.0', model='72', origin='US')
# DataRow(car='Plymouth Satellite Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4077.', acceleration='14.0', model='72', origin='US')
# DataRow(car='Volvo 145e (sw)', mpg='18.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2933.', acceleration='14.5', model='72', origin='Europe')
# DataRow(car='Volkswagen 411 (sw)', mpg='22.0', cylinders='4', displacement='121.0', horsepower='76.00', weight='2511.', acceleration='18.0', model='72', origin='Europe')
# DataRow(car='Peugeot 504 (sw)', mpg='21.0', cylinders='4', displacement='120.0', horsepower='87.00', weight='2979.', acceleration='19.5', model='72', origin='Europe')
# DataRow(car='Renault 12 (sw)', mpg='26.0', cylinders='4', displacement='96.00', horsepower='69.00', weight='2189.', acceleration='18.0', model='72', origin='Europe')
# DataRow(car='Ford Pinto (sw)', mpg='22.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2395.', acceleration='16.0', model='72', origin='US')
# DataRow(car='Datsun 510 (sw)', mpg='28.0', cylinders='4', displacement='97.00', horsepower='92.00', weight='2288.', acceleration='17.0', model='72', origin='Japan')
# DataRow(car='Toyota Corolla Mark II (sw)', mpg='23.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2506.', acceleration='14.5', model='72', origin='Japan')
# DataRow(car='Dodge Colt (sw)', mpg='28.0', cylinders='4', displacement='98.00', horsepower='80.00', weight='2164.', acceleration='15.0', model='72', origin='US')
# DataRow(car='Toyota Corolla 1600 (sw)', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2100.', acceleration='16.5', model='72', origin='Japan')
# DataRow(car='Buick Century 350', mpg='13.0', cylinders='8', displacement='350.0', horsepower='175.0', weight='4100.', acceleration='13.0', model='73', origin='US')
# DataRow(car='AMC Matador', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='73', origin='US')
# DataRow(car='Chevrolet Malibu', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='3988.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Ford Gran Torino', mpg='14.0', cylinders='8', displacement='302.0', horsepower='137.0', weight='4042.', acceleration='14.5', model='73', origin='US')
# DataRow(car='Dodge Coronet Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3777.', acceleration='12.5', model='73', origin='US')
# DataRow(car='Mercury Marquis Brougham', mpg='12.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4952.', acceleration='11.5', model='73', origin='US')
# DataRow(car='Chevrolet Caprice Classic', mpg='13.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4464.', acceleration='12.0', model='73', origin='US')
# DataRow(car='Ford LTD', mpg='13.0', cylinders='8', displacement='351.0', horsepower='158.0', weight='4363.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Plymouth Fury Gran Sedan', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4237.', acceleration='14.5', model='73', origin='US')
# DataRow(car='Chrysler New Yorker Brougham', mpg='13.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4735.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Buick Electra 225 Custom', mpg='12.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4951.', acceleration='11.0', model='73', origin='US')
# DataRow(car='AMC Ambassador Brougham', mpg='13.0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3821.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Plymouth Valiant', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3121.', acceleration='16.5', model='73', origin='US')
# DataRow(car='Chevrolet Nova Custom', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3278.', acceleration='18.0', model='73', origin='US')
# DataRow(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2945.', acceleration='16.0', model='73', origin='US')
# DataRow(car='Ford Maverick', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3021.', acceleration='16.5', model='73', origin='US')
# DataRow(car='Plymouth Duster', mpg='23.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2904.', acceleration='16.0', model='73', origin='US')
# DataRow(car='Volkswagen Super Beetle', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1950.', acceleration='21.0', model='73', origin='Europe')
# DataRow(car='Chevrolet Impala', mpg='11.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4997.', acceleration='14.0', model='73', origin='US')
# DataRow(car='Ford Country', mpg='12.0', cylinders='8', displacement='400.0', horsepower='167.0', weight='4906.', acceleration='12.5', model='73', origin='US')
# DataRow(car='Plymouth Custom Suburb', mpg='13.0', cylinders='8', displacement='360.0', horsepower='170.0', weight='4654.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Oldsmobile Vista Cruiser', mpg='12.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='4499.', acceleration='12.5', model='73', origin='US')
# DataRow(car='AMC Gremlin', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2789.', acceleration='15.0', model='73', origin='US')
# DataRow(car='Toyota Camry', mpg='20.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2279.', acceleration='19.0', model='73', origin='Japan')
# DataRow(car='Chevrolet Vega', mpg='21.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2401.', acceleration='19.5', model='73', origin='US')
# DataRow(car='Datsun 610', mpg='22.0', cylinders='4', displacement='108.0', horsepower='94.00', weight='2379.', acceleration='16.5', model='73', origin='Japan')
# DataRow(car='Mazda RX3', mpg='18.0', cylinders='3', displacement='70.00', horsepower='90.00', weight='2124.', acceleration='13.5', model='73', origin='Japan')
# DataRow(car='Ford Pinto', mpg='19.0', cylinders='4', displacement='122.0', horsepower='85.00', weight='2310.', acceleration='18.5', model='73', origin='US')
# DataRow(car='Mercury Capri v6', mpg='21.0', cylinders='6', displacement='155.0', horsepower='107.0', weight='2472.', acceleration='14.0', model='73', origin='US')
# DataRow(car='Fiat 124 Sport Coupe', mpg='26.0', cylinders='4', displacement='98.00', horsepower='90.00', weight='2265.', acceleration='15.5', model='73', origin='Europe')
# DataRow(car='Chevrolet Monte Carlo S', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4082.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Pontiac Grand Prix', mpg='16.0', cylinders='8', displacement='400.0', horsepower='230.0', weight='4278.', acceleration='9.50', model='73', origin='US')
# DataRow(car='Fiat 128', mpg='29.0', cylinders='4', displacement='68.00', horsepower='49.00', weight='1867.', acceleration='19.5', model='73', origin='Europe')
# DataRow(car='Opel Manta', mpg='24.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2158.', acceleration='15.5', model='73', origin='Europe')
# DataRow(car='Audi 100LS', mpg='20.0', cylinders='4', displacement='114.0', horsepower='91.00', weight='2582.', acceleration='14.0', model='73', origin='Europe')
# DataRow(car='Volvo 144ea', mpg='19.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2868.', acceleration='15.5', model='73', origin='Europe')
# DataRow(car='Dodge Dart Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3399.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Saab 99le', mpg='24.0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2660.', acceleration='14.0', model='73', origin='Europe')
# DataRow(car='Toyota Mark II', mpg='20.0', cylinders='6', displacement='156.0', horsepower='122.0', weight='2807.', acceleration='13.5', model='73', origin='Japan')
# DataRow(car='Oldsmobile Omega', mpg='11.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='3664.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Plymouth Duster', mpg='20.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='3102.', acceleration='16.5', model='74', origin='US')
# DataRow(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='0', weight='2875.', acceleration='17.0', model='74', origin='US')
# DataRow(car='AMC Hornet', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2901.', acceleration='16.0', model='74', origin='US')
# DataRow(car='Chevrolet Nova', mpg='15.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3336.', acceleration='17.0', model='74', origin='US')
# DataRow(car='Datsun B210', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1950.', acceleration='19.0', model='74', origin='Japan')
# DataRow(car='Ford Pinto', mpg='26.0', cylinders='4', displacement='122.0', horsepower='80.00', weight='2451.', acceleration='16.5', model='74', origin='US')
# DataRow(car='Toyota Corolla 1200', mpg='32.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1836.', acceleration='21.0', model='74', origin='Japan')
# DataRow(car='Chevrolet Vega', mpg='25.0', cylinders='4', displacement='140.0', horsepower='75.00', weight='2542.', acceleration='17.0', model='74', origin='US')
# DataRow(car='Chevrolet Chevelle Malibu Classic', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3781.', acceleration='17.0', model='74', origin='US')
# DataRow(car='AMC Matador', mpg='16.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3632.', acceleration='18.0', model='74', origin='US')
# DataRow(car='Plymouth Satellite Sebring', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3613.', acceleration='16.5', model='74', origin='US')
# DataRow(car='Ford Gran Torino', mpg='16.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4141.', acceleration='14.0', model='74', origin='US')
# DataRow(car='Buick Century Luxus (sw)', mpg='13.0', cylinders='8', displacement='350.0', horsepower='150.0', weight='4699.', acceleration='14.5', model='74', origin='US')
# DataRow(car='Dodge Coronet Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4457.', acceleration='13.5', model='74', origin='US')
# DataRow(car='Ford Gran Torino (sw)', mpg='14.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4638.', acceleration='16.0', model='74', origin='US')
# DataRow(car='AMC Matador (sw)', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='4257.', acceleration='15.5', model='74', origin='US')
# DataRow(car='Audi Fox', mpg='29.0', cylinders='4', displacement='98.00', horsepower='83.00', weight='2219.', acceleration='16.5', model='74', origin='Europe')
# DataRow(car='Volkswagen Dasher', mpg='26.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1963.', acceleration='15.5', model='74', origin='Europe')
# DataRow(car='Opel Manta', mpg='26.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='2300.', acceleration='14.5', model='74', origin='Europe')
# DataRow(car='Toyota Corolla', mpg='31.0', cylinders='4', displacement='76.00', horsepower='52.00', weight='1649.', acceleration='16.5', model='74', origin='Japan')
# DataRow(car='Datsun 710', mpg='32.0', cylinders='4', displacement='83.00', horsepower='61.00', weight='2003.', acceleration='19.0', model='74', origin='Japan')
# DataRow(car='Dodge Colt', mpg='28.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2125.', acceleration='14.5', model='74', origin='US')
# DataRow(car='Fiat 128', mpg='24.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2108.', acceleration='15.5', model='74', origin='Europe')
# DataRow(car='Fiat 124 TC', mpg='26.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2246.', acceleration='14.0', model='74', origin='Europe')
# DataRow(car='Honda Civic', mpg='24.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2489.', acceleration='15.0', model='74', origin='Japan')
# DataRow(car='Subaru', mpg='26.0', cylinders='4', displacement='108.0', horsepower='93.00', weight='2391.', acceleration='15.5', model='74', origin='Japan')
# DataRow(car='Fiat x1.9', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='2000.', acceleration='16.0', model='74', origin='Europe')
# DataRow(car='Plymouth Valiant Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3264.', acceleration='16.0', model='75', origin='US')
# DataRow(car='Chevrolet Nova', mpg='18.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3459.', acceleration='16.0', model='75', origin='US')
# DataRow(car='Mercury Monarch', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3432.', acceleration='21.0', model='75', origin='US')
# DataRow(car='Ford Maverick', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3158.', acceleration='19.5', model='75', origin='US')
# DataRow(car='Pontiac Catalina', mpg='16.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4668.', acceleration='11.5', model='75', origin='US')
# DataRow(car='Chevrolet Bel Air', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4440.', acceleration='14.0', model='75', origin='US')
# DataRow(car='Plymouth Grand Fury', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4498.', acceleration='14.5', model='75', origin='US')
# DataRow(car='Ford LTD', mpg='14.0', cylinders='8', displacement='351.0', horsepower='148.0', weight='4657.', acceleration='13.5', model='75', origin='US')
# DataRow(car='Buick Century', mpg='17.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3907.', acceleration='21.0', model='75', origin='US')
# DataRow(car='Chevrolete Chevelle Malibu', mpg='16.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3897.', acceleration='18.5', model='75', origin='US')
# DataRow(car='AMC Matador', mpg='15.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3730.', acceleration='19.0', model='75', origin='US')
# DataRow(car='Plymouth Fury', mpg='18.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3785.', acceleration='19.0', model='75', origin='US')
# DataRow(car='Buick Skyhawk', mpg='21.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3039.', acceleration='15.0', model='75', origin='US')
# DataRow(car='Chevrolet Monza 2+2', mpg='20.0', cylinders='8', displacement='262.0', horsepower='110.0', weight='3221.', acceleration='13.5', model='75', origin='US')
# DataRow(car='Ford Mustang II', mpg='13.0', cylinders='8', displacement='302.0', horsepower='129.0', weight='3169.', acceleration='12.0', model='75', origin='US')
# DataRow(car='Toyota Corolla', mpg='29.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2171.', acceleration='16.0', model='75', origin='Japan')
# DataRow(car='Ford Pinto', mpg='23.0', cylinders='4', displacement='140.0', horsepower='83.00', weight='2639.', acceleration='17.0', model='75', origin='US')
# DataRow(car='AMC Gremlin', mpg='20.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2914.', acceleration='16.0', model='75', origin='US')
# DataRow(car='Pontiac Astro', mpg='23.0', cylinders='4', displacement='140.0', horsepower='78.00', weight='2592.', acceleration='18.5', model='75', origin='US')
# DataRow(car='Toyota Corolla', mpg='24.0', cylinders='4', displacement='134.0', horsepower='96.00', weight='2702.', acceleration='13.5', model='75', origin='Japan')
# DataRow(car='Volkswagen Dasher', mpg='25.0', cylinders='4', displacement='90.00', horsepower='71.00', weight='2223.', acceleration='16.5', model='75', origin='Europe')
# DataRow(car='Datsun 710', mpg='24.0', cylinders='4', displacement='119.0', horsepower='97.00', weight='2545.', acceleration='17.0', model='75', origin='Japan')
# DataRow(car='Ford Pinto', mpg='18.0', cylinders='6', displacement='171.0', horsepower='97.00', weight='2984.', acceleration='14.5', model='75', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.0', model='75', origin='Europe')
# DataRow(car='AMC Pacer', mpg='19.0', cylinders='6', displacement='232.0', horsepower='90.00', weight='3211.', acceleration='17.0', model='75', origin='US')
# DataRow(car='Audi 100LS', mpg='23.0', cylinders='4', displacement='115.0', horsepower='95.00', weight='2694.', acceleration='15.0', model='75', origin='Europe')
# DataRow(car='Peugeot 504', mpg='23.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2957.', acceleration='17.0', model='75', origin='Europe')
# DataRow(car='Volvo 244DL', mpg='22.0', cylinders='4', displacement='121.0', horsepower='98.00', weight='2945.', acceleration='14.5', model='75', origin='Europe')
# DataRow(car='Saab 99LE', mpg='25.0', cylinders='4', displacement='121.0', horsepower='115.0', weight='2671.', acceleration='13.5', model='75', origin='Europe')
# DataRow(car='Honda Civic CVCC', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.5', model='75', origin='Japan')
# DataRow(car='Fiat 131', mpg='28.0', cylinders='4', displacement='107.0', horsepower='86.00', weight='2464.', acceleration='15.5', model='76', origin='Europe')
# DataRow(car='Opel 1900', mpg='25.0', cylinders='4', displacement='116.0', horsepower='81.00', weight='2220.', acceleration='16.9', model='76', origin='Europe')
# DataRow(car='Capri ii', mpg='25.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2572.', acceleration='14.9', model='76', origin='US')
# DataRow(car='Dodge Colt', mpg='26.0', cylinders='4', displacement='98.00', horsepower='79.00', weight='2255.', acceleration='17.7', model='76', origin='US')
# DataRow(car='Renault 12tl', mpg='27.0', cylinders='4', displacement='101.0', horsepower='83.00', weight='2202.', acceleration='15.3', model='76', origin='Europe')
# DataRow(car='Chevrolet Chevelle Malibu Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='140.0', weight='4215.', acceleration='13.0', model='76', origin='US')
# DataRow(car='Dodge Coronet Brougham', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4190.', acceleration='13.0', model='76', origin='US')
# DataRow(car='AMC Matador', mpg='15.5', cylinders='8', displacement='304.0', horsepower='120.0', weight='3962.', acceleration='13.9', model='76', origin='US')
# DataRow(car='Ford Gran Torino', mpg='14.5', cylinders='8', displacement='351.0', horsepower='152.0', weight='4215.', acceleration='12.8', model='76', origin='US')
# DataRow(car='Plymouth Valiant', mpg='22.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3233.', acceleration='15.4', model='76', origin='US')
# DataRow(car='Chevrolet Nova', mpg='22.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3353.', acceleration='14.5', model='76', origin='US')
# DataRow(car='Ford Maverick', mpg='24.0', cylinders='6', displacement='200.0', horsepower='81.00', weight='3012.', acceleration='17.6', model='76', origin='US')
# DataRow(car='AMC Hornet', mpg='22.5', cylinders='6', displacement='232.0', horsepower='90.00', weight='3085.', acceleration='17.6', model='76', origin='US')
# DataRow(car='Chevrolet Chevette', mpg='29.0', cylinders='4', displacement='85.00', horsepower='52.00', weight='2035.', acceleration='22.2', model='76', origin='US')
# DataRow(car='Chevrolet Woody', mpg='24.5', cylinders='4', displacement='98.00', horsepower='60.00', weight='2164.', acceleration='22.1', model='76', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.2', model='76', origin='Europe')
# DataRow(car='Honda Civic', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.4', model='76', origin='Japan')
# DataRow(car='Dodge Aspen SE', mpg='20.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3651.', acceleration='17.7', model='76', origin='US')
# DataRow(car='Ford Grenada ghia', mpg='18.0', cylinders='6', displacement='250.0', horsepower='78.00', weight='3574.', acceleration='21.0', model='76', origin='US')
# DataRow(car='Pontiac Ventura SJ', mpg='18.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3645.', acceleration='16.2', model='76', origin='US')
# DataRow(car='AMC Pacer d/l', mpg='17.5', cylinders='6', displacement='258.0', horsepower='95.00', weight='3193.', acceleration='17.8', model='76', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='29.5', cylinders='4', displacement='97.00', horsepower='71.00', weight='1825.', acceleration='12.2', model='76', origin='Europe')
# DataRow(car='Datsun B-210', mpg='32.0', cylinders='4', displacement='85.00', horsepower='70.00', weight='1990.', acceleration='17.0', model='76', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='28.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2155.', acceleration='16.4', model='76', origin='Japan')
# DataRow(car='Ford Pinto', mpg='26.5', cylinders='4', displacement='140.0', horsepower='72.00', weight='2565.', acceleration='13.6', model='76', origin='US')
# DataRow(car='Volvo 245', mpg='20.0', cylinders='4', displacement='130.0', horsepower='102.0', weight='3150.', acceleration='15.7', model='76', origin='Europe')
# DataRow(car='Plymouth Volare Premier v8', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3940.', acceleration='13.2', model='76', origin='US')
# DataRow(car='Peugeot 504', mpg='19.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='3270.', acceleration='21.9', model='76', origin='Europe')
# DataRow(car='Toyota Mark II', mpg='19.0', cylinders='6', displacement='156.0', horsepower='108.0', weight='2930.', acceleration='15.5', model='76', origin='Japan')
# DataRow(car='Mercedes-Benz 280s', mpg='16.5', cylinders='6', displacement='168.0', horsepower='120.0', weight='3820.', acceleration='16.7', model='76', origin='Europe')
# DataRow(car='Cadillac Seville', mpg='16.5', cylinders='8', displacement='350.0', horsepower='180.0', weight='4380.', acceleration='12.1', model='76', origin='US')
# DataRow(car='Chevrolet C10', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4055.', acceleration='12.0', model='76', origin='US')
# DataRow(car='Ford F108', mpg='13.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='3870.', acceleration='15.0', model='76', origin='US')
# DataRow(car='Dodge D100', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3755.', acceleration='14.0', model='76', origin='US')
# DataRow(car='Honda Accord CVCC', mpg='31.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2045.', acceleration='18.5', model='77', origin='Japan')
# DataRow(car='Buick Opel Isuzu Deluxe', mpg='30.0', cylinders='4', displacement='111.0', horsepower='80.00', weight='2155.', acceleration='14.8', model='77', origin='US')
# DataRow(car='Renault 5 GTL', mpg='36.0', cylinders='4', displacement='79.00', horsepower='58.00', weight='1825.', acceleration='18.6', model='77', origin='Europe')
# DataRow(car='Plymouth Arrow GS', mpg='25.5', cylinders='4', displacement='122.0', horsepower='96.00', weight='2300.', acceleration='15.5', model='77', origin='US')
# DataRow(car='Datsun F-10 Hatchback', mpg='33.5', cylinders='4', displacement='85.00', horsepower='70.00', weight='1945.', acceleration='16.8', model='77', origin='Japan')
# DataRow(car='Chevrolet Caprice Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='145.0', weight='3880.', acceleration='12.5', model='77', origin='US')
# DataRow(car='Oldsmobile Cutlass Supreme', mpg='17.0', cylinders='8', displacement='260.0', horsepower='110.0', weight='4060.', acceleration='19.0', model='77', origin='US')
# DataRow(car='Dodge Monaco Brougham', mpg='15.5', cylinders='8', displacement='318.0', horsepower='145.0', weight='4140.', acceleration='13.7', model='77', origin='US')
# DataRow(car='Mercury Cougar Brougham', mpg='15.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='4295.', acceleration='14.9', model='77', origin='US')
# DataRow(car='Chevrolet Concours', mpg='17.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3520.', acceleration='16.4', model='77', origin='US')
# DataRow(car='Buick Skylark', mpg='20.5', cylinders='6', displacement='231.0', horsepower='105.0', weight='3425.', acceleration='16.9', model='77', origin='US')
# DataRow(car='Plymouth Volare Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3630.', acceleration='17.7', model='77', origin='US')
# DataRow(car='Ford Grenada', mpg='18.5', cylinders='6', displacement='250.0', horsepower='98.00', weight='3525.', acceleration='19.0', model='77', origin='US')
# DataRow(car='Pontiac Grand Prix LJ', mpg='16.0', cylinders='8', displacement='400.0', horsepower='180.0', weight='4220.', acceleration='11.1', model='77', origin='US')
# DataRow(car='Chevrolet Monte Carlo Landau', mpg='15.5', cylinders='8', displacement='350.0', horsepower='170.0', weight='4165.', acceleration='11.4', model='77', origin='US')
# DataRow(car='Chrysler Cordoba', mpg='15.5', cylinders='8', displacement='400.0', horsepower='190.0', weight='4325.', acceleration='12.2', model='77', origin='US')
# DataRow(car='Ford Thunderbird', mpg='16.0', cylinders='8', displacement='351.0', horsepower='149.0', weight='4335.', acceleration='14.5', model='77', origin='US')
# DataRow(car='Volkswagen Rabbit Custom', mpg='29.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='1940.', acceleration='14.5', model='77', origin='Europe')
# DataRow(car='Pontiac Sunbird Coupe', mpg='24.5', cylinders='4', displacement='151.0', horsepower='88.00', weight='2740.', acceleration='16.0', model='77', origin='US')
# DataRow(car='Toyota Corolla Liftback', mpg='26.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2265.', acceleration='18.2', model='77', origin='Japan')
# DataRow(car='Ford Mustang II 2+2', mpg='25.5', cylinders='4', displacement='140.0', horsepower='89.00', weight='2755.', acceleration='15.8', model='77', origin='US')
# DataRow(car='Chevrolet Chevette', mpg='30.5', cylinders='4', displacement='98.00', horsepower='63.00', weight='2051.', acceleration='17.0', model='77', origin='US')
# DataRow(car='Dodge Colt m/m', mpg='33.5', cylinders='4', displacement='98.00', horsepower='83.00', weight='2075.', acceleration='15.9', model='77', origin='US')
# DataRow(car='Subaru DL', mpg='30.0', cylinders='4', displacement='97.00', horsepower='67.00', weight='1985.', acceleration='16.4', model='77', origin='Japan')
# DataRow(car='Volkswagen Dasher', mpg='30.5', cylinders='4', displacement='97.00', horsepower='78.00', weight='2190.', acceleration='14.1', model='77', origin='Europe')
# DataRow(car='Datsun 810', mpg='22.0', cylinders='6', displacement='146.0', horsepower='97.00', weight='2815.', acceleration='14.5', model='77', origin='Japan')
# DataRow(car='BMW 320i', mpg='21.5', cylinders='4', displacement='121.0', horsepower='110.0', weight='2600.', acceleration='12.8', model='77', origin='Europe')
# DataRow(car='Mazda RX-4', mpg='21.5', cylinders='3', displacement='80.00', horsepower='110.0', weight='2720.', acceleration='13.5', model='77', origin='Japan')
# DataRow(car='Volkswagen Rabbit Custom Diesel', mpg='43.1', cylinders='4', displacement='90.00', horsepower='48.00', weight='1985.', acceleration='21.5', model='78', origin='Europe')
# DataRow(car='Ford Fiesta', mpg='36.1', cylinders='4', displacement='98.00', horsepower='66.00', weight='1800.', acceleration='14.4', model='78', origin='US')
# DataRow(car='Mazda GLC Deluxe', mpg='32.8', cylinders='4', displacement='78.00', horsepower='52.00', weight='1985.', acceleration='19.4', model='78', origin='Japan')
# DataRow(car='Datsun B210 GX', mpg='39.4', cylinders='4', displacement='85.00', horsepower='70.00', weight='2070.', acceleration='18.6', model='78', origin='Japan')
# DataRow(car='Honda Civic CVCC', mpg='36.1', cylinders='4', displacement='91.00', horsepower='60.00', weight='1800.', acceleration='16.4', model='78', origin='Japan')
# DataRow(car='Oldsmobile Cutlass Salon Brougham', mpg='19.9', cylinders='8', displacement='260.0', horsepower='110.0', weight='3365.', acceleration='15.5', model='78', origin='US')
# DataRow(car='Dodge Diplomat', mpg='19.4', cylinders='8', displacement='318.0', horsepower='140.0', weight='3735.', acceleration='13.2', model='78', origin='US')
# DataRow(car='Mercury Monarch ghia', mpg='20.2', cylinders='8', displacement='302.0', horsepower='139.0', weight='3570.', acceleration='12.8', model='78', origin='US')
# DataRow(car='Pontiac Phoenix LJ', mpg='19.2', cylinders='6', displacement='231.0', horsepower='105.0', weight='3535.', acceleration='19.2', model='78', origin='US')
# DataRow(car='Chevrolet Malibu', mpg='20.5', cylinders='6', displacement='200.0', horsepower='95.00', weight='3155.', acceleration='18.2', model='78', origin='US')
# DataRow(car='Ford Fairmont (auto)', mpg='20.2', cylinders='6', displacement='200.0', horsepower='85.00', weight='2965.', acceleration='15.8', model='78', origin='US')
# DataRow(car='Ford Fairmont (man)', mpg='25.1', cylinders='4', displacement='140.0', horsepower='88.00', weight='2720.', acceleration='15.4', model='78', origin='US')
# DataRow(car='Plymouth Volare', mpg='20.5', cylinders='6', displacement='225.0', horsepower='100.0', weight='3430.', acceleration='17.2', model='78', origin='US')
# DataRow(car='AMC Concord', mpg='19.4', cylinders='6', displacement='232.0', horsepower='90.00', weight='3210.', acceleration='17.2', model='78', origin='US')
# DataRow(car='Buick Century Special', mpg='20.6', cylinders='6', displacement='231.0', horsepower='105.0', weight='3380.', acceleration='15.8', model='78', origin='US')
# DataRow(car='Mercury Zephyr', mpg='20.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='3070.', acceleration='16.7', model='78', origin='US')
# DataRow(car='Dodge Aspen', mpg='18.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3620.', acceleration='18.7', model='78', origin='US')
# DataRow(car='AMC Concord d/l', mpg='18.1', cylinders='6', displacement='258.0', horsepower='120.0', weight='3410.', acceleration='15.1', model='78', origin='US')
# DataRow(car='Chevrolet Monte Carlo Landau', mpg='19.2', cylinders='8', displacement='305.0', horsepower='145.0', weight='3425.', acceleration='13.2', model='78', origin='US')
# DataRow(car='Buick Regal Sport Coupe (turbo)', mpg='17.7', cylinders='6', displacement='231.0', horsepower='165.0', weight='3445.', acceleration='13.4', model='78', origin='US')
# DataRow(car='Ford Futura', mpg='18.1', cylinders='8', displacement='302.0', horsepower='139.0', weight='3205.', acceleration='11.2', model='78', origin='US')
# DataRow(car='Dodge Magnum XE', mpg='17.5', cylinders='8', displacement='318.0', horsepower='140.0', weight='4080.', acceleration='13.7', model='78', origin='US')
# DataRow(car='Chevrolet Chevette', mpg='30.0', cylinders='4', displacement='98.00', horsepower='68.00', weight='2155.', acceleration='16.5', model='78', origin='US')
# DataRow(car='Toyota Corolla', mpg='27.5', cylinders='4', displacement='134.0', horsepower='95.00', weight='2560.', acceleration='14.2', model='78', origin='Japan')
# DataRow(car='Datsun 510', mpg='27.2', cylinders='4', displacement='119.0', horsepower='97.00', weight='2300.', acceleration='14.7', model='78', origin='Japan')
# DataRow(car='Dodge Omni', mpg='30.9', cylinders='4', displacement='105.0', horsepower='75.00', weight='2230.', acceleration='14.5', model='78', origin='US')
# DataRow(car='Toyota Celica GT Liftback', mpg='21.1', cylinders='4', displacement='134.0', horsepower='95.00', weight='2515.', acceleration='14.8', model='78', origin='Japan')
# DataRow(car='Plymouth Sapporo', mpg='23.2', cylinders='4', displacement='156.0', horsepower='105.0', weight='2745.', acceleration='16.7', model='78', origin='US')
# DataRow(car='Oldsmobile Starfire SX', mpg='23.8', cylinders='4', displacement='151.0', horsepower='85.00', weight='2855.', acceleration='17.6', model='78', origin='US')
# DataRow(car='Datsun 200-SX', mpg='23.9', cylinders='4', displacement='119.0', horsepower='97.00', weight='2405.', acceleration='14.9', model='78', origin='Japan')
# DataRow(car='Audi 5000', mpg='20.3', cylinders='5', displacement='131.0', horsepower='103.0', weight='2830.', acceleration='15.9', model='78', origin='Europe')
# DataRow(car='Volvo 264gl', mpg='17.0', cylinders='6', displacement='163.0', horsepower='125.0', weight='3140.', acceleration='13.6', model='78', origin='Europe')
# DataRow(car='Saab 99gle', mpg='21.6', cylinders='4', displacement='121.0', horsepower='115.0', weight='2795.', acceleration='15.7', model='78', origin='Europe')
# DataRow(car='Peugeot 604sl', mpg='16.2', cylinders='6', displacement='163.0', horsepower='133.0', weight='3410.', acceleration='15.8', model='78', origin='Europe')
# DataRow(car='Volkswagen Scirocco', mpg='31.5', cylinders='4', displacement='89.00', horsepower='71.00', weight='1990.', acceleration='14.9', model='78', origin='Europe')
# DataRow(car='Honda Accord LX', mpg='29.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2135.', acceleration='16.6', model='78', origin='Japan')
# DataRow(car='Pontiac Lemans V6', mpg='21.5', cylinders='6', displacement='231.0', horsepower='115.0', weight='3245.', acceleration='15.4', model='79', origin='US')
# DataRow(car='Mercury Zephyr 6', mpg='19.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='2990.', acceleration='18.2', model='79', origin='US')
# DataRow(car='Ford Fairmont 4', mpg='22.3', cylinders='4', displacement='140.0', horsepower='88.00', weight='2890.', acceleration='17.3', model='79', origin='US')
# DataRow(car='AMC Concord DL 6', mpg='20.2', cylinders='6', displacement='232.0', horsepower='90.00', weight='3265.', acceleration='18.2', model='79', origin='US')
# DataRow(car='Dodge Aspen 6', mpg='20.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3360.', acceleration='16.6', model='79', origin='US')
# ...
# DataRow(car='Plymouth Horizon TC3', mpg='34.5', cylinders='4', displacement='105.0', horsepower='70.00', weight='2150.', acceleration='14.9', model='79', origin='US')
# DataRow(car='Datsun 210', mpg='31.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2020.', acceleration='19.2', model='79', origin='Japan')
# DataRow(car='Fiat Strada Custom', mpg='37.3', cylinders='4', displacement='91.00', horsepower='69.00', weight='2130.', acceleration='14.7', model='79', origin='Europe')
# DataRow(car='Buick Skylark Limited', mpg='28.4', cylinders='4', displacement='151.0', horsepower='90.00', weight='2670.', acceleration='16.0', model='79', origin='US')
# DataRow(car='Chevrolet Citation', mpg='28.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2595.', acceleration='11.3', model='79', origin='US')
# DataRow(car='Oldsmobile Omega Brougham', mpg='26.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2700.', acceleration='12.9', model='79', origin='US')
# DataRow(car='Pontiac Phoenix', mpg='33.5', cylinders='4', displacement='151.0', horsepower='90.00', weight='2556.', acceleration='13.2', model='79', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='41.5', cylinders='4', displacement='98.00', horsepower='76.00', weight='2144.', acceleration='14.7', model='80', origin='Europe')
# DataRow(car='Toyota Corolla Tercel', mpg='38.1', cylinders='4', displacement='89.00', horsepower='60.00', weight='1968.', acceleration='18.8', model='80', origin='Japan')
# DataRow(car='Chevrolet Chevette', mpg='32.1', cylinders='4', displacement='98.00', horsepower='70.00', weight='2120.', acceleration='15.5', model='80', origin='US')
# DataRow(car='Datsun 310', mpg='37.2', cylinders='4', displacement='86.00', horsepower='65.00', weight='2019.', acceleration='16.4', model='80', origin='Japan')
# DataRow(car='Chevrolet Citation', mpg='28.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2678.', acceleration='16.5', model='80', origin='US')
# DataRow(car='Ford Fairmont', mpg='26.4', cylinders='4', displacement='140.0', horsepower='88.00', weight='2870.', acceleration='18.1', model='80', origin='US')
# DataRow(car='AMC Concord', mpg='24.3', cylinders='4', displacement='151.0', horsepower='90.00', weight='3003.', acceleration='20.1', model='80', origin='US')
# DataRow(car='Dodge Aspen', mpg='19.1', cylinders='6', displacement='225.0', horsepower='90.00', weight='3381.', acceleration='18.7', model='80', origin='US')
# DataRow(car='Audi 4000', mpg='34.3', cylinders='4', displacement='97.00', horsepower='78.00', weight='2188.', acceleration='15.8', model='80', origin='Europe')
# DataRow(car='Toyota Corolla Liftback', mpg='29.8', cylinders='4', displacement='134.0', horsepower='90.00', weight='2711.', acceleration='15.5', model='80', origin='Japan')
# DataRow(car='Mazda 626', mpg='31.3', cylinders='4', displacement='120.0', horsepower='75.00', weight='2542.', acceleration='17.5', model='80', origin='Japan')
# DataRow(car='Datsun 510 Hatchback', mpg='37.0', cylinders='4', displacement='119.0', horsepower='92.00', weight='2434.', acceleration='15.0', model='80', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='32.2', cylinders='4', displacement='108.0', horsepower='75.00', weight='2265.', acceleration='15.2', model='80', origin='Japan')
# DataRow(car='Mazda GLC', mpg='46.6', cylinders='4', displacement='86.00', horsepower='65.00', weight='2110.', acceleration='17.9', model='80', origin='Japan')
# DataRow(car='Dodge Colt', mpg='27.9', cylinders='4', displacement='156.0', horsepower='105.0', weight='2800.', acceleration='14.4', model='80', origin='US')
# DataRow(car='Datsun 210', mpg='40.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2110.', acceleration='19.2', model='80', origin='Japan')
# DataRow(car='Volkswagen Rabbit C (Diesel)', mpg='44.3', cylinders='4', displacement='90.00', horsepower='48.00', weight='2085.', acceleration='21.7', model='80', origin='Europe')
# DataRow(car='Volkswagen Dasher (diesel)', mpg='43.4', cylinders='4', displacement='90.00', horsepower='48.00', weight='2335.', acceleration='23.7', model='80', origin='Europe')
# DataRow(car='Audi 5000s (diesel)', mpg='36.4', cylinders='5', displacement='121.0', horsepower='67.00', weight='2950.', acceleration='19.9', model='80', origin='Europe')
# DataRow(car='Mercedes-Benz 240d', mpg='30.0', cylinders='4', displacement='146.0', horsepower='67.00', weight='3250.', acceleration='21.8', model='80', origin='Europe')
# DataRow(car='Honda Civic 1500 gl', mpg='44.6', cylinders='4', displacement='91.00', horsepower='67.00', weight='1850.', acceleration='13.8', model='80', origin='Japan')
# DataRow(car='Renault Lecar Deluxe', mpg='40.9', cylinders='4', displacement='85.00', horsepower='0', weight='1835.', acceleration='17.3', model='80', origin='Europe')
# DataRow(car='Subaru DL', mpg='33.8', cylinders='4', displacement='97.00', horsepower='67.00', weight='2145.', acceleration='18.0', model='80', origin='Japan')
# DataRow(car='Volkswagen Rabbit', mpg='29.8', cylinders='4', displacement='89.00', horsepower='62.00', weight='1845.', acceleration='15.3', model='80', origin='Europe')
# DataRow(car='Datsun 280-ZX', mpg='32.7', cylinders='6', displacement='168.0', horsepower='132.0', weight='2910.', acceleration='11.4', model='80', origin='Japan')
# DataRow(car='Mazda RX-7 GS', mpg='23.7', cylinders='3', displacement='70.00', horsepower='100.0', weight='2420.', acceleration='12.5', model='80', origin='Japan')
# DataRow(car='Triumph TR7 Coupe', mpg='35.0', cylinders='4', displacement='122.0', horsepower='88.00', weight='2500.', acceleration='15.1', model='80', origin='Europe')
# DataRow(car='Ford Mustang Cobra', mpg='23.6', cylinders='4', displacement='140.0', horsepower='0', weight='2905.', acceleration='14.3', model='80', origin='US')
# DataRow(car='Honda Accord', mpg='32.4', cylinders='4', displacement='107.0', horsepower='72.00', weight='2290.', acceleration='17.0', model='80', origin='Japan')
# DataRow(car='Plymouth Reliant', mpg='27.2', cylinders='4', displacement='135.0', horsepower='84.00', weight='2490.', acceleration='15.7', model='81', origin='US')
# DataRow(car='Buick Skylark', mpg='26.6', cylinders='4', displacement='151.0', horsepower='84.00', weight='2635.', acceleration='16.4', model='81', origin='US')
# DataRow(car='Dodge Aries Wagon (sw)', mpg='25.8', cylinders='4', displacement='156.0', horsepower='92.00', weight='2620.', acceleration='14.4', model='81', origin='US')
# DataRow(car='Chevrolet Citation', mpg='23.5', cylinders='6', displacement='173.0', horsepower='110.0', weight='2725.', acceleration='12.6', model='81', origin='US')
# DataRow(car='Plymouth Reliant', mpg='30.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2385.', acceleration='12.9', model='81', origin='US')
# DataRow(car='Toyota Starlet', mpg='39.1', cylinders='4', displacement='79.00', horsepower='58.00', weight='1755.', acceleration='16.9', model='81', origin='Japan')
# DataRow(car='Plymouth Champ', mpg='39.0', cylinders='4', displacement='86.00', horsepower='64.00', weight='1875.', acceleration='16.4', model='81', origin='US')
# DataRow(car='Honda Civic 1300', mpg='35.1', cylinders='4', displacement='81.00', horsepower='60.00', weight='1760.', acceleration='16.1', model='81', origin='Japan')
# DataRow(car='Subaru', mpg='32.3', cylinders='4', displacement='97.00', horsepower='67.00', weight='2065.', acceleration='17.8', model='81', origin='Japan')
# DataRow(car='Datsun 210 MPG', mpg='37.0', cylinders='4', displacement='85.00', horsepower='65.00', weight='1975.', acceleration='19.4', model='81', origin='Japan')
# DataRow(car='Toyota Tercel', mpg='37.7', cylinders='4', displacement='89.00', horsepower='62.00', weight='2050.', acceleration='17.3', model='81', origin='Japan')
# DataRow(car='Mazda GLC 4', mpg='34.1', cylinders='4', displacement='91.00', horsepower='68.00', weight='1985.', acceleration='16.0', model='81', origin='Japan')
# DataRow(car='Plymouth Horizon 4', mpg='34.7', cylinders='4', displacement='105.0', horsepower='63.00', weight='2215.', acceleration='14.9', model='81', origin='US')
# DataRow(car='Ford Escort 4W', mpg='34.4', cylinders='4', displacement='98.00', horsepower='65.00', weight='2045.', acceleration='16.2', model='81', origin='US')
# DataRow(car='Ford Escort 2H', mpg='29.9', cylinders='4', displacement='98.00', horsepower='65.00', weight='2380.', acceleration='20.7', model='81', origin='US')
# DataRow(car='Volkswagen Jetta', mpg='33.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='2190.', acceleration='14.2', model='81', origin='Europe')
# DataRow(car='Renault 18i', mpg='34.5', cylinders='4', displacement='100.0', horsepower='0', weight='2320.', acceleration='15.8', model='81', origin='Europe')
# DataRow(car='Honda Prelude', mpg='33.7', cylinders='4', displacement='107.0', horsepower='75.00', weight='2210.', acceleration='14.4', model='81', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='32.4', cylinders='4', displacement='108.0', horsepower='75.00', weight='2350.', acceleration='16.8', model='81', origin='Japan')
# DataRow(car='Datsun 200SX', mpg='32.9', cylinders='4', displacement='119.0', horsepower='100.0', weight='2615.', acceleration='14.8', model='81', origin='Japan')
# DataRow(car='Mazda 626', mpg='31.6', cylinders='4', displacement='120.0', horsepower='74.00', weight='2635.', acceleration='18.3', model='81', origin='Japan')
# DataRow(car='Peugeot 505s Turbo Diesel', mpg='28.1', cylinders='4', displacement='141.0', horsepower='80.00', weight='3230.', acceleration='20.4', model='81', origin='Europe')
# DataRow(car='Saab 900s', mpg='0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2800.', acceleration='15.4', model='81', origin='Europe')
# DataRow(car='Volvo Diesel', mpg='30.7', cylinders='6', displacement='145.0', horsepower='76.00', weight='3160.', acceleration='19.6', model='81', origin='Europe')
# DataRow(car='Toyota Cressida', mpg='25.4', cylinders='6', displacement='168.0', horsepower='116.0', weight='2900.', acceleration='12.6', model='81', origin='Japan')
# DataRow(car='Datsun 810 Maxima', mpg='24.2', cylinders='6', displacement='146.0', horsepower='120.0', weight='2930.', acceleration='13.8', model='81', origin='Japan')
# DataRow(car='Buick Century', mpg='22.4', cylinders='6', displacement='231.0', horsepower='110.0', weight='3415.', acceleration='15.8', model='81', origin='US')
# DataRow(car='Oldsmobile Cutlass LS', mpg='26.6', cylinders='8', displacement='350.0', horsepower='105.0', weight='3725.', acceleration='19.0', model='81', origin='US')
# DataRow(car='Ford Grenada gl', mpg='20.2', cylinders='6', displacement='200.0', horsepower='88.00', weight='3060.', acceleration='17.1', model='81', origin='US')
# DataRow(car='Chrysler Lebaron Salon', mpg='17.6', cylinders='6', displacement='225.0', horsepower='85.00', weight='3465.', acceleration='16.6', model='81', origin='US')
# DataRow(car='Chevrolet Cavalier', mpg='28.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2605.', acceleration='19.6', model='82', origin='US')
# DataRow(car='Chevrolet Cavalier Wagon', mpg='27.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2640.', acceleration='18.6', model='82', origin='US')
# DataRow(car='Chevrolet Cavalier 2-door', mpg='34.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2395.', acceleration='18.0', model='82', origin='US')
# DataRow(car='Pontiac J2000 SE Hatchback', mpg='31.0', cylinders='4', displacement='112.0', horsepower='85.00', weight='2575.', acceleration='16.2', model='82', origin='US')
# DataRow(car='Dodge Aries SE', mpg='29.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2525.', acceleration='16.0', model='82', origin='US')
# DataRow(car='Pontiac Phoenix', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2735.', acceleration='18.0', model='82', origin='US')
# DataRow(car='Ford Fairmont Futura', mpg='24.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2865.', acceleration='16.4', model='82', origin='US')
# DataRow(car='AMC Concord DL', mpg='23.0', cylinders='4', displacement='151.0', horsepower='0', weight='3035.', acceleration='20.5', model='82', origin='US')
# DataRow(car='Volkswagen Rabbit l', mpg='36.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='1980.', acceleration='15.3', model='82', origin='Europe')
# DataRow(car='Mazda GLC Custom l', mpg='37.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='2025.', acceleration='18.2', model='82', origin='Japan')
# DataRow(car='Mazda GLC Custom', mpg='31.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='1970.', acceleration='17.6', model='82', origin='Japan')
# DataRow(car='Plymouth Horizon Miser', mpg='38.0', cylinders='4', displacement='105.0', horsepower='63.00', weight='2125.', acceleration='14.7', model='82', origin='US')
# DataRow(car='Mercury Lynx l', mpg='36.0', cylinders='4', displacement='98.00', horsepower='70.00', weight='2125.', acceleration='17.3', model='82', origin='US')
# DataRow(car='Nissan Stanza XE', mpg='36.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2160.', acceleration='14.5', model='82', origin='Japan')
# DataRow(car='Honda Accord', mpg='36.0', cylinders='4', displacement='107.0', horsepower='75.00', weight='2205.', acceleration='14.5', model='82', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='34.0', cylinders='4', displacement='108.0', horsepower='70.00', weight='2245', acceleration='16.9', model='82', origin='Japan')
# DataRow(car='Honda Civic', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.0', model='82', origin='Japan')
# DataRow(car='Honda Civic (auto)', mpg='32.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.7', model='82', origin='Japan')
# DataRow(car='Datsun 310 GX', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1995.', acceleration='16.2', model='82', origin='Japan')
# DataRow(car='Buick Century Limited', mpg='25.0', cylinders='6', displacement='181.0', horsepower='110.0', weight='2945.', acceleration='16.4', model='82', origin='US')
# DataRow(car='Oldsmobile Cutlass Ciera (diesel)', mpg='38.0', cylinders='6', displacement='262.0', horsepower='85.00', weight='3015.', acceleration='17.0', model='82', origin='US')
# DataRow(car='Chrysler Lebaron Medallion', mpg='26.0', cylinders='4', displacement='156.0', horsepower='92.00', weight='2585.', acceleration='14.5', model='82', origin='US')
# DataRow(car='Ford Grenada l', mpg='22.0', cylinders='6', displacement='232.0', horsepower='112.0', weight='2835', acceleration='14.7', model='82', origin='US')
# DataRow(car='Toyota Celica GT', mpg='32.0', cylinders='4', displacement='144.0', horsepower='96.00', weight='2665.', acceleration='13.9', model='82', origin='Japan')
# DataRow(car='Dodge Charger 2.2', mpg='36.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2370.', acceleration='13.0', model='82', origin='US')
# DataRow(car='Chevrolet Camaro', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2950.', acceleration='17.3', model='82', origin='US')
# DataRow(car='Ford Mustang GL', mpg='27.0', cylinders='4', displacement='140.0', horsepower='86.00', weight='2790.', acceleration='15.6', model='82', origin='US')
# DataRow(car='Volkswagen Pickup', mpg='44.0', cylinders='4', displacement='97.00', horsepower='52.00', weight='2130.', acceleration='24.6', model='82', origin='Europe')
# DataRow(car='Dodge Rampage', mpg='32.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2295.', acceleration='11.6', model='82', origin='US')
# DataRow(car='Ford Ranger', mpg='28.0', cylinders='4', displacement='120.0', horsepower='79.00', weight='2625.', acceleration='18.6', model='82', origin='US')
# DataRow(car='Chevy S-10', mpg='31.0', cylinders='4', displacement='119.0', horsepower='82.00', weight='2720.', acceleration='19.4', model='82', origin='US')

# %%
from contextlib import contextmanager

@contextmanager
def csv_file_reader(fname: str):
    dialect = get_csv_dialect(fname)
    try:
        f = open(fname)
        csv_reader = csv.reader(f, dialect)
        next(csv_reader)  # ignore headers
        yield csv_reader
    finally:
        f.close()

# %%
fname = "personal_info.csv"
DataRow = get_data_row_factory(fname)
with csv_file_reader(fname) as file:
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    for row in file:
        print(row)
# Out:
# DataRow(ssn='100-53-9824', first_name='Sebastiano', last_name='Tester', gender='Male', language='Icelandic')
# DataRow(ssn='101-71-4702', first_name='Cayla', last_name='MacDonagh', gender='Female', language='Lao')
# DataRow(ssn='101-84-0356', first_name='Nomi', last_name='Lipprose', gender='Female', language='Yiddish')
# DataRow(ssn='104-22-0928', first_name='Justinian', last_name='Kunzelmann', gender='Male', language='Dhivehi')
# DataRow(ssn='104-84-7144', first_name='Claudianus', last_name='Brixey', gender='Male', language='Afrikaans')
# ['105-27-5541', 'Federico', 'Aggett', 'Male', 'Chinese']
# ['105-85-7486', 'Angelina', 'McAvey', 'Female', 'Punjabi']
# ['105-91-5022', 'Moselle', 'Apfel', 'Female', 'Latvian']
# ['105-91-7777', 'Audi', 'Roach', 'Female', 'Estonian']
# ['106-35-1938', 'Mackenzie', 'Nussey', 'Male', 'Swedish']
# ['106-36-3293', 'Martino', 'Tregoning', 'Male', 'Tok Pisin']
# ['110-84-3641', 'Amberly', 'Huws', 'Female', 'Papiamento']
# ['111-35-1034', 'Giacopo', 'Timperley', 'Male', 'Gagauz']
# ['114-06-6912', 'Jule', 'Velte', 'Male', 'Dutch']
# ['114-66-0984', 'Casandra', 'Juares', 'Female', 'Lithuanian']
# ['114-74-8701', 'Levey', 'Baradel', 'Male', 'Icelandic']
# ['116-10-7235', 'Chiquita', 'Danbi', 'Female', 'Dari']
# ['116-77-4915', 'Herold', 'Fearon', 'Male', 'Italian']
# ['117-39-6617', 'Auroora', 'Yong', 'Female', 'Swahili']
# ['117-77-9748', 'Lucien', 'Smalman', 'Male', 'Hebrew']
# ['117-78-6202', 'Dareen', 'Jiggins', 'Female', 'Polish']
# ['118-21-0357', 'Laina', 'Bayly', 'Female', 'Bulgarian']
# ['118-95-7100', 'Alexi', 'Leglise', 'Female', 'Lithuanian']
# ['119-07-8817', 'Blondie', 'Powderham', 'Female', 'Croatian']
# ['120-33-5535', 'Eugen', 'Shark', 'Male', 'Dhivehi']
# ['120-98-4054', 'Lorry', 'Hitter', 'Male', 'Kazakh']
# ['121-98-3948', 'Sal', 'Le Lievre', 'Male', 'Croatian']
# ['123-05-3229', 'Spenser', 'Shucksmith', 'Male', 'Bosnian']
# ['123-62-2832', 'Kare', 'Barhams', 'Female', 'Tajik']
# ['123-88-3381', 'Christiane', 'Hynes', 'Female', 'Danish']
# ['125-07-9434', 'Florella', 'Mathevon', 'Female', 'Armenian']
# ['127-49-2473', 'Quinta', 'Rippingall', 'Female', 'Haitian Creole']
# ['127-52-8001', 'Wilona', 'Noirel', 'Female', 'Aymara']
# ['127-68-4232', 'Tresa', 'Verheyden', 'Female', 'Icelandic']
# ['127-93-3548', 'Mellicent', 'Ingham', 'Female', 'Lao']
# ['128-42-4599', 'Neddy', "O'Griffin", 'Male', 'Croatian']
# ['128-53-0369', 'Chucho', 'Rikel', 'Male', 'Croatian']
# ['128-53-7952', 'Tobie', 'Newhouse', 'Male', 'Luxembourgish']
# ['128-56-6040', 'Jinny', 'Stebbings', 'Female', 'Armenian']
# ['128-60-4388', 'Norton', 'Shailer', 'Male', 'Czech']
# ['129-67-0291', 'Danella', 'Linacre', 'Female', 'Dzongkha']
# ['131-81-4310', 'Jemie', 'Manilo', 'Female', 'Finnish']
# ['132-26-3507', 'Shalom', 'Arendsen', 'Male', 'Hindi']
# ['134-05-0120', 'Simone', 'Cruickshanks', 'Female', 'Filipino']
# ['135-86-9625', 'Tilly', 'Meir', 'Female', 'Gagauz']
# ['137-13-1889', 'Tedman', "O'Donnelly", 'Male', 'Bislama']
# ['138-65-4579', 'Davidson', 'Gregoraci', 'Male', 'Luxembourgish']
# ['138-67-1198', 'Pam', 'Tofful', 'Female', 'Bislama']
# ['138-88-5288', 'Joletta', 'Babcock', 'Female', 'Burmese']
# ['139-04-8189', 'Stirling', 'Creak', 'Male', 'Italian']
# ['139-94-5865', 'Donalt', 'Plewes', 'Male', 'Haitian Creole']
# ['139-99-6417', 'Susanetta', 'Nazaret', 'Female', 'Punjabi']
# ['140-33-9727', 'Price', 'Butterwick', 'Male', 'Belarusian']
# ['140-58-8263', 'Tim', 'Bergin', 'Female', 'Maori']
# ['141-15-0543', 'Candy', 'Murtagh', 'Female', 'Montenegrin']
# ['141-88-9721', 'Cyrille', 'Capponer', 'Male', 'Tswana']
# ['142-77-4616', 'Barron', 'Victoria', 'Male', 'Assamese']
# ['142-87-3416', 'Margaux', 'Wintringham', 'Female', 'Tajik']
# ['143-17-4714', 'Hallie', 'Jeggo', 'Female', 'Greek']
# ['145-10-8454', 'Donny', 'Laba', 'Male', 'Japanese']
# ['145-35-5124', 'Leon', 'Boyson', 'Male', 'Dhivehi']
# ['145-78-3985', 'Baron', 'Cocci', 'Male', 'Mongolian']
# ['146-81-3446', 'Korry', 'Billham', 'Female', 'Hebrew']
# ['147-33-1463', 'Bendicty', 'Gentry', 'Male', 'Papiamento']
# ['147-47-8577', 'Janessa', 'Growy', 'Female', 'Gujarati']
# ['147-63-3462', 'Aime', 'Di Antonio', 'Female', 'Tok Pisin']
# ['148-60-7519', 'Jordan', 'Readwood', 'Female', 'Khmer']
# ['149-18-7272', 'Andrey', 'Bettley', 'Male', 'Papiamento']
# ['149-45-6482', 'Wheeler', 'Harbottle', 'Male', 'Georgian']
# ['150-64-6357', 'Helenka', 'Summerell', 'Female', 'Bosnian']
# ['150-89-3343', 'Bram', 'Beetlestone', 'Male', 'Dzongkha']
# ['151-54-3946', 'Piggy', 'Fishly', 'Male', 'Nepali']
# ['151-70-0641', 'Urbain', 'Balint', 'Male', 'Malagasy']
# ['151-78-1397', 'Portia', 'Belshaw', 'Female', 'Sotho']
# ['152-71-3526', 'Mel', 'Atkirk', 'Female', 'Swedish']
# ['153-67-1309', 'Annelise', 'Yushin', 'Female', 'French']
# ['154-17-7912', 'Ainslee', 'Branche', 'Female', 'Hindi']
# ['156-18-7547', 'Trey', 'Payne', 'Male', 'West Frisian']
# ['156-91-6848', 'Carol', 'Cromar', 'Female', 'Amharic']
# ['157-17-9982', 'Ardyce', 'Kuhnel', 'Female', 'Danish']
# ['157-38-7090', 'Johannes', 'Bugge', 'Male', 'Afrikaans']
# ['157-51-5269', 'Melisse', 'Petkov', 'Female', 'Punjabi']
# ['161-36-9710', 'Melina', 'MacDavitt', 'Female', 'Polish']
# ['161-53-4778', 'Kiri', 'Ciccone', 'Female', 'Kyrgyz']
# ['163-68-8070', 'Vassily', 'MacCarlich', 'Male', 'Filipino']
# ['163-98-1022', 'Babbette', 'Crystal', 'Female', 'Lithuanian']
# ['164-11-9849', 'Clemence', 'Aujean', 'Female', 'Albanian']
# ['166-10-4488', 'Lester', 'Keyson', 'Male', 'Bislama']
# ['167-39-2377', 'Reyna', 'Ullyatt', 'Female', 'Portuguese']
# ['168-02-5324', 'Dane', 'Cornick', 'Male', 'Tajik']
# ['168-19-8754', 'Teddie', 'Ingliss', 'Male', 'Norwegian']
# ['168-81-0838', 'Toby', 'Pond-Jones', 'Female', 'Aymara']
# ['168-89-6661', 'Vergil', 'Cecere', 'Male', 'Tetum']
# ['170-65-3388', 'Salvidor', 'Larcher', 'Male', 'Burmese']
# ['171-27-7781', 'Phillida', 'Cleeve', 'Female', 'Lao']
# ['172-23-7739', 'Everett', 'Turneaux', 'Male', 'Kyrgyz']
# ['172-77-4263', 'Alex', 'Udie', 'Male', 'French']
# ['172-89-7546', 'Trude', 'Gillson', 'Female', 'Norwegian']
# ['173-99-7372', 'Hedwiga', 'Gee', 'Female', 'Danish']
# ['174-13-2047', 'Rey', 'Dallywater', 'Female', 'Zulu']
# ['174-35-3812', 'Sayer', 'Astling', 'Male', 'Kyrgyz']
# ['174-51-9992', 'Drucie', 'Travers', 'Female', 'Swati']
# ['174-87-2537', 'Benton', 'Nolte', 'Male', 'Persian']
# ['176-82-1359', 'Corny', 'Rothera', 'Female', 'Thai']
# ['176-99-5851', 'Olivero', 'Janse', 'Male', 'Moldovan']
# ['179-88-2790', 'Errick', 'Charsley', 'Male', 'Japanese']
# ['181-07-4434', 'Ferdinande', 'Probet', 'Female', 'Catalan']
# ['181-28-8337', 'Fan', 'Hillyatt', 'Female', 'Moldovan']
# ['181-88-6077', 'Ebba', 'Wozencroft', 'Female', 'German']
# ['182-15-5082', 'Lavinie', 'Niess', 'Female', 'Swahili']
# ['182-81-4541', 'Sunny', 'Ferrarini', 'Male', 'Swedish']
# ['183-10-5024', 'Curran', 'Squires', 'Male', 'Romanian']
# ['184-60-6243', 'Fern', 'Demogeot', 'Female', 'Tok Pisin']
# ['184-84-1003', 'Bary', 'Buzin', 'Male', 'Aymara']
# ['184-92-3560', 'Kore', 'Eastes', 'Female', 'Fijian']
# ['184-94-5241', 'Manfred', 'McCrillis', 'Male', 'Swati']
# ['185-50-0434', 'Alexa', 'Emblin', 'Female', 'Quechua']
# ['185-84-9868', 'Shandy', 'Ilyin', 'Female', 'Northern Sotho']
# ['186-65-7773', 'Hazlett', 'Arney', 'Male', 'Marathi']
# ['188-20-9317', 'Clifford', 'Sedgemore', 'Male', 'Thai']
# ['188-40-4336', 'Belita', 'Camolli', 'Female', 'Telugu']
# ['189-26-5696', 'Arnold', 'Pepis', 'Male', 'Tok Pisin']
# ['189-49-1458', 'Vernen', 'Ivanyushkin', 'Male', 'Quechua']
# ['190-05-6987', 'Gorden', 'Clemonts', 'Male', 'West Frisian']
# ['190-53-4517', 'Hadlee', 'Rohan', 'Male', 'Swahili']
# ['191-15-3194', 'Calhoun', 'Mugford', 'Male', 'Thai']
# ['192-54-0695', 'Trev', 'Ruppeli', 'Male', 'Maori']
# ['192-67-3201', 'Edvard', 'Cattel', 'Male', 'Hebrew']
# ['194-76-5816', 'Jacquelynn', 'Shurey', 'Female', 'Amharic']
# ['195-23-5731', 'Talyah', 'Canny', 'Female', 'Portuguese']
# ['196-69-3796', 'Marijo', 'Tester', 'Female', 'Oriya']
# ['198-70-6443', 'Judah', 'Duggan', 'Male', 'Macedonian']
# ['199-45-0804', 'Consolata', 'Pigram', 'Female', 'Guarana']
# ['199-54-4639', 'Ellene', 'Dowrey', 'Female', 'Nepali']
# ['200-81-7151', 'Merilyn', 'Tink', 'Female', 'Bengali']
# ['201-53-1249', 'Jammal', 'Dohmer', 'Male', 'Danish']
# ['202-84-1146', 'Dore', 'Woodrup', 'Male', 'Afrikaans']
# ['203-35-7648', 'Budd', 'Artiss', 'Male', 'Norwegian']
# ['205-69-7375', 'Cacilia', 'Kneesha', 'Female', 'Indonesian']
# ['205-87-2423', 'Oralla', 'Kearle', 'Female', 'Zulu']
# ['206-28-6674', 'Con', 'Mansbridge', 'Male', 'Haitian Creole']
# ['206-83-8848', 'Ardyth', 'Arger', 'Female', 'Gagauz']
# ['208-74-2166', 'Tiebold', 'Gherarducci', 'Male', 'Croatian']
# ['208-80-5879', 'Rockie', 'Fryd', 'Male', 'Korean']
# ['209-50-8146', 'Kenna', 'Meryett', 'Female', 'Czech']
# ['209-58-4708', 'Stephanus', 'Creboe', 'Male', 'Latvian']
# ['210-91-4729', 'Tamarra', 'Minchella', 'Female', 'Greek']
# ['211-04-1734', 'Jeana', 'Girardeau', 'Female', 'Dzongkha']
# ['211-13-5247', 'Wes', 'Weinberg', 'Male', 'French']
# ['211-15-5182', 'Gene', 'Bassilashvili', 'Female', 'Swedish']
# ['211-19-6826', 'Noni', 'Meynell', 'Female', 'Portuguese']
# ['212-40-0215', 'Giffie', 'Strauss', 'Male', 'Azeri']
# ['212-41-1496', 'Agnese', 'Lawes', 'Female', 'Tamil']
# ['213-28-1395', 'Catlaina', 'Patullo', 'Female', 'Bengali']
# ['214-29-1189', 'Chandler', 'Gonsalvo', 'Male', 'Haitian Creole']
# ['214-96-8581', 'Earlie', 'de Nore', 'Male', 'Georgian']
# ['214-99-7584', 'Barny', 'Witherden', 'Male', 'Czech']
# ['216-89-3812', 'Florian', 'Jaze', 'Male', 'Croatian']
# ['216-97-3104', 'Elvira', 'McDougal', 'Female', 'Bislama']
# ['217-71-3922', 'Hayes', 'Vallentin', 'Male', 'Bengali']
# ['217-81-5416', 'Gusta', 'Cruise', 'Female', 'Tsonga']
# ['218-14-4448', 'Keary', 'Druhan', 'Male', 'Dutch']
# ['218-25-9873', 'Westbrooke', 'Succamore', 'Male', 'Fijian']
# ['218-31-1615', 'Trenton', 'Eggerton', 'Male', 'Dari']
# ['218-49-7300', 'Justinn', 'Sherebrooke', 'Female', 'English']
# ['220-16-0476', 'Baxy', 'Brothwood', 'Male', 'Kyrgyz']
# ['220-38-0208', 'Jess', 'Fulun', 'Female', 'Gagauz']
# ['222-39-8571', 'Fidelia', 'Domonkos', 'Female', 'Fijian']
# ['223-67-9203', 'Markus', 'Radband', 'Male', 'Bosnian']
# ['223-98-0846', 'Josy', 'Hadwick', 'Female', 'Papiamento']
# ['224-12-3436', 'Alister', 'Eakle', 'Male', 'Estonian']
# ['224-30-9267', 'Flori', 'Bagnal', 'Female', 'Swedish']
# ['224-54-6919', 'Kelly', 'Shipman', 'Male', 'Icelandic']
# ['224-84-2271', 'Weider', 'Carlisle', 'Male', 'Swedish']
# ['224-99-0668', 'Brandy', 'Steed', 'Male', 'Croatian']
# ['225-08-5789', 'Tamra', 'Becken', 'Female', 'Telugu']
# ['225-64-2735', 'Graig', 'Rasher', 'Male', 'Maltese']
# ['226-76-4452', 'Van', 'Gervaise', 'Male', 'Greek']
# ['227-72-7247', 'Mauricio', 'Gush', 'Male', 'Tajik']
# ['228-16-7922', 'Tabby', 'Chitty', 'Male', 'Spanish']
# ['228-55-2042', 'Jaquith', 'Durtnel', 'Female', 'Czech']
# ['228-90-5077', 'Jonathon', 'Klugel', 'Male', 'Hindi']
# ['229-44-9909', 'Barnabas', 'Heppenspall', 'Male', 'Icelandic']
# ['230-09-1794', 'Xerxes', 'Mathivon', 'Male', 'Danish']
# ['230-48-0684', 'Clay', 'Peaurt', 'Male', 'Dhivehi']
# ['230-99-1485', 'Markus', 'Revill', 'Male', 'Moldovan']
# ['231-66-9264', 'Gisele', 'Castelow', 'Female', 'Hiri Motu']
# ['232-18-5397', 'Clare', 'McGairl', 'Female', 'Bengali']
# ['233-27-2377', 'Arlyne', 'Stenning', 'Female', 'Dari']
# ['235-10-3518', 'Winfield', 'Purvis', 'Male', 'Estonian']
# ['236-31-8333', 'Wendeline', 'Millins', 'Female', 'Kashmiri']
# ['236-37-2567', 'Ariel', 'Murrigan', 'Female', 'West Frisian']
# ['237-48-6737', 'Eal', 'Ducastel', 'Male', 'Indonesian']
# ['237-80-7039', 'Ardyce', 'Hunn', 'Female', 'Maltese']
# ['238-13-8034', 'Estrellita', 'Heavy', 'Female', 'Azeri']
# ['238-39-9999', 'Pauly', 'Griffin', 'Female', 'Georgian']
# ['239-09-9133', 'Tom', 'Roggeman', 'Male', 'Sotho']
# ['239-37-4122', 'Jodee', 'Elsdon', 'Female', 'Guarana']
# ['240-08-8805', 'Gates', 'McGiffin', 'Female', 'Finnish']
# ['240-32-8915', 'Cathee', 'Tarbard', 'Female', 'Papiamento']
# ['240-67-6258', 'Kalina', 'Lloyds', 'Female', 'Hindi']
# ['242-22-9624', 'Felice', 'Surr', 'Male', 'Afrikaans']
# ['243-37-9496', 'Verine', 'Etchells', 'Female', 'Burmese']
# ['243-44-4611', 'Shani', "O'Tierney", 'Female', 'Aymara']
# ['244-34-2210', 'Lek', 'Heino', 'Male', 'New Zealand Sign Language']
# ['244-52-7593', 'Erda', 'Paulusch', 'Female', 'Gujarati']
# ['244-79-3004', 'Renault', 'Stollard', 'Male', 'Amharic']
# ['244-81-0671', 'Viviyan', 'Udell', 'Female', 'Moldovan']
# ['245-60-5880', 'Oby', 'Hauxby', 'Male', 'French']
# ['245-77-4110', 'Alasdair', 'McAndrew', 'Male', 'Czech']
# ['247-08-9326', 'Minni', 'Scurman', 'Female', 'Kannada']
# ['247-86-5288', 'Lilly', 'Holby', 'Female', 'Bosnian']
# ['248-07-9757', 'Sean', 'Ham', 'Male', 'Luxembourgish']
# ['248-23-0150', 'Welbie', 'Gilley', 'Male', 'Korean']
# ['249-19-5514', 'Yehudi', 'Pharoah', 'Male', 'Latvian']
# ['253-61-8401', 'Genny', 'Juara', 'Female', 'Tswana']
# ['254-10-6071', 'Dwight', 'Eastcourt', 'Male', 'Oriya']
# ['254-92-9669', 'Tom', 'Larking', 'Male', 'Icelandic']
# ['255-81-0958', 'Darryl', 'Sparkes', 'Female', 'Estonian']
# ['256-54-7507', 'Angus', 'Cullip', 'Male', 'Spanish']
# ['256-57-0666', 'Rip', 'Grube', 'Male', 'Ndebele']
# ['257-12-6834', 'Derward', 'Paladini', 'Male', 'Thai']
# ['257-59-8603', 'Cyrillus', 'Sanchiz', 'Male', 'Romanian']
# ['257-77-3669', 'Ynez', 'Hain', 'Female', 'Kazakh']
# ['258-22-6416', 'Veriee', 'Klein', 'Female', 'Northern Sotho']
# ['259-38-5920', 'Jethro', 'Rustidge', 'Male', 'Fijian']
# ['261-14-9490', 'Lorry', 'Boshere', 'Male', 'Oriya']
# ['262-09-2144', 'Leigh', 'Paxforde', 'Male', 'Portuguese']
# ['262-46-7573', 'Lorene', 'Vagg', 'Female', 'Punjabi']
# ['262-55-4066', 'Kaitlynn', 'Bleazard', 'Female', 'Estonian']
# ['262-66-7030', 'Gray', 'Bissatt', 'Female', 'Khmer']
# ['264-39-3910', 'Elysia', 'Favell', 'Female', 'Hindi']
# ['266-86-9980', 'Rita', 'Leving', 'Female', 'Latvian']
# ['267-75-6383', 'Ardath', 'Pitts', 'Female', 'Romanian']
# ['269-01-2640', 'Russell', 'Dabner', 'Male', 'Danish']
# ['271-04-0134', 'Eadith', 'Jerg', 'Female', 'Gagauz']
# ['271-81-9938', 'James', 'Robbins', 'Male', 'Bengali']
# ['271-93-3051', 'Augustin', 'Agiolfinger', 'Male', 'Latvian']
# ['272-50-7309', 'Sig', 'Ather', 'Male', 'Catalan']
# ['272-81-7979', 'Sherlocke', 'Giddings', 'Male', 'Georgian']
# ['273-49-8218', 'Haze', 'Starkings', 'Male', 'Portuguese']
# ['274-50-3806', 'Shurlocke', 'Aron', 'Male', 'Punjabi']
# ['274-76-9883', 'Fawn', 'MacNamara', 'Female', 'Bengali']
# ['276-05-2973', 'Cly', 'Yerlett', 'Male', 'Kazakh']
# ['278-55-5842', 'Korie', 'Di Pietro', 'Female', 'German']
# ['278-64-4853', 'Diane-marie', 'Broggini', 'Female', 'Tsonga']
# ['279-12-7167', 'Elbertina', 'Alders', 'Female', 'Amharic']
# ['279-40-5540', 'Montague', 'Knowler', 'Male', 'Chinese']
# ['279-49-5682', 'Kleon', 'Tembridge', 'Male', 'Gagauz']
# ['280-53-7447', 'Suzette', 'Prahl', 'Female', 'Romanian']
# ['280-98-4410', 'Ealasaid', 'Devon', 'Female', 'Tok Pisin']
# ['281-23-3458', 'Bettina', 'Danilov', 'Female', 'Sotho']
# ['282-83-9206', 'Jackie', 'McPhater', 'Male', 'Gagauz']
# ['283-04-6835', 'Tobey', 'Joule', 'Female', 'Dzongkha']
# ['286-26-4004', 'Augustus', 'Doodson', 'Male', 'Romanian']
# ['287-57-9688', 'Joachim', 'Moncreiff', 'Male', 'Catalan']
# ['287-66-2660', 'Larissa', 'Airy', 'Female', 'Bislama']
# ['288-54-7233', 'Hedy', 'Eaklee', 'Female', 'English']
# ['288-87-6462', 'Stanislaus', 'Haylor', 'Male', 'Kannada']
# ['289-03-9882', 'Giusto', 'Baszniak', 'Male', 'Yiddish']
# ['289-09-8686', 'Heath', 'Stallan', 'Male', 'Malayalam']
# ['290-25-7300', 'Bowie', 'Bancroft', 'Male', 'Thai']
# ['290-82-4968', 'Ingram', 'Kincade', 'Male', 'Moldovan']
# ['293-54-3694', 'Theodora', 'Geddes', 'Female', 'Maori']
# ['294-27-9936', 'Cari', 'Bradane', 'Female', 'Japanese']
# ['294-53-1911', 'Ginelle', 'Jaquet', 'Female', 'Persian']
# ['295-63-7693', 'Fonzie', 'Fattorini', 'Male', 'Estonian']
# ['296-32-7910', 'Harlene', 'Morrill', 'Female', 'Swati']
# ['296-88-0097', 'Herculie', 'Branthwaite', 'Male', 'Hungarian']
# ['296-90-4908', 'Holt', 'Angel', 'Male', 'Tamil']
# ['297-63-1154', 'Maribelle', 'Gowanson', 'Female', 'Montenegrin']
# ['298-06-3497', 'Moshe', 'Thomassin', 'Male', 'Polish']
# ['298-69-9168', 'Shea', 'Canon', 'Male', 'Finnish']
# ['298-70-6018', 'Minny', 'Van der Baaren', 'Female', 'Afrikaans']
# ['298-79-7640', 'Mycah', 'Hillam', 'Male', 'Swahili']
# ['299-03-6911', 'Janela', 'Ferrone', 'Female', 'Gagauz']
# ['299-38-0483', 'Robb', 'Posner', 'Male', 'Italian']
# ['299-77-1060', 'Bellina', 'Galbreth', 'Female', 'Norwegian']
# ['300-59-3610', 'Tam', 'Howles', 'Male', 'Pashto']
# ['300-76-8770', 'Danielle', 'Rowth', 'Female', 'Italian']
# ['300-80-7209', 'Gabbie', 'Burney', 'Female', 'Dutch']
# ['301-26-4306', 'Emmye', 'Whelpdale', 'Female', 'Tajik']
# ['301-51-0522', 'Kenneth', 'Methley', 'Male', 'Papiamento']
# ['302-64-4858', 'Hakeem', 'Zelley', 'Male', 'Afrikaans']
# ['304-48-4312', 'Edeline', 'Van de Vlies', 'Female', 'Montenegrin']
# ['305-07-1498', 'Ruddy', "O'Crotty", 'Male', 'Spanish']
# ['306-23-2423', 'Ree', 'Meader', 'Female', 'Polish']
# ['306-86-2930', 'Kassie', 'Neaverson', 'Female', 'Luxembourgish']
# ['308-58-0964', 'Talbert', 'Osipov', 'Male', 'Tetum']
# ['309-04-0364', 'Dov', 'Speight', 'Male', 'Tajik']
# ['309-38-8085', 'Nell', 'Scrigmour', 'Female', 'Persian']
# ['310-60-2027', 'Zacherie', 'Parken', 'Male', 'Albanian']
# ['311-46-9296', 'Alic', 'Pabel', 'Male', 'Fijian']
# ['312-38-7084', 'Ezri', 'Paolicchi', 'Male', 'Malagasy']
# ['312-59-3476', 'Sadye', 'Beloe', 'Female', 'Icelandic']
# ['312-77-3647', 'Hussein', 'Blything', 'Male', 'Hebrew']
# ['313-02-7822', 'Spence', 'Climer', 'Male', 'Maori']
# ['313-52-7312', 'Farrand', 'MacKenzie', 'Female', 'French']
# ['315-12-5664', 'Vere', 'Morlon', 'Female', 'German']
# ['315-26-2241', 'Cammy', 'Harland', 'Female', 'Bulgarian']
# ['315-44-9671', 'Ximenez', 'Maghull', 'Male', 'Macedonian']
# ['315-78-5587', 'Helsa', 'Lumber', 'Female', 'Tok Pisin']
# ['317-28-1600', 'Rodrick', 'Abrahams', 'Male', 'Assamese']
# ['317-43-2055', 'Jocelyn', 'Gildroy', 'Female', 'Punjabi']
# ['318-58-5314', 'Stephan', 'Peatt', 'Male', 'New Zealand Sign Language']
# ['319-43-0465', 'Boothe', 'Vanin', 'Male', 'West Frisian']
# ['320-90-1419', 'Em', 'Darwood', 'Male', 'Icelandic']
# ['320-97-9147', 'Roch', 'Wahlberg', 'Female', 'Thai']
# ['323-28-6705', 'Christiano', 'Stoffler', 'Male', 'Kyrgyz']
# ['323-33-8689', 'Dulcinea', 'Lundberg', 'Female', 'Dutch']
# ['324-39-5230', 'Alexandrina', 'Dahlbom', 'Female', 'Moldovan']
# ['324-73-8895', 'Walliw', 'Alstead', 'Female', 'Guarana']
# ['324-75-6098', 'Rafael', 'Robinett', 'Male', 'Portuguese']
# ['326-64-9957', 'Jorgan', 'Renowden', 'Male', 'Swati']
# ['327-52-0546', 'Carlota', 'Hovey', 'Female', 'English']
# ['327-88-7554', 'Malynda', 'Kingerby', 'Female', 'Swahili']
# ['330-99-3055', 'Marinna', 'Dally', 'Female', 'Azeri']
# ['332-83-6591', 'Forrester', 'Cullabine', 'Male', 'Dzongkha']
# ['333-52-5097', 'Florentia', 'Espinazo', 'Female', 'Tetum']
# ['333-95-5025', 'Rebeca', 'Walesa', 'Female', 'Zulu']
# ['335-35-1520', 'Ervin', 'Hugues', 'Male', 'Armenian']
# ['336-48-2579', 'Renee', 'Crank', 'Female', 'Armenian']
# ['339-27-8046', 'Julita', 'Jouhan', 'Female', 'Bosnian']
# ['339-71-2687', 'Marlie', 'Corpe', 'Female', 'Persian']
# ['341-10-6840', 'Cyrille', 'Critchlow', 'Male', 'Portuguese']
# ['342-05-9057', 'Beatrix', 'Relton', 'Female', 'Latvian']
# ['342-55-0538', 'Hilliary', 'Suddards', 'Female', 'Dzongkha']
# ['342-90-9333', 'Geri', 'Yesinov', 'Male', 'Norwegian']
# ['343-20-8407', 'Bradford', 'Niemiec', 'Male', 'Chinese']
# ['343-81-3179', 'Reinhard', 'Bortolutti', 'Male', 'Kannada']
# ['345-74-2160', 'Camile', 'Pengelly', 'Female', 'Lao']
# ['347-09-3254', 'Dulciana', 'Hexum', 'Female', 'Lao']
# ['347-64-8652', 'Dusty', 'Morat', 'Female', 'Japanese']
# ['348-73-4312', 'Elberta', 'Howden', 'Female', 'Khmer']
# ['348-74-3224', 'Dorthy', 'Abreheart', 'Female', 'Bosnian']
# ['349-53-8864', 'Muffin', 'Lord', 'Female', 'Georgian']
# ['349-67-7502', 'Ari', 'Yitzhakov', 'Male', 'Zulu']
# ['350-20-9593', 'Eldridge', 'Crispin', 'Male', 'Dutch']
# ['350-80-4646', 'Harp', 'Du Plantier', 'Male', 'Dutch']
# ['351-73-2802', 'Cybill', 'Parnham', 'Female', 'Latvian']
# ['355-21-9711', 'Daryn', 'Battin', 'Female', 'Georgian']
# ['355-52-9767', 'Kacy', 'Offen', 'Female', 'Kurdish']
# ['355-96-7706', 'Lauritz', 'Lucock', 'Male', 'Mongolian']
# ['356-39-9199', 'Arney', 'Polglaze', 'Male', 'Marathi']
# ['357-37-6094', 'Chrisse', 'Kirton', 'Male', 'Latvian']
# ['358-84-7049', 'Emalee', 'McCleary', 'Female', 'Thai']
# ['360-69-6230', 'Grannie', 'Champ', 'Male', 'Belarusian']
# ['361-06-1530', 'Luis', 'Ashborne', 'Male', 'Mongolian']
# ['361-42-7068', 'Ashia', 'Ferran', 'Female', 'West Frisian']
# ['361-49-4597', 'Adan', 'Janssen', 'Male', 'Swedish']
# ['361-83-5004', 'Wilona', 'Sink', 'Female', 'Sotho']
# ['362-09-8563', 'Carri', 'Peterffy', 'Female', 'Icelandic']
# ['362-12-7902', 'Weber', 'Legrand', 'Male', 'Swahili']
# ['364-25-0166', 'Arnuad', 'Planque', 'Male', 'Hindi']
# ['364-65-2174', 'Bernarr', 'Wollard', 'Male', 'Irish Gaelic']
# ['366-61-0607', 'Bethena', 'Joicey', 'Female', 'Haitian Creole']
# ['367-22-8998', 'Blake', 'Mustin', 'Female', 'Kyrgyz']
# ['367-62-4426', 'Sigismondo', 'Lerohan', 'Male', 'Georgian']
# ['370-01-6977', 'Hugues', 'Jeffryes', 'Male', 'Georgian']
# ['370-24-5876', 'Sergei', 'Risby', 'Male', 'Bulgarian']
# ['370-72-6509', 'Wrennie', 'McCrorie', 'Female', 'Papiamento']
# ['371-28-5892', 'Malia', 'Hanse', 'Female', 'Tsonga']
# ['371-44-0582', 'Clemmy', 'Cogzell', 'Male', 'Estonian']
# ['371-62-3727', 'Cymbre', 'Chinnock', 'Female', 'Dutch']
# ['371-88-9249', 'Nealon', 'Oxtaby', 'Male', 'German']
# ['372-44-7487', 'Jolyn', 'Bertome', 'Female', 'Catalan']
# ['372-62-7057', 'Eleanora', 'Vazquez', 'Female', 'Gujarati']
# ['373-67-2734', 'Ileana', 'Luty', 'Female', 'Italian']
# ['374-47-0262', 'Bank', 'Evitts', 'Male', 'Aymara']
# ['378-08-0805', 'Carroll', 'Harty', 'Female', 'Swedish']
# ['378-60-2472', 'Eddie', 'Howieson', 'Female', 'Albanian']
# ['378-66-0449', 'Kelby', 'Wincer', 'Male', 'Pashto']
# ['378-79-0193', 'Kenny', 'Josefsen', 'Male', 'Danish']
# ['378-88-6805', 'Vittoria', 'Oldroyd', 'Female', 'Moldovan']
# ['379-07-8748', 'Dyanna', 'Noto', 'Female', 'Polish']
# ['380-33-9730', 'Katinka', 'Piet', 'Female', 'Malay']
# ['380-35-3854', 'Cathleen', 'Sizland', 'Female', 'Bislama']
# ['383-18-4058', 'Frederigo', 'Cooksey', 'Male', 'Indonesian']
# ['384-30-6793', 'Kipp', 'Burnyate', 'Male', 'English']
# ['384-94-2772', 'Ramsay', 'Dolbey', 'Male', 'Tok Pisin']
# ['385-30-1777', 'Aubrey', 'Wetherill', 'Female', 'Tswana']
# ['385-34-7828', 'Dori', 'Quogan', 'Female', 'Afrikaans']
# ['385-98-0431', 'Kassi', 'Rashleigh', 'Female', 'Tswana']
# ['386-15-7960', 'Steffie', 'Tedahl', 'Female', 'Punjabi']
# ['386-34-4088', 'Adamo', 'Wogden', 'Male', 'Arabic']
# ['386-68-9884', 'Francis', 'Foch', 'Male', 'Dzongkha']
# ['386-97-3523', 'Siusan', 'Durkin', 'Female', 'Kurdish']
# ['389-31-0910', 'Mac', 'Westrey', 'Male', 'Armenian']
# ['389-51-1424', 'Isadore', 'Orbine', 'Male', 'Pashto']
# ['389-84-8254', 'Chiquita', 'Jolliman', 'Female', 'Marathi']
# ['390-74-3062', 'Cara', 'Ingree', 'Female', 'Indonesian']
# ['391-14-9280', 'Faun', 'Chillistone', 'Female', 'Montenegrin']
# ['391-47-4578', 'Fiann', 'Fellman', 'Female', 'Assamese']
# ['391-73-2830', 'Padget', 'Manthorpe', 'Male', 'Marathi']
# ['393-22-6585', 'Reinold', 'Ellif', 'Male', 'Nepali']
# ['396-51-1559', 'Natasha', 'Dafter', 'Female', 'Maori']
# ['397-16-5372', 'Alonzo', 'Mc Mechan', 'Male', 'Polish']
# ['397-29-8349', 'Madelle', 'Mapledorum', 'Female', 'Tok Pisin']
# ['397-87-8282', 'Kyrstin', 'Waldock', 'Female', 'Belarusian']
# ['399-31-2815', 'Durward', 'Giamitti', 'Male', 'Tok Pisin']
# ['399-63-8810', 'Bobbee', 'Postians', 'Female', 'Papiamento']
# ['399-81-6133', 'Viv', 'Borsay', 'Female', 'Chinese']
# ['400-21-8654', 'Travus', 'Miranda', 'Male', 'Kannada']
# ['400-77-6007', 'Dannie', 'Shurmer', 'Male', 'Tajik']
# ['402-61-3479', 'Mariele', 'Meyrick', 'Female', 'Telugu']
# ['402-65-2055', 'Martie', 'Crawshaw', 'Male', 'Marathi']
# ['402-88-5570', 'Torry', 'Bossons', 'Male', 'Chinese']
# ['403-65-1535', 'Cathy', 'Gabe', 'Female', 'Hiri Motu']
# ['404-57-4023', 'Pattin', 'Jarmain', 'Male', 'Hindi']
# ['405-25-1422', 'Raquel', 'Dukelow', 'Female', 'Gujarati']
# ['406-15-5123', 'Janot', 'Pulhoster', 'Female', 'Dari']
# ['406-24-4867', 'Renaud', 'Fleetwood', 'Male', 'Papiamento']
# ['406-49-0634', 'Lolita', 'Dailey', 'Female', 'Czech']
# ['407-30-0910', 'Gerhard', 'Crielly', 'Male', 'Bislama']
# ['407-80-7367', 'Sigismundo', 'Pothbury', 'Male', 'Latvian']
# ['407-99-6159', 'Flynn', 'Jirasek', 'Male', 'Afrikaans']
# ['408-83-7943', 'Wallie', 'Klosterman', 'Male', 'Hungarian']
# ['408-98-3291', 'Karia', 'Riquet', 'Female', 'Italian']
# ['409-58-2034', 'Fiann', 'Corsar', 'Female', 'Swahili']
# ['409-90-8946', 'Doralia', 'Proughten', 'Female', 'Estonian']
# ['410-38-4237', 'Gibbie', 'Seamer', 'Male', 'Tok Pisin']
# ['410-76-5092', 'Spencer', 'Dallon', 'Male', 'Swati']
# ['411-21-4276', 'Mari', 'Livick', 'Female', 'Pashto']
# ['411-43-4217', 'Cull', 'Noddle', 'Male', 'Spanish']
# ['411-79-4655', 'Caterina', 'Coey', 'Female', 'French']
# ['412-50-9133', 'Dianemarie', 'Withey', 'Female', 'Czech']
# ['412-59-0452', 'Seamus', 'Petrusch', 'Male', 'Spanish']
# ['412-59-8022', 'Brenna', 'Follin', 'Female', 'Gagauz']
# ['412-79-8951', 'Giorgi', 'Sisnett', 'Male', 'Tamil']
# ['413-14-3928', 'Shaine', 'Liebrecht', 'Male', 'Sotho']
# ['413-56-5613', 'Anjanette', 'Carnock', 'Female', 'Nepali']
# ['415-42-0898', 'Karlik', 'Adlam', 'Male', 'Mongolian']
# ['415-74-2251', 'Pattin', 'Greson', 'Male', 'Italian']
# ['416-37-7763', 'Emelia', 'Hancell', 'Female', 'German']
# ['416-38-3607', 'Jerry', 'Christin', 'Male', 'Hebrew']
# ['416-80-6367', 'Myrna', 'Christoffe', 'Female', 'Tok Pisin']
# ['416-87-0469', 'Dannel', 'Whyffen', 'Male', 'Estonian']
# ['418-72-1888', 'Roddy', 'Worman', 'Male', 'Bosnian']
# ['418-99-6659', 'Grenville', 'Gulliver', 'Male', 'Ndebele']
# ['420-46-7789', 'Steffie', 'Britto', 'Female', 'New Zealand Sign Language']
# ['420-52-3813', 'Arnaldo', 'Balsdone', 'Male', 'Zulu']
# ['421-01-2511', 'Mikaela', 'Andrivot', 'Female', 'English']
# ['421-13-9794', 'Minne', 'Measey', 'Female', 'Danish']
# ['421-20-3448', 'Alie', 'Gerauld', 'Female', 'Khmer']
# ['421-88-7316', 'Cherie', 'Yeudall', 'Female', 'Dutch']
# ['422-67-4000', 'Corby', 'Boyington', 'Male', 'Sotho']
# ['423-62-1820', 'Ruddy', 'Ingerson', 'Male', 'Maori']
# ['423-88-4721', 'Trip', 'Postlewhite', 'Male', 'Polish']
# ['424-22-9138', 'Farand', 'Huggon', 'Female', 'Indonesian']
# ['424-91-0692', 'Jeanie', 'Titchard', 'Female', 'Swati']
# ['424-92-0863', 'Halley', 'Mendenhall', 'Female', 'Thai']
# ['426-09-8331', 'Enrico', 'Balentyne', 'Male', 'Arabic']
# ['426-33-4523', 'Bibbie', 'Lardge', 'Female', 'Spanish']
# ['426-52-3410', 'Deeyn', 'Feldberg', 'Female', 'Lithuanian']
# ['426-61-5374', 'Adolph', 'Effemy', 'Male', 'Norwegian']
# ['427-12-4625', 'Ethelin', 'Huck', 'Female', 'Bosnian']
# ['427-36-0095', 'Shandee', 'Hawthorne', 'Female', 'Gujarati']
# ['427-96-6355', 'Fidel', 'Gutierrez', 'Male', 'Yiddish']
# ['428-19-2946', 'Dionne', 'Bibb', 'Female', 'Moldovan']
# ['428-79-0781', 'Mame', 'Criag', 'Female', 'Catalan']
# ['429-43-7811', 'Felice', 'Mound', 'Male', 'Ndebele']
# ['430-27-6236', 'Sergent', 'Tomich', 'Male', 'Tajik']
# ['430-27-8349', 'Boigie', 'Balsdon', 'Male', 'German']
# ['432-25-8923', 'Violetta', 'Remmer', 'Female', 'Swati']
# ['433-08-7855', 'Cleo', 'Sivior', 'Female', 'Latvian']
# ['434-41-2365', 'Obed', 'Podmore', 'Male', 'Georgian']
# ['435-34-0115', 'Chicky', 'Carlos', 'Male', 'Tamil']
# ['438-80-0430', 'Gunilla', 'Navan', 'Female', 'Moldovan']
# ['438-82-1280', 'Salvatore', 'Noirel', 'Male', 'Somali']
# ['440-60-4889', 'Evanne', 'Loosely', 'Female', 'Ndebele']
# ['441-19-1376', 'Harwell', 'Wharf', 'Male', 'Kazakh']
# ['442-15-1994', 'Niven', 'Kaser', 'Male', 'Macedonian']
# ['444-01-3823', 'Cello', 'Caddock', 'Male', 'Spanish']
# ['445-49-0727', 'Bessy', 'Howford', 'Female', 'Indonesian']
# ['445-62-3843', 'Forest', 'MacAughtrie', 'Male', 'Irish Gaelic']
# ['446-16-1946', 'Jacinthe', 'Hackworth', 'Female', 'Albanian']
# ['446-73-1646', 'Pattie', 'Ludwig', 'Female', 'West Frisian']
# ['447-05-5935', 'Artemas', 'Slay', 'Male', 'Somali']
# ['449-38-7421', 'Hakeem', 'Pinke', 'Male', 'Georgian']
# ['450-04-1023', 'Oliver', 'Strathe', 'Male', 'Georgian']
# ['450-36-3771', 'Anette', 'Reast', 'Female', 'Guarana']
# ['450-36-4561', 'Nate', 'Poulglais', 'Male', 'Albanian']
# ['450-45-5021', 'Ailis', 'Allsebrook', 'Female', 'Amharic']
# ['450-56-7231', 'Xavier', 'Garnar', 'Male', 'Danish']
# ['450-96-2075', 'Den', 'Deniset', 'Male', 'Portuguese']
# ['451-34-5996', 'Dolly', 'Pennyman', 'Female', 'Spanish']
# ['451-52-8000', 'Donia', 'Daville', 'Female', 'Burmese']
# ['452-26-9999', 'Donny', 'Garham', 'Male', 'French']
# ['453-99-0644', 'Justen', 'Bloxam', 'Male', 'Nepali']
# ['454-36-4371', 'Bald', 'Beckerleg', 'Male', 'Fijian']
# ['455-67-4513', 'Zedekiah', 'Cayzer', 'Male', 'Quechua']
# ['455-74-3521', 'Nesta', 'Gascone', 'Female', 'Croatian']
# ['455-83-6194', 'Arney', 'Podmore', 'Male', 'Gagauz']
# ['457-55-3869', 'Lotta', 'Maclean', 'Female', 'Swati']
# ['457-57-7890', 'Corey', 'Learned', 'Female', 'Punjabi']
# ['457-97-6863', 'Ray', 'Ledamun', 'Male', 'Czech']
# ['458-97-0499', 'Ginny', "O'Keenan", 'Female', 'Maltese']
# ['459-29-7955', 'Buddy', 'Titmus', 'Male', 'Gujarati']
# ['460-65-0321', 'Katine', 'Rosenstiel', 'Female', 'Macedonian']
# ['461-84-2780', 'Shaun', 'Duff', 'Female', 'Gujarati']
# ['461-88-8139', 'Marion', 'Mitkcov', 'Male', 'German']
# ['464-21-1055', 'Arie', 'Matthieson', 'Male', 'Kashmiri']
# ['464-84-7886', 'Etan', 'Bellsham', 'Male', 'Tswana']
# ['465-96-0362', 'Woody', 'Maw', 'Male', 'Kurdish']
# ['468-88-6064', 'Dante', 'Puddicombe', 'Male', 'Nepali']
# ['469-08-0077', 'Garret', 'Zanussii', 'Male', 'Hungarian']
# ['469-96-1488', 'Euphemia', 'Neggrini', 'Female', 'Guarana']
# ['470-34-5693', 'Hashim', 'Priddie', 'Male', 'Maori']
# ['470-94-7669', 'Julio', 'Lune', 'Male', 'Assamese']
# ['471-28-1745', 'Bernarr', 'Giral', 'Male', 'Sotho']
# ['472-23-0389', 'Valli', 'Khristoforov', 'Female', 'Bosnian']
# ['473-65-7769', 'Aguie', 'Rennix', 'Male', 'Japanese']
# ['474-56-7332', 'Maurine', 'Stopps', 'Female', 'Tswana']
# ['474-95-1775', 'Ivette', 'Whitewood', 'Female', 'Korean']
# ['475-15-5394', 'Orson', 'Lafferty', 'Male', 'Kyrgyz']
# ['475-24-1840', 'Malachi', 'Skittrell', 'Male', 'Azeri']
# ['475-47-5055', 'Casey', 'Worrill', 'Male', 'Lithuanian']
# ['476-27-0948', 'Laurette', 'Kearney', 'Female', 'West Frisian']
# ['476-68-8276', 'Geoffrey', 'Whisker', 'Male', 'Czech']
# ['477-30-0077', 'Giulio', 'Bilsland', 'Male', 'Macedonian']
# ['478-14-8720', 'Brittan', 'Vaen', 'Female', 'Hindi']
# ['479-49-8804', 'Serene', 'Giannotti', 'Female', 'Latvian']
# ['480-53-4039', 'Reg', 'Waskett', 'Male', 'Chinese']
# ['481-10-0098', 'Kitti', 'Morrad', 'Female', 'Kashmiri']
# ['481-87-3503', 'Delano', 'Mitchall', 'Male', 'Northern Sotho']
# ['482-88-7624', 'Corbet', 'Paireman', 'Male', 'Finnish']
# ['484-06-9645', 'Clay', 'Suttle', 'Male', 'Fijian']
# ['484-36-9255', 'Kristos', 'Garard', 'Male', 'Irish Gaelic']
# ['484-75-5799', 'Rhea', 'Braniff', 'Female', 'Somali']
# ['485-39-0911', 'Rea', 'Buzek', 'Female', 'Croatian']
# ['485-79-8123', 'Tish', 'Kemston', 'Female', 'Khmer']
# ['486-87-1145', 'Elyn', 'Djokovic', 'Female', 'French']
# ['488-02-2147', 'Gannon', 'Le Strange', 'Male', 'Malayalam']
# ['488-12-7780', 'Cynthea', 'Ioannou', 'Female', 'Yiddish']
# ['489-57-4785', 'Waldemar', 'Coast', 'Male', 'Korean']
# ['491-36-8648', 'Rice', 'Revans', 'Male', 'New Zealand Sign Language']
# ['491-38-3802', 'Marcella', 'Paolinelli', 'Female', 'Swati']
# ['491-89-4895', 'Orv', 'Kelland', 'Male', 'Belarusian']
# ['491-90-1059', 'Mic', 'Chaunce', 'Male', 'Afrikaans']
# ['493-09-7972', 'Agretha', 'Wickes', 'Female', 'French']
# ['495-15-7369', 'Lowrance', 'Prandin', 'Male', 'Ndebele']
# ['495-62-6374', 'Nevsa', 'Boarder', 'Female', 'Czech']
# ['495-64-2134', 'Noami', 'Schuck', 'Female', 'Nepali']
# ['495-89-7170', 'Allina', 'Caldecot', 'Female', 'New Zealand Sign Language']
# ['497-69-5399', 'Wanids', 'Bengoechea', 'Female', 'German']
# ['497-73-2347', 'Rana', 'Duhig', 'Female', 'Indonesian']
# ['499-07-4759', 'Kizzee', 'MacTrustam', 'Female', 'Norwegian']
# ['499-31-5371', 'Valenka', 'Triplett', 'Female', 'Somali']
# ['499-42-7583', 'Rafaellle', 'Caush', 'Male', 'Kashmiri']
# ['499-44-2439', 'Ediva', 'Flucks', 'Female', 'French']
# ['499-99-6990', 'Dewie', 'Madge', 'Male', 'Sotho']
# ['500-14-7051', 'Giulio', 'Pilley', 'Male', 'Maltese']
# ['500-41-0658', 'Jobie', 'Pyvis', 'Female', 'Zulu']
# ['500-45-7881', 'Stan', 'Drinkall', 'Male', 'Tetum']
# ['500-71-6995', 'Orazio', 'Izakoff', 'Male', 'Romanian']
# ['502-07-7030', 'Twyla', 'Klaessen', 'Female', 'Persian']
# ['502-60-9632', 'Ibrahim', 'Eddleston', 'Male', 'New Zealand Sign Language']
# ['504-41-5919', 'Cullen', 'Christin', 'Male', 'Montenegrin']
# ['505-37-1520', 'Adams', 'Watford', 'Male', 'Azeri']
# ['505-88-6030', 'Derby', "O'Kerin", 'Male', 'Dhivehi']
# ['506-02-3957', 'Tilly', 'Joubert', 'Female', 'Danish']
# ['507-40-9429', 'Forster', 'Dronsfield', 'Male', 'Gagauz']
# ['507-67-9726', 'Sinclare', 'Swatheridge', 'Male', 'Croatian']
# ['507-99-2334', 'Sunny', 'Vasilik', 'Male', 'Kurdish']
# ['508-54-3168', 'Helaine', 'Accombe', 'Female', 'Dutch']
# ['509-39-1128', 'Carie', 'Leneham', 'Female', 'Telugu']
# ['509-46-4927', 'Nickie', 'Dabes', 'Female', 'Sotho']
# ['510-34-4633', 'Alie', 'Jennaway', 'Female', 'Indonesian']
# ['511-28-0914', 'Gardie', 'Ravenshaw', 'Male', 'Persian']
# ['511-95-4867', 'Ethelda', 'Helversen', 'Female', 'Zulu']
# ['513-68-2140', 'Hussein', 'Filov', 'Male', 'Greek']
# ['515-47-1848', 'Darla', 'Leftridge', 'Female', 'Finnish']
# ['517-05-0600', 'Lindy', 'Losz', 'Female', 'Kurdish']
# ['519-15-9299', 'Hamid', 'Angier', 'Male', 'Chinese']
# ['519-58-0341', 'Barny', 'Matiashvili', 'Male', 'Lao']
# ['520-81-0974', 'Ofella', 'Navarro', 'Female', 'Kurdish']
# ['521-82-5436', 'Barb', 'Riolfi', 'Female', 'Swedish']
# ['522-54-3565', 'Geri', 'Vigar', 'Male', 'Quechua']
# ['523-07-2359', 'Tanney', 'Izsak', 'Male', 'Haitian Creole']
# ['523-44-3601', 'Goldina', 'Di Claudio', 'Female', 'Spanish']
# ['523-53-2420', 'Amerigo', 'Lipyeat', 'Male', 'Tsonga']
# ['523-85-4846', 'Noella', 'Samsonsen', 'Female', 'Kurdish']
# ['523-91-3280', 'Gordie', 'Billin', 'Male', 'Swati']
# ['524-28-4450', 'Jake', 'Klimpt', 'Male', 'Somali']
# ['526-45-2767', 'Kayle', 'Milsom', 'Female', 'Dhivehi']
# ['526-98-9361', 'Cathe', 'Allsupp', 'Female', 'Marathi']
# ['527-55-3736', 'Auguste', 'Hammersley', 'Female', 'Malayalam']
# ['527-72-3566', 'Colin', 'Paddington', 'Male', 'Pashto']
# ['528-10-7051', 'Leonie', 'Sondon', 'Female', 'Romanian']
# ['528-26-2803', 'See', 'Ettery', 'Male', 'Albanian']
# ['531-38-1945', 'Eveleen', 'Mignot', 'Female', 'Japanese']
# ['531-53-5021', 'Deerdre', 'Chaudron', 'Female', 'Oriya']
# ['531-67-4340', 'Ody', 'Blaxley', 'Male', 'Bosnian']
# ['531-79-0948', 'Britney', 'Sweeten', 'Female', 'Indonesian']
# ['532-36-4145', 'Dorry', 'Ditty', 'Female', 'Kannada']
# ['534-50-6091', 'Florencia', 'Abramof', 'Female', 'Arabic']
# ['534-68-0554', 'Ira', 'Swanne', 'Female', 'Chinese']
# ['534-86-8290', 'Ester', 'Jepson', 'Female', 'Albanian']
# ['535-66-3671', 'Felisha', 'Blackden', 'Female', 'Hiri Motu']
# ['536-23-6599', 'Laughton', 'Iozefovich', 'Male', 'Tok Pisin']
# ['537-46-3891', 'Clay', 'Bapty', 'Male', 'Burmese']
# ['538-46-6131', 'Steward', 'Glennard', 'Male', 'Papiamento']
# ['538-68-5142', 'Grantley', 'Berthel', 'Male', 'Nepali']
# ['541-54-1497', 'Katuscha', 'Jovis', 'Female', 'Irish Gaelic']
# ['542-74-6343', 'Raleigh', 'Tamsett', 'Male', 'Kurdish']
# ['543-38-7657', 'Kaja', 'Divisek', 'Female', 'Estonian']
# ['543-61-1911', 'Alisa', 'Dacca', 'Female', 'Romanian']
# ['543-67-6841', 'Rosemonde', 'Shelp', 'Female', 'Burmese']
# ['545-66-8802', 'Cassey', 'Gammage', 'Female', 'English']
# ['547-35-4478', 'Halsy', 'Goddard', 'Male', 'Bosnian']
# ['548-72-2840', 'Vite', 'Burnsall', 'Male', 'Sotho']
# ['549-90-2887', 'Brunhilda', 'Eilhermann', 'Female', 'Papiamento']
# ['551-57-4018', 'Magdalena', 'Morland', 'Female', 'Gagauz']
# ['551-92-2534', 'Merrill', 'Purviss', 'Male', 'Armenian']
# ['552-61-0289', 'Tom', 'Wilmut', 'Male', 'Pashto']
# ['553-77-2419', 'Ray', 'Warrick', 'Male', 'Amharic']
# ['555-99-5216', 'Ludovico', "O'Cassidy", 'Male', 'English']
# ['556-13-4040', 'Mignonne', 'Beckett', 'Female', 'Catalan']
# ['557-28-9953', 'Morie', 'Roon', 'Male', 'Kurdish']
# ['557-33-7476', 'Dean', 'Grimoldby', 'Male', 'Burmese']
# ['557-77-8703', 'Alayne', 'Shackleford', 'Female', 'Arabic']
# ['558-37-7838', 'Drucie', 'Andrick', 'Female', 'New Zealand Sign Language']
# ['559-33-6365', 'Lew', 'Barbara', 'Male', 'Kashmiri']
# ['559-54-7102', 'Dareen', 'Stoneley', 'Female', 'Arabic']
# ['560-06-2687', 'Sidnee', 'Potts', 'Male', 'Malayalam']
# ['561-96-2313', 'Torin', 'Cockland', 'Male', 'Sotho']
# ['561-98-2281', 'Barton', 'Andrichuk', 'Male', 'Bosnian']
# ['562-62-6370', 'Lewes', "O'Caine", 'Male', 'Hungarian']
# ['563-21-6857', 'Ambrose', 'Stiegers', 'Male', 'Zulu']
# ['563-27-3427', 'Pembroke', 'La Padula', 'Male', 'German']
# ['564-89-9688', 'Karoly', 'Collen', 'Female', 'Albanian']
# ['566-56-7324', 'Mattheus', 'Braidwood', 'Male', 'Tetum']
# ['566-62-0141', 'Tiffanie', 'McNamee', 'Female', 'Polish']
# ['567-02-8700', 'Cornelia', 'Trowle', 'Female', 'Dari']
# ['567-82-8701', 'Bathsheba', 'Ainge', 'Female', 'Montenegrin']
# ['569-26-2487', 'Yance', 'Mumby', 'Male', 'Danish']
# ['569-52-7923', 'Rahel', 'Aleshkov', 'Female', 'Georgian']
# ['570-01-5640', 'Nickolas', 'Crosdill', 'Male', 'Tetum']
# ['570-86-3275', 'Rab', 'Vuitte', 'Male', 'Swahili']
# ['571-12-4962', 'Audie', 'Legrice', 'Female', 'Lithuanian']
# ['572-82-5200', 'Walsh', 'Varah', 'Male', 'Japanese']
# ['573-94-0348', 'Sherm', 'Critten', 'Male', 'Dari']
# ['573-97-4729', 'Torey', 'Forcade', 'Female', 'Indonesian']
# ['574-60-0475', 'Gale', 'Porson', 'Male', 'Icelandic']
# ['574-91-3682', 'Marlon', 'Lafayette', 'Male', 'Somali']
# ['576-18-1075', 'Alexandro', 'Edgecombe', 'Male', 'Telugu']
# ['576-41-7443', 'Abba', 'Fall', 'Male', 'Indonesian']
# ['578-02-0932', 'Lalo', 'Grigoroni', 'Male', 'Polish']
# ['578-58-6435', 'Gavin', 'Daish', 'Male', 'Kazakh']
# ['579-87-4014', 'Feliza', 'Hendrickson', 'Female', 'Bulgarian']
# ['581-15-8015', 'Ave', 'Isaksson', 'Male', 'Dhivehi']
# ['581-95-7591', 'Merilee', 'Wigin', 'Female', 'Norwegian']
# ['582-71-1805', 'Mel', 'Marvin', 'Male', 'Maltese']
# ['583-61-3519', 'Reagen', 'Yelden', 'Male', 'Northern Sotho']
# ['583-76-7497', 'Wildon', 'Tunbridge', 'Male', 'Mongolian']
# ['585-03-2819', 'Breanne', 'Gorelli', 'Female', 'Tamil']
# ['585-96-1853', 'Jone', 'Sherwyn', 'Male', 'Gujarati']
# ['586-85-4199', 'Gisela', 'Foulser', 'Female', 'Albanian']
# ['587-94-0609', 'Fancy', 'Frift', 'Female', 'Chinese']
# ['588-48-7326', 'Sid', 'Colkett', 'Male', 'Northern Sotho']
# ['589-15-0686', 'Corabelle', 'Northin', 'Female', 'Sotho']
# ['591-02-4614', 'Linnie', 'Marzelli', 'Female', 'Kashmiri']
# ['591-09-5002', 'Arie', 'Winchcombe', 'Male', 'Dzongkha']
# ['591-34-2920', 'Woodman', 'Finley', 'Male', 'Ndebele']
# ['592-23-4343', 'Iona', 'Garron', 'Female', 'Catalan']
# ['594-37-6620', 'Bax', 'McLleese', 'Male', 'Maltese']
# ['594-80-1212', 'Berti', 'Ealden', 'Female', 'Tajik']
# ['595-51-3047', 'Haley', 'Critchley', 'Female', 'Ndebele']
# ['595-67-1091', 'Odette', 'Delue', 'Female', 'Filipino']
# ['597-45-6867', 'Boris', 'Selwood', 'Male', 'Tajik']
# ['597-53-1918', 'Tilda', 'Cheales', 'Female', 'Azeri']
# ['597-63-4107', 'Fairfax', 'De Blase', 'Male', 'Gujarati']
# ['598-39-5585', 'Maritsa', 'Brecher', 'Female', 'Maori']
# ['599-56-9050', 'Letti', 'Trappe', 'Female', 'Maori']
# ['599-69-3085', 'Luz', 'Jeffcoate', 'Female', 'Kyrgyz']
# ['599-69-5584', 'Concordia', 'Grassot', 'Female', 'Czech']
# ['600-52-7214', 'Patty', 'Ashurst', 'Male', 'Latvian']
# ['601-01-2163', 'Dominica', 'Muehler', 'Female', 'Kyrgyz']
# ['601-04-5606', 'Korrie', 'Brookfield', 'Female', 'Greek']
# ['601-06-5384', 'Lyle', 'Order', 'Male', 'Tajik']
# ['603-31-3174', 'Adelind', 'Pautard', 'Female', 'English']
# ['603-34-9733', 'Joellen', 'Doddrell', 'Female', 'Lithuanian']
# ['603-76-5257', 'Issiah', 'Bordis', 'Male', 'Spanish']
# ['604-19-5709', 'Alberto', 'Grog', 'Male', 'Dari']
# ['605-15-8306', 'Graehme', 'De Maine', 'Male', 'Catalan']
# ['605-26-7064', 'Howey', 'Acome', 'Male', 'Finnish']
# ['605-55-6033', 'Roddie', 'Kolis', 'Male', 'German']
# ['608-13-9301', 'Gradey', 'Duval', 'Male', 'Hebrew']
# ['612-27-1398', 'Lucian', 'Whight', 'Male', 'Haitian Creole']
# ['612-30-5754', 'Archibold', 'Van de Castele', 'Male', 'Tamil']
# ['615-38-6466', 'Roderigo', 'Caughan', 'Male', 'Oriya']
# ['617-38-3504', 'Toby', 'Hugnot', 'Female', 'Maori']
# ['617-71-4058', 'Lynsey', 'Creser', 'Female', 'Gujarati']
# ['618-35-5798', 'Izzy', 'Helliar', 'Male', 'Indonesian']
# ['620-81-4914', 'Clea', 'Baldazzi', 'Female', 'Catalan']
# ['623-98-4252', 'Kort', 'Kellie', 'Male', 'Italian']
# ['624-99-0933', 'Perrine', 'Bason', 'Female', 'Estonian']
# ['625-84-8454', 'Francois', 'Lardner', 'Male', 'Kashmiri']
# ['627-36-1126', 'Milzie', 'Steabler', 'Female', 'Tetum']
# ['627-91-0537', 'Georgie', 'Tadd', 'Male', 'Croatian']
# ['629-10-9201', 'Morie', 'Addams', 'Male', 'Papiamento']
# ['629-13-0131', 'Gregorius', 'Hill', 'Male', 'Lao']
# ['629-54-4455', 'Abram', 'Jones', 'Male', 'Croatian']
# ['629-91-9506', 'Dionysus', 'Twentyman', 'Male', 'Indonesian']
# ['630-21-7841', 'Julieta', 'Kloss', 'Female', 'Latvian']
# ['631-44-9168', 'Brooks', 'Edridge', 'Male', 'Kazakh']
# ['631-72-9770', 'Benji', 'Barnsley', 'Male', 'Guarana']
# ['633-96-5921', 'Tynan', 'Duthie', 'Male', 'Nepali']
# ['634-42-8798', 'Tomasine', 'Dron', 'Female', 'English']
# ['634-90-4851', 'Maia', 'Nornasell', 'Female', 'Pashto']
# ['635-99-3249', 'Jennifer', 'Audry', 'Female', 'Italian']
# ['637-74-3365', 'Jarrett', 'Tunnicliffe', 'Male', 'Luxembourgish']
# ['639-08-7138', 'Betsey', 'Wimbridge', 'Female', 'Telugu']
# ['640-86-4661', 'Ignacius', 'Kipling', 'Male', 'Portuguese']
# ['641-11-8353', 'Angel', 'Godthaab', 'Female', 'Bislama']
# ['643-10-4736', 'Konstanze', 'MacCawley', 'Female', 'Dzongkha']
# ['644-68-2955', 'Catrina', 'Gerardin', 'Female', 'Gagauz']
# ['644-70-8292', 'Glyn', 'Mc Giffin', 'Female', 'Zulu']
# ['645-33-6872', 'Dmitri', 'Varden', 'Male', 'Bosnian']
# ['646-69-6845', 'Joe', 'Mabee', 'Male', 'Fijian']
# ['647-24-7807', 'Jammal', 'Dametti', 'Male', 'Mongolian']
# ['647-82-5575', 'Burton', "D'Ambrosio", 'Male', 'Spanish']
# ['648-50-5566', 'Nilson', 'Kurth', 'Male', 'Armenian']
# ['648-92-3395', 'Benedetto', 'McBean', 'Male', 'Lao']
# ['650-63-9841', 'Evanne', 'Ibeson', 'Female', 'Korean']
# ['650-73-2431', 'Henrietta', 'Carnegie', 'Female', 'Bislama']
# ['650-89-8244', 'Goldarina', 'Rodrigo', 'Female', 'Maori']
# ['651-83-5203', 'Putnem', 'Buddle', 'Male', 'Georgian']
# ['652-46-3664', 'Benson', 'Ianelli', 'Male', 'Romanian']
# ['652-96-9901', 'Clareta', 'Blagburn', 'Female', 'Tok Pisin']
# ['653-23-1607', 'Noah', 'Lodwig', 'Male', 'Moldovan']
# ['653-49-0510', 'Dillie', 'Bleeze', 'Male', 'Burmese']
# ['654-61-1601', 'Vinnie', 'Buzzing', 'Female', 'Dhivehi']
# ['654-68-3903', 'Hanni', 'Fairleigh', 'Female', 'Dutch']
# ['654-75-3300', 'Korney', 'Chiplin', 'Female', 'Chinese']
# ['655-98-7788', 'Gabriellia', 'Lewer', 'Female', 'Tsonga']
# ['656-92-1337', 'Dianemarie', 'Bwye', 'Female', 'Maori']
# ['658-21-3014', 'Star', 'Crummey', 'Female', 'Norwegian']
# ['658-34-0029', 'Chrysler', 'Bastistini', 'Female', 'Tamil']
# ['658-97-8544', 'Hamish', 'Redit', 'Male', 'Tswana']
# ['659-43-4520', 'Alessandra', 'Rouf', 'Female', 'Fijian']
# ['667-57-3442', 'Rudy', 'Tommasuzzi', 'Male', 'Khmer']
# ['667-87-7090', 'Teena', 'Webb-Bowen', 'Female', 'Hiri Motu']
# ['669-12-9323', 'Peter', 'Ketteman', 'Male', 'Hiri Motu']
# ['669-83-8959', 'Corney', 'Semerad', 'Male', 'Zulu']
# ['670-56-7817', 'Stephen', 'Keinrat', 'Male', 'Hiri Motu']
# ['670-66-6403', 'Marje', 'Durdle', 'Female', 'Japanese']
# ['670-67-9679', 'Emili', 'Alexis', 'Female', 'Ndebele']
# ['670-89-3434', 'Elvina', 'Scowcroft', 'Female', 'Albanian']
# ['671-16-1411', 'Elsa', 'Dawes', 'Female', 'Swahili']
# ['671-71-9470', 'Billie', 'Spittal', 'Female', 'Catalan']
# ['671-76-8792', 'Melisse', 'Extil', 'Female', 'Punjabi']
# ['672-60-8782', 'Sharia', 'Gavrielly', 'Female', 'Lao']
# ['673-83-5713', 'Bartholomeo', 'Stote', 'Male', 'Icelandic']
# ['674-64-0219', 'Abner', 'Hoyle', 'Male', 'Latvian']
# ['675-31-0953', 'Mychal', 'Legerwood', 'Male', 'Tamil']
# ['675-41-4272', 'Kevan', 'Grishechkin', 'Male', 'English']
# ['678-60-4630', 'Mortie', 'Dunbobin', 'Male', 'Malay']
# ['679-22-5301', 'Avigdor', 'Galway', 'Male', 'Afrikaans']
# ['680-11-2707', 'Letta', 'Wishart', 'Female', 'Chinese']
# ['681-72-2644', 'Rosie', 'Aartsen', 'Female', 'Luxembourgish']
# ['682-06-8032', 'Gray', 'Clemencon', 'Female', 'Japanese']
# ['682-68-1965', 'Benedict', 'Nealy', 'Male', 'Montenegrin']
# ['682-73-2035', 'Juditha', 'Bowra', 'Female', 'Haitian Creole']
# ['684-49-8302', 'Jeddy', 'Ruppertz', 'Male', 'Tswana']
# ['684-95-5429', 'Ajay', 'Layne', 'Female', 'Hungarian']
# ['686-22-5917', 'Aleta', 'Abad', 'Female', 'Latvian']
# ['687-27-5241', 'Hildegarde', 'Crosoer', 'Female', 'Marathi']
# ['687-98-6782', 'Jamal', 'Jagg', 'Male', 'Montenegrin']
# ['689-25-7868', 'Kalil', 'North', 'Male', 'Telugu']
# ['690-61-7133', 'Lindsay', 'Henzley', 'Male', 'Montenegrin']
# ['692-31-0697', 'Blondell', 'Wrigley', 'Female', 'Persian']
# ['692-38-3792', 'Mart', 'Wheldon', 'Male', 'Indonesian']
# ['694-86-1783', 'Griffie', 'Rosenbush', 'Male', 'Montenegrin']
# ['695-51-8778', 'Farly', 'Benjamin', 'Male', 'Burmese']
# ['696-10-4037', 'Marcela', 'Stoade', 'Female', 'Lithuanian']
# ['696-45-6436', 'Enrico', 'Rubinowitz', 'Male', 'Lao']
# ['698-76-6576', 'Tom', 'Crosscombe', 'Male', 'Northern Sotho']
# ['698-94-3612', 'Duke', 'Brobak', 'Male', 'Gujarati']
# ['699-17-4497', 'Eolanda', 'Shine', 'Female', 'Estonian']
# ['700-49-1211', 'Julie', 'Houseley', 'Female', 'Tok Pisin']
# ['700-73-0102', 'Forester', 'Blinerman', 'Male', 'Finnish']
# ['701-06-8590', 'Ralf', 'Aliman', 'Male', 'Aymara']
# ['701-53-6262', 'Devon', 'Wane', 'Female', 'Maori']
# ['702-02-6635', 'Sherwood', 'Jeffreys', 'Male', 'Dhivehi']
# ['702-67-5109', 'Gabi', 'Swallow', 'Female', 'Sotho']
# ['704-72-4439', 'Euell', "O'Leagham", 'Male', 'Yiddish']
# ['705-15-6989', 'Minta', 'Beecroft', 'Female', 'Maltese']
# ['705-98-0229', 'Vic', 'Elsley', 'Male', 'Czech']
# ['709-73-6600', 'Stillman', 'Fairbrass', 'Male', 'German']
# ['714-55-2111', 'Elysee', 'Bardsley', 'Female', 'Lao']
# ['715-89-3174', 'Nicholas', 'Crack', 'Male', 'Greek']
# ['717-91-7919', 'Ches', 'Rablan', 'Male', 'Thai']
# ['718-89-7490', 'Jessamyn', 'Hamill', 'Female', 'Icelandic']
# ['718-91-6110', 'Emory', 'Ambrus', 'Male', 'Papiamento']
# ['719-05-6621', 'Susanne', 'Dilger', 'Female', 'Punjabi']
# ['719-96-8751', 'Sallie', 'Gosnold', 'Female', 'Catalan']
# ['720-63-4381', 'Jayson', 'Gatrell', 'Male', 'Haitian Creole']
# ['722-30-1903', 'Nowell', 'Ambler', 'Male', 'Korean']
# ['722-64-9283', 'Dionisio', 'Peddar', 'Male', 'Kazakh']
# ['723-36-6692', 'Ivan', 'Musla', 'Male', 'Haitian Creole']
# ['724-90-0728', 'Guido', 'Southby', 'Male', 'Hindi']
# ['725-23-0793', 'Faber', 'Houseley', 'Male', 'Dzongkha']
# ['727-48-6769', 'Ervin', 'Duncklee', 'Male', 'Zulu']
# ['727-82-4383', 'Agosto', 'Cudbertson', 'Male', 'Greek']
# ['728-54-5322', 'Berti', 'Bertelet', 'Female', 'German']
# ['729-95-1691', 'Marion', 'Danson', 'Female', 'Zulu']
# ['731-22-8474', 'Hatti', 'Dzeniskevich', 'Female', 'Punjabi']
# ['733-29-1354', 'Marcelo', 'Bannard', 'Male', 'Dzongkha']
# ['733-78-5243', 'Gallard', 'Schapiro', 'Male', 'Albanian']
# ['735-42-4024', 'Peirce', 'Jeeks', 'Male', 'Punjabi']
# ['736-60-2127', 'Constanta', 'Round', 'Female', 'Estonian']
# ['737-89-8983', 'Katherine', 'Kuschke', 'Female', 'Tajik']
# ['738-38-4091', 'Armstrong', 'Dykes', 'Male', 'Haitian Creole']
# ['738-65-3635', 'Shaina', 'Getsham', 'Female', 'Spanish']
# ['740-64-7874', 'Ethan', 'Meiklejohn', 'Male', 'Maori']
# ['741-53-2153', 'Rodie', 'Simakov', 'Female', 'Czech']
# ['741-56-7694', 'Arnold', 'Duchateau', 'Male', 'Hebrew']
# ['741-90-1249', 'Kesley', 'Standbrook', 'Female', 'Swahili']
# ['743-75-2371', 'Jodee', 'Lintin', 'Female', 'Dzongkha']
# ['743-87-2936', 'Hirsch', 'Mee', 'Male', 'Finnish']
# ['744-87-2990', 'Swen', 'Le Surf', 'Male', 'Persian']
# ['745-19-1777', 'Dannel', 'Down', 'Male', 'Polish']
# ['746-55-1405', 'Cornall', 'Hegel', 'Male', 'Albanian']
# ['747-12-8456', 'Spense', 'Cicchinelli', 'Male', 'Fijian']
# ['749-85-8879', 'Ferdinand', 'Lambrook', 'Male', 'French']
# ['753-94-0630', 'Garrett', 'Peron', 'Male', 'Punjabi']
# ['753-98-5796', 'Charlena', 'Cleve', 'Female', 'New Zealand Sign Language']
# ['754-28-9729', 'Grata', 'Jiroudek', 'Female', 'Aymara']
# ['754-49-4659', 'Cecilla', 'Dutnall', 'Female', 'Latvian']
# ['755-08-4000', 'Domenic', 'Symes', 'Male', 'Italian']
# ['756-40-2283', 'Paten', 'Senior', 'Male', 'Malay']
# ['758-20-5576', 'Kathrine', 'Amar', 'Female', 'Croatian']
# ['761-01-2227', 'Shandy', 'Alasdair', 'Female', 'Hebrew']
# ['761-64-5650', 'Elton', 'Castelin', 'Male', 'Norwegian']
# ['762-43-8029', 'Gill', 'Wilford', 'Female', 'Malay']
# ['763-09-1587', 'Yasmeen', 'Vaskin', 'Female', 'Lithuanian']
# ['764-93-2248', 'Maure', 'Verrillo', 'Female', 'Spanish']
# ['765-35-8117', 'Bernelle', 'Vinten', 'Female', 'German']
# ['765-45-5973', 'Hastings', 'Merrell', 'Male', 'Swedish']
# ['765-87-9144', 'Pandora', 'Paull', 'Female', 'Tswana']
# ['767-05-4859', 'Dennison', 'Tournay', 'Male', 'Catalan']
# ['767-55-6767', 'Glen', 'Cater', 'Female', 'Finnish']
# ['768-54-5764', 'Cash', 'Bodman', 'Male', 'Dutch']
# ['768-74-8540', 'Karee', 'Bleier', 'Female', 'Tajik']
# ['770-61-8252', 'Elbertina', 'Colls', 'Female', 'Chinese']
# ['771-20-6900', 'Alejandra', 'Tevlin', 'Female', 'Greek']
# ['771-71-0505', 'Romona', 'Meikle', 'Female', 'New Zealand Sign Language']
# ['773-21-9639', 'Brittney', 'Byart', 'Female', 'Tok Pisin']
# ['773-53-7438', 'Flo', 'Sirmond', 'Female', 'Khmer']
# ['773-82-1734', 'Maris', 'Currin', 'Female', 'Armenian']
# ['774-08-5376', 'Pam', 'Matterface', 'Female', 'Swahili']
# ['775-09-9949', 'Orlando', 'Gresley', 'Male', 'Danish']
# ['777-05-1491', 'Devora', 'Ashbridge', 'Female', 'Somali']
# ['777-68-2978', 'Mignon', 'Skottle', 'Female', 'Northern Sotho']
# ['777-94-4586', 'Siward', 'Blues', 'Male', 'Thai']
# ['778-74-8262', 'Sonia', 'Grishakin', 'Female', 'Bulgarian']
# ['779-59-1449', 'Gertrude', 'Ledamun', 'Female', 'Hungarian']
# ['780-69-8282', 'Sibeal', 'Dawney', 'Female', 'Czech']
# ['781-88-2076', 'Gelya', 'Stell', 'Female', 'Czech']
# ['782-46-9660', 'Malina', 'Julyan', 'Female', 'Burmese']
# ['782-60-6848', 'Jehu', 'Scholig', 'Male', 'Polish']
# ['783-22-9258', 'Modestine', 'Cuttings', 'Female', 'Assamese']
# ['784-88-0730', 'Baxie', 'Judd', 'Male', 'Maltese']
# ['785-14-5978', 'Trista', 'Watkinson', 'Female', 'Moldovan']
# ['786-56-3561', 'Wait', 'Boyda', 'Male', 'Norwegian']
# ['786-63-6223', 'Adham', 'Toope', 'Male', 'Belarusian']
# ['787-05-9008', 'Ricki', 'Jurges', 'Female', 'Arabic']
# ['787-09-5697', 'Chelsea', 'Pashby', 'Female', 'Northern Sotho']
# ['787-10-7877', 'Torrence', 'Tapping', 'Male', 'Hiri Motu']
# ['788-15-2625', 'Drusilla', 'Bannester', 'Female', 'Gujarati']
# ['789-70-1821', 'Denni', 'De Biasio', 'Female', 'Azeri']
# ['790-04-1283', 'Christyna', 'Morrissey', 'Female', 'Quechua']
# ['792-71-8046', 'Carly', 'Hazley', 'Female', 'Guarana']
# ['794-24-3802', 'Esther', 'Sayton', 'Female', 'Somali']
# ['795-56-6486', 'Stevena', 'Vatcher', 'Female', 'Gagauz']
# ['795-77-5263', 'Burty', 'Frosdick', 'Male', 'Marathi']
# ['797-05-2289', 'Fanchon', 'Petrushanko', 'Female', 'Finnish']
# ['797-25-9814', 'Aleksandr', 'Swalwell', 'Male', 'Pashto']
# ['797-65-2382', 'Marianne', 'Huccaby', 'Female', 'Swedish']
# ['797-87-7992', 'Lonna', 'Plumridge', 'Female', 'Armenian']
# ['798-34-1082', 'Henka', 'Synder', 'Female', 'Italian']
# ['798-65-5644', 'Irita', 'Heady', 'Female', 'Montenegrin']
# ['800-06-9721', 'Carter', 'Waldron', 'Male', 'Estonian']
# ['801-08-8313', 'Aida', 'Whitemarsh', 'Female', 'Chinese']
# ['801-92-6460', 'Levi', 'Downgate', 'Male', 'Belarusian']
# ['801-99-2773', 'Justinian', 'Carlesso', 'Male', 'Japanese']
# ['804-46-0617', 'Geneva', 'Crinion', 'Female', 'Hungarian']
# ['807-13-5922', 'Vivi', 'Edinboro', 'Female', 'Sotho']
# ['807-24-6202', 'Lanette', 'Elvins', 'Female', 'Hiri Motu']
# ['807-25-6136', 'Sammy', 'Linnard', 'Female', 'Dutch']
# ['807-35-8936', 'Georgi', 'Widd', 'Male', 'Afrikaans']
# ['807-50-8539', 'Jaquith', 'Erdes', 'Female', 'Dhivehi']
# ['807-60-5615', 'Michale', 'Druery', 'Male', 'Dhivehi']
# ['808-55-8658', 'Ursulina', 'Kunze', 'Female', 'Chinese']
# ['808-80-2542', 'Gustaf', 'Hullot', 'Male', 'Persian']
# ['811-65-2750', 'Minetta', 'Dusting', 'Female', 'Spanish']
# ['812-11-9403', 'Carmina', 'Turnell', 'Female', 'West Frisian']
# ['813-42-4142', 'Killy', 'Threadgould', 'Male', 'Polish']
# ['813-47-5215', 'Willi', 'Collet', 'Male', 'Gujarati']
# ['815-83-0300', 'Romeo', 'Rayworth', 'Male', 'Thai']
# ['816-31-3858', 'Elvera', 'Walmsley', 'Female', 'Montenegrin']
# ['816-47-4782', 'Wilmer', 'Maides', 'Male', 'Aymara']
# ['816-90-2049', 'Berry', 'Delagnes', 'Female', 'Bengali']
# ['817-04-1950', 'Fletcher', 'McGrouther', 'Male', 'Albanian']
# ['817-25-7437', 'Randall', 'Fibbitts', 'Male', 'Yiddish']
# ['817-80-8930', 'Lib', 'Skein', 'Female', 'Arabic']
# ['818-61-0770', 'Stanly', 'Casseldine', 'Male', 'Belarusian']
# ['819-52-5886', 'Paulette', 'McAree', 'Female', 'Arabic']
# ['819-64-1414', 'Malynda', 'Hundall', 'Female', 'Filipino']
# ['820-96-1105', 'Andy', 'Sayce', 'Female', 'Pashto']
# ['822-05-9037', 'Meggi', 'Mapes', 'Female', 'Moldovan']
# ['822-30-4861', 'Phyllis', 'Cronk', 'Female', 'Fijian']
# ['823-27-0762', 'Marten', 'McCord', 'Male', 'Indonesian']
# ['823-75-5753', 'Thibaut', 'Van Schafflaer', 'Male', 'Chinese']
# ['824-89-4169', 'Tamqrah', 'Goroni', 'Female', 'Swedish']
# ['826-97-8029', 'Llewellyn', 'Shimwell', 'Male', 'Belarusian']
# ['827-62-4599', 'Phyllys', 'Akast', 'Female', 'Armenian']
# ['830-23-1573', 'Carine', 'Abramin', 'Female', 'Bislama']
# ['831-44-3286', 'Leesa', 'Finci', 'Female', 'Nepali']
# ['833-01-1428', 'Ashlan', 'Zannotti', 'Female', 'Finnish']
# ['835-54-3785', 'Nathaniel', 'Wegman', 'Male', 'Azeri']
# ['836-40-1837', 'Brocky', 'Kewzick', 'Male', 'Armenian']
# ['836-99-3309', 'Cobby', 'Mutter', 'Male', 'Georgian']
# ['837-76-5619', 'Alleyn', 'Parade', 'Male', 'Croatian']
# ['838-69-1351', 'Alwin', 'Hazzard', 'Male', 'Kannada']
# ['840-41-7929', 'Sherlock', 'Pinshon', 'Male', 'Khmer']
# ['841-64-8517', 'Hugues', 'Kenealy', 'Male', 'Korean']
# ['842-90-7557', 'Brit', 'Weall', 'Female', 'West Frisian']
# ['844-15-4668', 'Eleonora', 'Delete', 'Female', 'Hiri Motu']
# ['844-50-7305', 'Merralee', 'Orae', 'Female', 'Macedonian']
# ['846-07-1407', 'Tobias', 'Blakelock', 'Male', 'German']
# ['846-09-9851', 'Shani', 'Penrose', 'Female', 'New Zealand Sign Language']
# ['846-59-9961', 'Saleem', 'Osmant', 'Male', 'Croatian']
# ['847-34-4817', 'Orazio', 'Coners', 'Male', 'Yiddish']
# ['847-61-7656', 'Brit', 'Lodovichi', 'Male', 'Bislama']
# ['848-58-3386', 'Julianne', 'Lygo', 'Female', 'Japanese']
# ['848-74-2886', 'Helyn', 'Witheford', 'Female', 'Bislama']
# ['848-76-8808', 'Durward', 'Nuscha', 'Male', 'Nepali']
# ['849-31-1551', 'Lisabeth', 'Mattessen', 'Female', 'German']
# ['849-64-6624', 'Hallie', 'Proschke', 'Female', 'Fijian']
# ['849-98-2973', 'Hurley', 'Newart', 'Male', 'Hindi']
# ['851-94-2162', 'Rodi', 'Mulrenan', 'Female', 'Catalan']
# ['852-15-7707', 'Mario', 'Lelande', 'Male', 'Nepali']
# ['853-11-8953', 'Brice', 'Kyd', 'Male', 'Dari']
# ['853-47-3648', 'Olag', 'Belhome', 'Male', 'Maltese']
# ['854-68-7635', 'Eyde', 'McCunn', 'Female', 'Moldovan']
# ['854-71-2983', 'Rikki', 'Loveland', 'Male', 'Dutch']
# ['854-79-5334', 'Bevan', 'Kolczynski', 'Male', 'Swahili']
# ['856-18-3980', 'Neale', 'Sesser', 'Male', 'Maltese']
# ['856-27-9112', 'Virgilio', 'Kirrage', 'Male', 'Pashto']
# ['856-67-4080', 'Aggy', 'Cobley', 'Female', 'Dhivehi']
# ['857-37-5902', 'Jenni', 'Swinyard', 'Female', 'Hindi']
# ['858-03-7735', 'Allayne', 'Wardingley', 'Male', 'Kazakh']
# ['858-27-9190', 'Yuri', 'Sixsmith', 'Male', 'Norwegian']
# ['860-67-0256', 'Bendicty', 'Lindgren', 'Male', 'Tajik']
# ['860-89-2570', 'Otto', 'Burgwin', 'Male', 'Finnish']
# ['861-50-6716', 'Norina', 'Yerbury', 'Female', 'Indonesian']
# ['862-20-0653', 'Wilfrid', 'Kid', 'Male', 'Swedish']
# ['864-22-9364', 'Lyell', 'Petrollo', 'Male', 'Latvian']
# ['864-91-7489', 'Guthrie', 'Pilsworth', 'Male', 'Bislama']
# ['866-18-1440', 'Zachary', 'Branchflower', 'Male', 'Papiamento']
# ['866-53-0625', 'Francene', 'Ehlerding', 'Female', 'Latvian']
# ['867-11-6007', 'Kennett', 'Barhims', 'Male', 'Malayalam']
# ['867-13-6844', 'Clo', 'Skacel', 'Female', 'Armenian']
# ['867-88-2360', 'Gasper', 'Dohrmann', 'Male', 'Dzongkha']
# ['868-32-1805', 'Joanna', 'Raycroft', 'Female', 'Bosnian']
# ['870-12-6609', 'Jourdain', 'Comino', 'Male', 'Guarana']
# ['870-93-1121', 'Elisha', 'Wonham', 'Male', 'Hebrew']
# ['871-99-3191', 'Susann', 'Walrond', 'Female', 'Amharic']
# ['872-18-9267', 'Roddy', 'Honeywood', 'Male', 'Maltese']
# ['872-49-1288', 'Salaidh', 'Barthod', 'Female', 'Finnish']
# ['873-36-4733', 'Locke', 'Staries', 'Male', 'Moldovan']
# ['875-18-9454', 'Eustace', 'Kinnear', 'Male', 'Hiri Motu']
# ['875-75-0495', 'Frasquito', 'Lammas', 'Male', 'Polish']
# ['878-12-8265', 'Nance', 'Doble', 'Female', 'Dhivehi']
# ['880-22-4449', 'Zebadiah', 'Halliburton', 'Male', 'Azeri']
# ['881-19-5974', 'Lodovico', 'Gabby', 'Male', 'Northern Sotho']
# ['881-88-7308', 'Maitilde', 'Davis', 'Female', 'Tsonga']
# ['881-95-7180', 'Homerus', 'Lamar', 'Male', 'Macedonian']
# ['882-49-5290', 'Tamarah', 'Stenson', 'Female', 'Armenian']
# ['884-61-1852', 'Wylie', 'Glennon', 'Male', 'Romanian']
# ['887-41-7878', 'Bruce', 'Danieli', 'Male', 'Tamil']
# ['887-83-9002', 'Mab', 'Bozworth', 'Female', 'Tok Pisin']
# ['888-50-7008', 'Mayor', 'Gouley', 'Male', 'Dzongkha']
# ['888-53-7684', 'Lanny', 'Perfect', 'Male', 'Estonian']
# ['888-82-4928', 'Billye', 'Legat', 'Female', 'Icelandic']
# ['890-28-9962', 'Kingston', 'Spitell', 'Male', 'Quechua']
# ['893-12-0901', 'Dicky', 'Rohlfing', 'Male', 'Oriya']
# ['893-17-7318', 'Nani', 'Bonelle', 'Female', 'Kyrgyz']
# ['894-81-0628', 'Ree', 'Mordue', 'Female', 'Tswana']
# ['895-26-1658', 'Nance', 'Danzelman', 'Female', 'Icelandic']
# ['895-26-5515', 'Frank', 'Mason', 'Male', 'Northern Sotho']
# ['897-76-7070', 'Glynnis', 'Tillerton', 'Female', 'Nepali']
# ['898-03-3165', 'Sela', 'Vaillant', 'Female', 'Arabic']
# ['898-86-8860', 'Hershel', 'Few', 'Male', 'Gagauz']
# ['899-09-1766', 'Joe', 'Myderscough', 'Male', 'Filipino']
# ['899-39-7179', 'Rani', 'Naisbitt', 'Female', 'Greek']
# ['899-39-7378', 'Lindsay', 'Colledge', 'Female', 'Croatian']
# ['899-47-6116', 'Tiphanie', 'Kevlin', 'Female', 'Tetum']

# %%
fname = "cars.csv"
DataRow = get_data_row_factory(fname)
with csv_file_reader(fname) as file:
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    for row in file:
        print(row)
# Out:
# DataRow(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# DataRow(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# DataRow(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# ['Ford Galaxie 500', '15.0', '8', '429.0', '198.0', '4341.', '10.0', '70', 'US']
# ['Chevrolet Impala', '14.0', '8', '454.0', '220.0', '4354.', '9.0', '70', 'US']
# ['Plymouth Fury iii', '14.0', '8', '440.0', '215.0', '4312.', '8.5', '70', 'US']
# ['Pontiac Catalina', '14.0', '8', '455.0', '225.0', '4425.', '10.0', '70', 'US']
# ['AMC Ambassador DPL', '15.0', '8', '390.0', '190.0', '3850.', '8.5', '70', 'US']
# ['Citroen DS-21 Pallas', '0', '4', '133.0', '115.0', '3090.', '17.5', '70', 'Europe']
# ['Chevrolet Chevelle Concours (sw)', '0', '8', '350.0', '165.0', '4142.', '11.5', '70', 'US']
# ['Ford Torino (sw)', '0', '8', '351.0', '153.0', '4034.', '11.0', '70', 'US']
# ['Plymouth Satellite (sw)', '0', '8', '383.0', '175.0', '4166.', '10.5', '70', 'US']
# ['AMC Rebel SST (sw)', '0', '8', '360.0', '175.0', '3850.', '11.0', '70', 'US']
# ['Dodge Challenger SE', '15.0', '8', '383.0', '170.0', '3563.', '10.0', '70', 'US']
# ["Plymouth 'Cuda 340", '14.0', '8', '340.0', '160.0', '3609.', '8.0', '70', 'US']
# ['Ford Mustang Boss 302', '0', '8', '302.0', '140.0', '3353.', '8.0', '70', 'US']
# ['Chevrolet Monte Carlo', '15.0', '8', '400.0', '150.0', '3761.', '9.5', '70', 'US']
# ['Buick Estate Wagon (sw)', '14.0', '8', '455.0', '225.0', '3086.', '10.0', '70', 'US']
# ['Toyota Corolla Mark ii', '24.0', '4', '113.0', '95.00', '2372.', '15.0', '70', 'Japan']
# ['Plymouth Duster', '22.0', '6', '198.0', '95.00', '2833.', '15.5', '70', 'US']
# ['AMC Hornet', '18.0', '6', '199.0', '97.00', '2774.', '15.5', '70', 'US']
# ['Ford Maverick', '21.0', '6', '200.0', '85.00', '2587.', '16.0', '70', 'US']
# ['Datsun PL510', '27.0', '4', '97.00', '88.00', '2130.', '14.5', '70', 'Japan']
# ['Volkswagen 1131 Deluxe Sedan', '26.0', '4', '97.00', '46.00', '1835.', '20.5', '70', 'Europe']
# ['Peugeot 504', '25.0', '4', '110.0', '87.00', '2672.', '17.5', '70', 'Europe']
# ['Audi 100 LS', '24.0', '4', '107.0', '90.00', '2430.', '14.5', '70', 'Europe']
# ['Saab 99e', '25.0', '4', '104.0', '95.00', '2375.', '17.5', '70', 'Europe']
# ['BMW 2002', '26.0', '4', '121.0', '113.0', '2234.', '12.5', '70', 'Europe']
# ['AMC Gremlin', '21.0', '6', '199.0', '90.00', '2648.', '15.0', '70', 'US']
# ['Ford F250', '10.0', '8', '360.0', '215.0', '4615.', '14.0', '70', 'US']
# ['Chevy C20', '10.0', '8', '307.0', '200.0', '4376.', '15.0', '70', 'US']
# ['Dodge D200', '11.0', '8', '318.0', '210.0', '4382.', '13.5', '70', 'US']
# ['Hi 1200D', '9.0', '8', '304.0', '193.0', '4732.', '18.5', '70', 'US']
# ['Datsun PL510', '27.0', '4', '97.00', '88.00', '2130.', '14.5', '71', 'Japan']
# ['Chevrolet Vega 2300', '28.0', '4', '140.0', '90.00', '2264.', '15.5', '71', 'US']
# ['Toyota Corolla', '25.0', '4', '113.0', '95.00', '2228.', '14.0', '71', 'Japan']
# ['Ford Pinto', '25.0', '4', '98.00', '0', '2046.', '19.0', '71', 'US']
# ['Volkswagen Super Beetle 117', '0', '4', '97.00', '48.00', '1978.', '20.0', '71', 'Europe']
# ['AMC Gremlin', '19.0', '6', '232.0', '100.0', '2634.', '13.0', '71', 'US']
# ['Plymouth Satellite Custom', '16.0', '6', '225.0', '105.0', '3439.', '15.5', '71', 'US']
# ['Chevrolet Chevelle Malibu', '17.0', '6', '250.0', '100.0', '3329.', '15.5', '71', 'US']
# ['Ford Torino 500', '19.0', '6', '250.0', '88.00', '3302.', '15.5', '71', 'US']
# ['AMC Matador', '18.0', '6', '232.0', '100.0', '3288.', '15.5', '71', 'US']
# ['Chevrolet Impala', '14.0', '8', '350.0', '165.0', '4209.', '12.0', '71', 'US']
# ['Pontiac Catalina Brougham', '14.0', '8', '400.0', '175.0', '4464.', '11.5', '71', 'US']
# ['Ford Galaxie 500', '14.0', '8', '351.0', '153.0', '4154.', '13.5', '71', 'US']
# ['Plymouth Fury iii', '14.0', '8', '318.0', '150.0', '4096.', '13.0', '71', 'US']
# ['Dodge Monaco (sw)', '12.0', '8', '383.0', '180.0', '4955.', '11.5', '71', 'US']
# ['Ford Country Squire (sw)', '13.0', '8', '400.0', '170.0', '4746.', '12.0', '71', 'US']
# ['Pontiac Safari (sw)', '13.0', '8', '400.0', '175.0', '5140.', '12.0', '71', 'US']
# ['AMC Hornet Sportabout (sw)', '18.0', '6', '258.0', '110.0', '2962.', '13.5', '71', 'US']
# ['Chevrolet Vega (sw)', '22.0', '4', '140.0', '72.00', '2408.', '19.0', '71', 'US']
# ['Pontiac Firebird', '19.0', '6', '250.0', '100.0', '3282.', '15.0', '71', 'US']
# ['Ford Mustang', '18.0', '6', '250.0', '88.00', '3139.', '14.5', '71', 'US']
# ['Mercury Capri 2000', '23.0', '4', '122.0', '86.00', '2220.', '14.0', '71', 'US']
# ['Opel 1900', '28.0', '4', '116.0', '90.00', '2123.', '14.0', '71', 'Europe']
# ['Peugeot 304', '30.0', '4', '79.00', '70.00', '2074.', '19.5', '71', 'Europe']
# ['Fiat 124B', '30.0', '4', '88.00', '76.00', '2065.', '14.5', '71', 'Europe']
# ['Toyota Corolla 1200', '31.0', '4', '71.00', '65.00', '1773.', '19.0', '71', 'Japan']
# ['Datsun 1200', '35.0', '4', '72.00', '69.00', '1613.', '18.0', '71', 'Japan']
# ['Volkswagen Model 111', '27.0', '4', '97.00', '60.00', '1834.', '19.0', '71', 'Europe']
# ['Plymouth Cricket', '26.0', '4', '91.00', '70.00', '1955.', '20.5', '71', 'US']
# ['Toyota Corolla Hardtop', '24.0', '4', '113.0', '95.00', '2278.', '15.5', '72', 'Japan']
# ['Dodge Colt Hardtop', '25.0', '4', '97.50', '80.00', '2126.', '17.0', '72', 'US']
# ['Volkswagen Type 3', '23.0', '4', '97.00', '54.00', '2254.', '23.5', '72', 'Europe']
# ['Chevrolet Vega', '20.0', '4', '140.0', '90.00', '2408.', '19.5', '72', 'US']
# ['Ford Pinto Runabout', '21.0', '4', '122.0', '86.00', '2226.', '16.5', '72', 'US']
# ['Chevrolet Impala', '13.0', '8', '350.0', '165.0', '4274.', '12.0', '72', 'US']
# ['Pontiac Catalina', '14.0', '8', '400.0', '175.0', '4385.', '12.0', '72', 'US']
# ['Plymouth Fury III', '15.0', '8', '318.0', '150.0', '4135.', '13.5', '72', 'US']
# ['Ford Galaxie 500', '14.0', '8', '351.0', '153.0', '4129.', '13.0', '72', 'US']
# ['AMC Ambassador SST', '17.0', '8', '304.0', '150.0', '3672.', '11.5', '72', 'US']
# ['Mercury Marquis', '11.0', '8', '429.0', '208.0', '4633.', '11.0', '72', 'US']
# ['Buick LeSabre Custom', '13.0', '8', '350.0', '155.0', '4502.', '13.5', '72', 'US']
# ['Oldsmobile Delta 88 Royale', '12.0', '8', '350.0', '160.0', '4456.', '13.5', '72', 'US']
# ['Chrysler Newport Royal', '13.0', '8', '400.0', '190.0', '4422.', '12.5', '72', 'US']
# ['Mazda RX2 Coupe', '19.0', '3', '70.00', '97.00', '2330.', '13.5', '72', 'Japan']
# ['AMC Matador (sw)', '15.0', '8', '304.0', '150.0', '3892.', '12.5', '72', 'US']
# ['Chevrolet Chevelle Concours (sw)', '13.0', '8', '307.0', '130.0', '4098.', '14.0', '72', 'US']
# ['Ford Gran Torino (sw)', '13.0', '8', '302.0', '140.0', '4294.', '16.0', '72', 'US']
# ['Plymouth Satellite Custom (sw)', '14.0', '8', '318.0', '150.0', '4077.', '14.0', '72', 'US']
# ['Volvo 145e (sw)', '18.0', '4', '121.0', '112.0', '2933.', '14.5', '72', 'Europe']
# ['Volkswagen 411 (sw)', '22.0', '4', '121.0', '76.00', '2511.', '18.0', '72', 'Europe']
# ['Peugeot 504 (sw)', '21.0', '4', '120.0', '87.00', '2979.', '19.5', '72', 'Europe']
# ['Renault 12 (sw)', '26.0', '4', '96.00', '69.00', '2189.', '18.0', '72', 'Europe']
# ['Ford Pinto (sw)', '22.0', '4', '122.0', '86.00', '2395.', '16.0', '72', 'US']
# ['Datsun 510 (sw)', '28.0', '4', '97.00', '92.00', '2288.', '17.0', '72', 'Japan']
# ['Toyota Corolla Mark II (sw)', '23.0', '4', '120.0', '97.00', '2506.', '14.5', '72', 'Japan']
# ['Dodge Colt (sw)', '28.0', '4', '98.00', '80.00', '2164.', '15.0', '72', 'US']
# ['Toyota Corolla 1600 (sw)', '27.0', '4', '97.00', '88.00', '2100.', '16.5', '72', 'Japan']
# ['Buick Century 350', '13.0', '8', '350.0', '175.0', '4100.', '13.0', '73', 'US']
# ['AMC Matador', '14.0', '8', '304.0', '150.0', '3672.', '11.5', '73', 'US']
# ['Chevrolet Malibu', '13.0', '8', '350.0', '145.0', '3988.', '13.0', '73', 'US']
# ['Ford Gran Torino', '14.0', '8', '302.0', '137.0', '4042.', '14.5', '73', 'US']
# ['Dodge Coronet Custom', '15.0', '8', '318.0', '150.0', '3777.', '12.5', '73', 'US']
# ['Mercury Marquis Brougham', '12.0', '8', '429.0', '198.0', '4952.', '11.5', '73', 'US']
# ['Chevrolet Caprice Classic', '13.0', '8', '400.0', '150.0', '4464.', '12.0', '73', 'US']
# ['Ford LTD', '13.0', '8', '351.0', '158.0', '4363.', '13.0', '73', 'US']
# ['Plymouth Fury Gran Sedan', '14.0', '8', '318.0', '150.0', '4237.', '14.5', '73', 'US']
# ['Chrysler New Yorker Brougham', '13.0', '8', '440.0', '215.0', '4735.', '11.0', '73', 'US']
# ['Buick Electra 225 Custom', '12.0', '8', '455.0', '225.0', '4951.', '11.0', '73', 'US']
# ['AMC Ambassador Brougham', '13.0', '8', '360.0', '175.0', '3821.', '11.0', '73', 'US']
# ['Plymouth Valiant', '18.0', '6', '225.0', '105.0', '3121.', '16.5', '73', 'US']
# ['Chevrolet Nova Custom', '16.0', '6', '250.0', '100.0', '3278.', '18.0', '73', 'US']
# ['AMC Hornet', '18.0', '6', '232.0', '100.0', '2945.', '16.0', '73', 'US']
# ['Ford Maverick', '18.0', '6', '250.0', '88.00', '3021.', '16.5', '73', 'US']
# ['Plymouth Duster', '23.0', '6', '198.0', '95.00', '2904.', '16.0', '73', 'US']
# ['Volkswagen Super Beetle', '26.0', '4', '97.00', '46.00', '1950.', '21.0', '73', 'Europe']
# ['Chevrolet Impala', '11.0', '8', '400.0', '150.0', '4997.', '14.0', '73', 'US']
# ['Ford Country', '12.0', '8', '400.0', '167.0', '4906.', '12.5', '73', 'US']
# ['Plymouth Custom Suburb', '13.0', '8', '360.0', '170.0', '4654.', '13.0', '73', 'US']
# ['Oldsmobile Vista Cruiser', '12.0', '8', '350.0', '180.0', '4499.', '12.5', '73', 'US']
# ['AMC Gremlin', '18.0', '6', '232.0', '100.0', '2789.', '15.0', '73', 'US']
# ['Toyota Camry', '20.0', '4', '97.00', '88.00', '2279.', '19.0', '73', 'Japan']
# ['Chevrolet Vega', '21.0', '4', '140.0', '72.00', '2401.', '19.5', '73', 'US']
# ['Datsun 610', '22.0', '4', '108.0', '94.00', '2379.', '16.5', '73', 'Japan']
# ['Mazda RX3', '18.0', '3', '70.00', '90.00', '2124.', '13.5', '73', 'Japan']
# ['Ford Pinto', '19.0', '4', '122.0', '85.00', '2310.', '18.5', '73', 'US']
# ['Mercury Capri v6', '21.0', '6', '155.0', '107.0', '2472.', '14.0', '73', 'US']
# ['Fiat 124 Sport Coupe', '26.0', '4', '98.00', '90.00', '2265.', '15.5', '73', 'Europe']
# ['Chevrolet Monte Carlo S', '15.0', '8', '350.0', '145.0', '4082.', '13.0', '73', 'US']
# ['Pontiac Grand Prix', '16.0', '8', '400.0', '230.0', '4278.', '9.50', '73', 'US']
# ['Fiat 128', '29.0', '4', '68.00', '49.00', '1867.', '19.5', '73', 'Europe']
# ['Opel Manta', '24.0', '4', '116.0', '75.00', '2158.', '15.5', '73', 'Europe']
# ['Audi 100LS', '20.0', '4', '114.0', '91.00', '2582.', '14.0', '73', 'Europe']
# ['Volvo 144ea', '19.0', '4', '121.0', '112.0', '2868.', '15.5', '73', 'Europe']
# ['Dodge Dart Custom', '15.0', '8', '318.0', '150.0', '3399.', '11.0', '73', 'US']
# ['Saab 99le', '24.0', '4', '121.0', '110.0', '2660.', '14.0', '73', 'Europe']
# ['Toyota Mark II', '20.0', '6', '156.0', '122.0', '2807.', '13.5', '73', 'Japan']
# ['Oldsmobile Omega', '11.0', '8', '350.0', '180.0', '3664.', '11.0', '73', 'US']
# ['Plymouth Duster', '20.0', '6', '198.0', '95.00', '3102.', '16.5', '74', 'US']
# ['Ford Maverick', '21.0', '6', '200.0', '0', '2875.', '17.0', '74', 'US']
# ['AMC Hornet', '19.0', '6', '232.0', '100.0', '2901.', '16.0', '74', 'US']
# ['Chevrolet Nova', '15.0', '6', '250.0', '100.0', '3336.', '17.0', '74', 'US']
# ['Datsun B210', '31.0', '4', '79.00', '67.00', '1950.', '19.0', '74', 'Japan']
# ['Ford Pinto', '26.0', '4', '122.0', '80.00', '2451.', '16.5', '74', 'US']
# ['Toyota Corolla 1200', '32.0', '4', '71.00', '65.00', '1836.', '21.0', '74', 'Japan']
# ['Chevrolet Vega', '25.0', '4', '140.0', '75.00', '2542.', '17.0', '74', 'US']
# ['Chevrolet Chevelle Malibu Classic', '16.0', '6', '250.0', '100.0', '3781.', '17.0', '74', 'US']
# ['AMC Matador', '16.0', '6', '258.0', '110.0', '3632.', '18.0', '74', 'US']
# ['Plymouth Satellite Sebring', '18.0', '6', '225.0', '105.0', '3613.', '16.5', '74', 'US']
# ['Ford Gran Torino', '16.0', '8', '302.0', '140.0', '4141.', '14.0', '74', 'US']
# ['Buick Century Luxus (sw)', '13.0', '8', '350.0', '150.0', '4699.', '14.5', '74', 'US']
# ['Dodge Coronet Custom (sw)', '14.0', '8', '318.0', '150.0', '4457.', '13.5', '74', 'US']
# ['Ford Gran Torino (sw)', '14.0', '8', '302.0', '140.0', '4638.', '16.0', '74', 'US']
# ['AMC Matador (sw)', '14.0', '8', '304.0', '150.0', '4257.', '15.5', '74', 'US']
# ['Audi Fox', '29.0', '4', '98.00', '83.00', '2219.', '16.5', '74', 'Europe']
# ['Volkswagen Dasher', '26.0', '4', '79.00', '67.00', '1963.', '15.5', '74', 'Europe']
# ['Opel Manta', '26.0', '4', '97.00', '78.00', '2300.', '14.5', '74', 'Europe']
# ['Toyota Corolla', '31.0', '4', '76.00', '52.00', '1649.', '16.5', '74', 'Japan']
# ['Datsun 710', '32.0', '4', '83.00', '61.00', '2003.', '19.0', '74', 'Japan']
# ['Dodge Colt', '28.0', '4', '90.00', '75.00', '2125.', '14.5', '74', 'US']
# ['Fiat 128', '24.0', '4', '90.00', '75.00', '2108.', '15.5', '74', 'Europe']
# ['Fiat 124 TC', '26.0', '4', '116.0', '75.00', '2246.', '14.0', '74', 'Europe']
# ['Honda Civic', '24.0', '4', '120.0', '97.00', '2489.', '15.0', '74', 'Japan']
# ['Subaru', '26.0', '4', '108.0', '93.00', '2391.', '15.5', '74', 'Japan']
# ['Fiat x1.9', '31.0', '4', '79.00', '67.00', '2000.', '16.0', '74', 'Europe']
# ['Plymouth Valiant Custom', '19.0', '6', '225.0', '95.00', '3264.', '16.0', '75', 'US']
# ['Chevrolet Nova', '18.0', '6', '250.0', '105.0', '3459.', '16.0', '75', 'US']
# ['Mercury Monarch', '15.0', '6', '250.0', '72.00', '3432.', '21.0', '75', 'US']
# ['Ford Maverick', '15.0', '6', '250.0', '72.00', '3158.', '19.5', '75', 'US']
# ['Pontiac Catalina', '16.0', '8', '400.0', '170.0', '4668.', '11.5', '75', 'US']
# ['Chevrolet Bel Air', '15.0', '8', '350.0', '145.0', '4440.', '14.0', '75', 'US']
# ['Plymouth Grand Fury', '16.0', '8', '318.0', '150.0', '4498.', '14.5', '75', 'US']
# ['Ford LTD', '14.0', '8', '351.0', '148.0', '4657.', '13.5', '75', 'US']
# ['Buick Century', '17.0', '6', '231.0', '110.0', '3907.', '21.0', '75', 'US']
# ['Chevrolete Chevelle Malibu', '16.0', '6', '250.0', '105.0', '3897.', '18.5', '75', 'US']
# ['AMC Matador', '15.0', '6', '258.0', '110.0', '3730.', '19.0', '75', 'US']
# ['Plymouth Fury', '18.0', '6', '225.0', '95.00', '3785.', '19.0', '75', 'US']
# ['Buick Skyhawk', '21.0', '6', '231.0', '110.0', '3039.', '15.0', '75', 'US']
# ['Chevrolet Monza 2+2', '20.0', '8', '262.0', '110.0', '3221.', '13.5', '75', 'US']
# ['Ford Mustang II', '13.0', '8', '302.0', '129.0', '3169.', '12.0', '75', 'US']
# ['Toyota Corolla', '29.0', '4', '97.00', '75.00', '2171.', '16.0', '75', 'Japan']
# ['Ford Pinto', '23.0', '4', '140.0', '83.00', '2639.', '17.0', '75', 'US']
# ['AMC Gremlin', '20.0', '6', '232.0', '100.0', '2914.', '16.0', '75', 'US']
# ['Pontiac Astro', '23.0', '4', '140.0', '78.00', '2592.', '18.5', '75', 'US']
# ['Toyota Corolla', '24.0', '4', '134.0', '96.00', '2702.', '13.5', '75', 'Japan']
# ['Volkswagen Dasher', '25.0', '4', '90.00', '71.00', '2223.', '16.5', '75', 'Europe']
# ['Datsun 710', '24.0', '4', '119.0', '97.00', '2545.', '17.0', '75', 'Japan']
# ['Ford Pinto', '18.0', '6', '171.0', '97.00', '2984.', '14.5', '75', 'US']
# ['Volkswagen Rabbit', '29.0', '4', '90.00', '70.00', '1937.', '14.0', '75', 'Europe']
# ['AMC Pacer', '19.0', '6', '232.0', '90.00', '3211.', '17.0', '75', 'US']
# ['Audi 100LS', '23.0', '4', '115.0', '95.00', '2694.', '15.0', '75', 'Europe']
# ['Peugeot 504', '23.0', '4', '120.0', '88.00', '2957.', '17.0', '75', 'Europe']
# ['Volvo 244DL', '22.0', '4', '121.0', '98.00', '2945.', '14.5', '75', 'Europe']
# ['Saab 99LE', '25.0', '4', '121.0', '115.0', '2671.', '13.5', '75', 'Europe']
# ['Honda Civic CVCC', '33.0', '4', '91.00', '53.00', '1795.', '17.5', '75', 'Japan']
# ['Fiat 131', '28.0', '4', '107.0', '86.00', '2464.', '15.5', '76', 'Europe']
# ['Opel 1900', '25.0', '4', '116.0', '81.00', '2220.', '16.9', '76', 'Europe']
# ['Capri ii', '25.0', '4', '140.0', '92.00', '2572.', '14.9', '76', 'US']
# ['Dodge Colt', '26.0', '4', '98.00', '79.00', '2255.', '17.7', '76', 'US']
# ['Renault 12tl', '27.0', '4', '101.0', '83.00', '2202.', '15.3', '76', 'Europe']
# ['Chevrolet Chevelle Malibu Classic', '17.5', '8', '305.0', '140.0', '4215.', '13.0', '76', 'US']
# ['Dodge Coronet Brougham', '16.0', '8', '318.0', '150.0', '4190.', '13.0', '76', 'US']
# ['AMC Matador', '15.5', '8', '304.0', '120.0', '3962.', '13.9', '76', 'US']
# ['Ford Gran Torino', '14.5', '8', '351.0', '152.0', '4215.', '12.8', '76', 'US']
# ['Plymouth Valiant', '22.0', '6', '225.0', '100.0', '3233.', '15.4', '76', 'US']
# ['Chevrolet Nova', '22.0', '6', '250.0', '105.0', '3353.', '14.5', '76', 'US']
# ['Ford Maverick', '24.0', '6', '200.0', '81.00', '3012.', '17.6', '76', 'US']
# ['AMC Hornet', '22.5', '6', '232.0', '90.00', '3085.', '17.6', '76', 'US']
# ['Chevrolet Chevette', '29.0', '4', '85.00', '52.00', '2035.', '22.2', '76', 'US']
# ['Chevrolet Woody', '24.5', '4', '98.00', '60.00', '2164.', '22.1', '76', 'US']
# ['Volkswagen Rabbit', '29.0', '4', '90.00', '70.00', '1937.', '14.2', '76', 'Europe']
# ['Honda Civic', '33.0', '4', '91.00', '53.00', '1795.', '17.4', '76', 'Japan']
# ['Dodge Aspen SE', '20.0', '6', '225.0', '100.0', '3651.', '17.7', '76', 'US']
# ['Ford Grenada ghia', '18.0', '6', '250.0', '78.00', '3574.', '21.0', '76', 'US']
# ['Pontiac Ventura SJ', '18.5', '6', '250.0', '110.0', '3645.', '16.2', '76', 'US']
# ['AMC Pacer d/l', '17.5', '6', '258.0', '95.00', '3193.', '17.8', '76', 'US']
# ['Volkswagen Rabbit', '29.5', '4', '97.00', '71.00', '1825.', '12.2', '76', 'Europe']
# ['Datsun B-210', '32.0', '4', '85.00', '70.00', '1990.', '17.0', '76', 'Japan']
# ['Toyota Corolla', '28.0', '4', '97.00', '75.00', '2155.', '16.4', '76', 'Japan']
# ['Ford Pinto', '26.5', '4', '140.0', '72.00', '2565.', '13.6', '76', 'US']
# ['Volvo 245', '20.0', '4', '130.0', '102.0', '3150.', '15.7', '76', 'Europe']
# ['Plymouth Volare Premier v8', '13.0', '8', '318.0', '150.0', '3940.', '13.2', '76', 'US']
# ['Peugeot 504', '19.0', '4', '120.0', '88.00', '3270.', '21.9', '76', 'Europe']
# ['Toyota Mark II', '19.0', '6', '156.0', '108.0', '2930.', '15.5', '76', 'Japan']
# ['Mercedes-Benz 280s', '16.5', '6', '168.0', '120.0', '3820.', '16.7', '76', 'Europe']
# ['Cadillac Seville', '16.5', '8', '350.0', '180.0', '4380.', '12.1', '76', 'US']
# ['Chevrolet C10', '13.0', '8', '350.0', '145.0', '4055.', '12.0', '76', 'US']
# ['Ford F108', '13.0', '8', '302.0', '130.0', '3870.', '15.0', '76', 'US']
# ['Dodge D100', '13.0', '8', '318.0', '150.0', '3755.', '14.0', '76', 'US']
# ['Honda Accord CVCC', '31.5', '4', '98.00', '68.00', '2045.', '18.5', '77', 'Japan']
# ['Buick Opel Isuzu Deluxe', '30.0', '4', '111.0', '80.00', '2155.', '14.8', '77', 'US']
# ['Renault 5 GTL', '36.0', '4', '79.00', '58.00', '1825.', '18.6', '77', 'Europe']
# ['Plymouth Arrow GS', '25.5', '4', '122.0', '96.00', '2300.', '15.5', '77', 'US']
# ['Datsun F-10 Hatchback', '33.5', '4', '85.00', '70.00', '1945.', '16.8', '77', 'Japan']
# ['Chevrolet Caprice Classic', '17.5', '8', '305.0', '145.0', '3880.', '12.5', '77', 'US']
# ['Oldsmobile Cutlass Supreme', '17.0', '8', '260.0', '110.0', '4060.', '19.0', '77', 'US']
# ['Dodge Monaco Brougham', '15.5', '8', '318.0', '145.0', '4140.', '13.7', '77', 'US']
# ['Mercury Cougar Brougham', '15.0', '8', '302.0', '130.0', '4295.', '14.9', '77', 'US']
# ['Chevrolet Concours', '17.5', '6', '250.0', '110.0', '3520.', '16.4', '77', 'US']
# ['Buick Skylark', '20.5', '6', '231.0', '105.0', '3425.', '16.9', '77', 'US']
# ['Plymouth Volare Custom', '19.0', '6', '225.0', '100.0', '3630.', '17.7', '77', 'US']
# ['Ford Grenada', '18.5', '6', '250.0', '98.00', '3525.', '19.0', '77', 'US']
# ['Pontiac Grand Prix LJ', '16.0', '8', '400.0', '180.0', '4220.', '11.1', '77', 'US']
# ['Chevrolet Monte Carlo Landau', '15.5', '8', '350.0', '170.0', '4165.', '11.4', '77', 'US']
# ['Chrysler Cordoba', '15.5', '8', '400.0', '190.0', '4325.', '12.2', '77', 'US']
# ['Ford Thunderbird', '16.0', '8', '351.0', '149.0', '4335.', '14.5', '77', 'US']
# ['Volkswagen Rabbit Custom', '29.0', '4', '97.00', '78.00', '1940.', '14.5', '77', 'Europe']
# ['Pontiac Sunbird Coupe', '24.5', '4', '151.0', '88.00', '2740.', '16.0', '77', 'US']
# ['Toyota Corolla Liftback', '26.0', '4', '97.00', '75.00', '2265.', '18.2', '77', 'Japan']
# ['Ford Mustang II 2+2', '25.5', '4', '140.0', '89.00', '2755.', '15.8', '77', 'US']
# ['Chevrolet Chevette', '30.5', '4', '98.00', '63.00', '2051.', '17.0', '77', 'US']
# ['Dodge Colt m/m', '33.5', '4', '98.00', '83.00', '2075.', '15.9', '77', 'US']
# ['Subaru DL', '30.0', '4', '97.00', '67.00', '1985.', '16.4', '77', 'Japan']
# ['Volkswagen Dasher', '30.5', '4', '97.00', '78.00', '2190.', '14.1', '77', 'Europe']
# ['Datsun 810', '22.0', '6', '146.0', '97.00', '2815.', '14.5', '77', 'Japan']
# ['BMW 320i', '21.5', '4', '121.0', '110.0', '2600.', '12.8', '77', 'Europe']
# ['Mazda RX-4', '21.5', '3', '80.00', '110.0', '2720.', '13.5', '77', 'Japan']
# ['Volkswagen Rabbit Custom Diesel', '43.1', '4', '90.00', '48.00', '1985.', '21.5', '78', 'Europe']
# ['Ford Fiesta', '36.1', '4', '98.00', '66.00', '1800.', '14.4', '78', 'US']
# ['Mazda GLC Deluxe', '32.8', '4', '78.00', '52.00', '1985.', '19.4', '78', 'Japan']
# ['Datsun B210 GX', '39.4', '4', '85.00', '70.00', '2070.', '18.6', '78', 'Japan']
# ['Honda Civic CVCC', '36.1', '4', '91.00', '60.00', '1800.', '16.4', '78', 'Japan']
# ['Oldsmobile Cutlass Salon Brougham', '19.9', '8', '260.0', '110.0', '3365.', '15.5', '78', 'US']
# ['Dodge Diplomat', '19.4', '8', '318.0', '140.0', '3735.', '13.2', '78', 'US']
# ['Mercury Monarch ghia', '20.2', '8', '302.0', '139.0', '3570.', '12.8', '78', 'US']
# ['Pontiac Phoenix LJ', '19.2', '6', '231.0', '105.0', '3535.', '19.2', '78', 'US']
# ['Chevrolet Malibu', '20.5', '6', '200.0', '95.00', '3155.', '18.2', '78', 'US']
# ['Ford Fairmont (auto)', '20.2', '6', '200.0', '85.00', '2965.', '15.8', '78', 'US']
# ['Ford Fairmont (man)', '25.1', '4', '140.0', '88.00', '2720.', '15.4', '78', 'US']
# ['Plymouth Volare', '20.5', '6', '225.0', '100.0', '3430.', '17.2', '78', 'US']
# ['AMC Concord', '19.4', '6', '232.0', '90.00', '3210.', '17.2', '78', 'US']
# ['Buick Century Special', '20.6', '6', '231.0', '105.0', '3380.', '15.8', '78', 'US']
# ['Mercury Zephyr', '20.8', '6', '200.0', '85.00', '3070.', '16.7', '78', 'US']
# ['Dodge Aspen', '18.6', '6', '225.0', '110.0', '3620.', '18.7', '78', 'US']
# ['AMC Concord d/l', '18.1', '6', '258.0', '120.0', '3410.', '15.1', '78', 'US']
# ['Chevrolet Monte Carlo Landau', '19.2', '8', '305.0', '145.0', '3425.', '13.2', '78', 'US']
# ['Buick Regal Sport Coupe (turbo)', '17.7', '6', '231.0', '165.0', '3445.', '13.4', '78', 'US']
# ['Ford Futura', '18.1', '8', '302.0', '139.0', '3205.', '11.2', '78', 'US']
# ['Dodge Magnum XE', '17.5', '8', '318.0', '140.0', '4080.', '13.7', '78', 'US']
# ['Chevrolet Chevette', '30.0', '4', '98.00', '68.00', '2155.', '16.5', '78', 'US']
# ['Toyota Corolla', '27.5', '4', '134.0', '95.00', '2560.', '14.2', '78', 'Japan']
# ['Datsun 510', '27.2', '4', '119.0', '97.00', '2300.', '14.7', '78', 'Japan']
# ['Dodge Omni', '30.9', '4', '105.0', '75.00', '2230.', '14.5', '78', 'US']
# ['Toyota Celica GT Liftback', '21.1', '4', '134.0', '95.00', '2515.', '14.8', '78', 'Japan']
# ['Plymouth Sapporo', '23.2', '4', '156.0', '105.0', '2745.', '16.7', '78', 'US']
# ['Oldsmobile Starfire SX', '23.8', '4', '151.0', '85.00', '2855.', '17.6', '78', 'US']
# ['Datsun 200-SX', '23.9', '4', '119.0', '97.00', '2405.', '14.9', '78', 'Japan']
# ['Audi 5000', '20.3', '5', '131.0', '103.0', '2830.', '15.9', '78', 'Europe']
# ['Volvo 264gl', '17.0', '6', '163.0', '125.0', '3140.', '13.6', '78', 'Europe']
# ['Saab 99gle', '21.6', '4', '121.0', '115.0', '2795.', '15.7', '78', 'Europe']
# ['Peugeot 604sl', '16.2', '6', '163.0', '133.0', '3410.', '15.8', '78', 'Europe']
# ['Volkswagen Scirocco', '31.5', '4', '89.00', '71.00', '1990.', '14.9', '78', 'Europe']
# ['Honda Accord LX', '29.5', '4', '98.00', '68.00', '2135.', '16.6', '78', 'Japan']
# ['Pontiac Lemans V6', '21.5', '6', '231.0', '115.0', '3245.', '15.4', '79', 'US']
# ['Mercury Zephyr 6', '19.8', '6', '200.0', '85.00', '2990.', '18.2', '79', 'US']
# ['Ford Fairmont 4', '22.3', '4', '140.0', '88.00', '2890.', '17.3', '79', 'US']
# ['AMC Concord DL 6', '20.2', '6', '232.0', '90.00', '3265.', '18.2', '79', 'US']
# ['Dodge Aspen 6', '20.6', '6', '225.0', '110.0', '3360.', '16.6', '79', 'US']
# ['Chevrolet Caprice Classic', '17.0', '8', '305.0', '130.0', '3840.', '15.4', '79', 'US']
# ['Ford LTD Landau', '17.6', '8', '302.0', '129.0', '3725.', '13.4', '79', 'US']
# ['Mercury Grand Marquis', '16.5', '8', '351.0', '138.0', '3955.', '13.2', '79', 'US']
# ['Dodge St. Regis', '18.2', '8', '318.0', '135.0', '3830.', '15.2', '79', 'US']
# ['Buick Estate Wagon (sw)', '16.9', '8', '350.0', '155.0', '4360.', '14.9', '79', 'US']
# ['Ford Country Squire (sw)', '15.5', '8', '351.0', '142.0', '4054.', '14.3', '79', 'US']
# ['Chevrolet Malibu Classic (sw)', '19.2', '8', '267.0', '125.0', '3605.', '15.0', '79', 'US']
# ['Chrysler Lebaron Town @ Country (sw)', '18.5', '8', '360.0', '150.0', '3940.', '13.0', '79', 'US']
# ['Volkswagen Rabbit Custom', '31.9', '4', '89.00', '71.00', '1925.', '14.0', '79', 'Europe']
# ['Mazda GLC Deluxe', '34.1', '4', '86.00', '65.00', '1975.', '15.2', '79', 'Japan']
# ['Dodge Colt Hatchback Custom', '35.7', '4', '98.00', '80.00', '1915.', '14.4', '79', 'US']
# ['AMC Spirit DL', '27.4', '4', '121.0', '80.00', '2670.', '15.0', '79', 'US']
# ['Mercedes Benz 300d', '25.4', '5', '183.0', '77.00', '3530.', '20.1', '79', 'Europe']
# ['Cadillac Eldorado', '23.0', '8', '350.0', '125.0', '3900.', '17.4', '79', 'US']
# ['Peugeot 504', '27.2', '4', '141.0', '71.00', '3190.', '24.8', '79', 'Europe']
# ['Oldsmobile Cutlass Salon Brougham', '23.9', '8', '260.0', '90.00', '3420.', '22.2', '79', 'US']
# ['Plymouth Horizon', '34.2', '4', '105.0', '70.00', '2200.', '13.2', '79', 'US']
# ['Plymouth Horizon TC3', '34.5', '4', '105.0', '70.00', '2150.', '14.9', '79', 'US']
# ['Datsun 210', '31.8', '4', '85.00', '65.00', '2020.', '19.2', '79', 'Japan']
# ['Fiat Strada Custom', '37.3', '4', '91.00', '69.00', '2130.', '14.7', '79', 'Europe']
# ['Buick Skylark Limited', '28.4', '4', '151.0', '90.00', '2670.', '16.0', '79', 'US']
# ['Chevrolet Citation', '28.8', '6', '173.0', '115.0', '2595.', '11.3', '79', 'US']
# ['Oldsmobile Omega Brougham', '26.8', '6', '173.0', '115.0', '2700.', '12.9', '79', 'US']
# ['Pontiac Phoenix', '33.5', '4', '151.0', '90.00', '2556.', '13.2', '79', 'US']
# ['Volkswagen Rabbit', '41.5', '4', '98.00', '76.00', '2144.', '14.7', '80', 'Europe']
# ['Toyota Corolla Tercel', '38.1', '4', '89.00', '60.00', '1968.', '18.8', '80', 'Japan']
# ['Chevrolet Chevette', '32.1', '4', '98.00', '70.00', '2120.', '15.5', '80', 'US']
# ['Datsun 310', '37.2', '4', '86.00', '65.00', '2019.', '16.4', '80', 'Japan']
# ['Chevrolet Citation', '28.0', '4', '151.0', '90.00', '2678.', '16.5', '80', 'US']
# ['Ford Fairmont', '26.4', '4', '140.0', '88.00', '2870.', '18.1', '80', 'US']
# ['AMC Concord', '24.3', '4', '151.0', '90.00', '3003.', '20.1', '80', 'US']
# ['Dodge Aspen', '19.1', '6', '225.0', '90.00', '3381.', '18.7', '80', 'US']
# ['Audi 4000', '34.3', '4', '97.00', '78.00', '2188.', '15.8', '80', 'Europe']
# ['Toyota Corolla Liftback', '29.8', '4', '134.0', '90.00', '2711.', '15.5', '80', 'Japan']
# ['Mazda 626', '31.3', '4', '120.0', '75.00', '2542.', '17.5', '80', 'Japan']
# ['Datsun 510 Hatchback', '37.0', '4', '119.0', '92.00', '2434.', '15.0', '80', 'Japan']
# ['Toyota Corolla', '32.2', '4', '108.0', '75.00', '2265.', '15.2', '80', 'Japan']
# ['Mazda GLC', '46.6', '4', '86.00', '65.00', '2110.', '17.9', '80', 'Japan']
# ['Dodge Colt', '27.9', '4', '156.0', '105.0', '2800.', '14.4', '80', 'US']
# ['Datsun 210', '40.8', '4', '85.00', '65.00', '2110.', '19.2', '80', 'Japan']
# ['Volkswagen Rabbit C (Diesel)', '44.3', '4', '90.00', '48.00', '2085.', '21.7', '80', 'Europe']
# ['Volkswagen Dasher (diesel)', '43.4', '4', '90.00', '48.00', '2335.', '23.7', '80', 'Europe']
# ['Audi 5000s (diesel)', '36.4', '5', '121.0', '67.00', '2950.', '19.9', '80', 'Europe']
# ['Mercedes-Benz 240d', '30.0', '4', '146.0', '67.00', '3250.', '21.8', '80', 'Europe']
# ['Honda Civic 1500 gl', '44.6', '4', '91.00', '67.00', '1850.', '13.8', '80', 'Japan']
# ['Renault Lecar Deluxe', '40.9', '4', '85.00', '0', '1835.', '17.3', '80', 'Europe']
# ['Subaru DL', '33.8', '4', '97.00', '67.00', '2145.', '18.0', '80', 'Japan']
# ['Volkswagen Rabbit', '29.8', '4', '89.00', '62.00', '1845.', '15.3', '80', 'Europe']
# ['Datsun 280-ZX', '32.7', '6', '168.0', '132.0', '2910.', '11.4', '80', 'Japan']
# ['Mazda RX-7 GS', '23.7', '3', '70.00', '100.0', '2420.', '12.5', '80', 'Japan']
# ['Triumph TR7 Coupe', '35.0', '4', '122.0', '88.00', '2500.', '15.1', '80', 'Europe']
# ['Ford Mustang Cobra', '23.6', '4', '140.0', '0', '2905.', '14.3', '80', 'US']
# ['Honda Accord', '32.4', '4', '107.0', '72.00', '2290.', '17.0', '80', 'Japan']
# ['Plymouth Reliant', '27.2', '4', '135.0', '84.00', '2490.', '15.7', '81', 'US']
# ['Buick Skylark', '26.6', '4', '151.0', '84.00', '2635.', '16.4', '81', 'US']
# ['Dodge Aries Wagon (sw)', '25.8', '4', '156.0', '92.00', '2620.', '14.4', '81', 'US']
# ['Chevrolet Citation', '23.5', '6', '173.0', '110.0', '2725.', '12.6', '81', 'US']
# ['Plymouth Reliant', '30.0', '4', '135.0', '84.00', '2385.', '12.9', '81', 'US']
# ['Toyota Starlet', '39.1', '4', '79.00', '58.00', '1755.', '16.9', '81', 'Japan']
# ['Plymouth Champ', '39.0', '4', '86.00', '64.00', '1875.', '16.4', '81', 'US']
# ['Honda Civic 1300', '35.1', '4', '81.00', '60.00', '1760.', '16.1', '81', 'Japan']
# ['Subaru', '32.3', '4', '97.00', '67.00', '2065.', '17.8', '81', 'Japan']
# ['Datsun 210 MPG', '37.0', '4', '85.00', '65.00', '1975.', '19.4', '81', 'Japan']
# ['Toyota Tercel', '37.7', '4', '89.00', '62.00', '2050.', '17.3', '81', 'Japan']
# ['Mazda GLC 4', '34.1', '4', '91.00', '68.00', '1985.', '16.0', '81', 'Japan']
# ['Plymouth Horizon 4', '34.7', '4', '105.0', '63.00', '2215.', '14.9', '81', 'US']
# ['Ford Escort 4W', '34.4', '4', '98.00', '65.00', '2045.', '16.2', '81', 'US']
# ['Ford Escort 2H', '29.9', '4', '98.00', '65.00', '2380.', '20.7', '81', 'US']
# ['Volkswagen Jetta', '33.0', '4', '105.0', '74.00', '2190.', '14.2', '81', 'Europe']
# ['Renault 18i', '34.5', '4', '100.0', '0', '2320.', '15.8', '81', 'Europe']
# ['Honda Prelude', '33.7', '4', '107.0', '75.00', '2210.', '14.4', '81', 'Japan']
# ['Toyota Corolla', '32.4', '4', '108.0', '75.00', '2350.', '16.8', '81', 'Japan']
# ['Datsun 200SX', '32.9', '4', '119.0', '100.0', '2615.', '14.8', '81', 'Japan']
# ['Mazda 626', '31.6', '4', '120.0', '74.00', '2635.', '18.3', '81', 'Japan']
# ['Peugeot 505s Turbo Diesel', '28.1', '4', '141.0', '80.00', '3230.', '20.4', '81', 'Europe']
# ['Saab 900s', '0', '4', '121.0', '110.0', '2800.', '15.4', '81', 'Europe']
# ['Volvo Diesel', '30.7', '6', '145.0', '76.00', '3160.', '19.6', '81', 'Europe']
# ['Toyota Cressida', '25.4', '6', '168.0', '116.0', '2900.', '12.6', '81', 'Japan']
# ['Datsun 810 Maxima', '24.2', '6', '146.0', '120.0', '2930.', '13.8', '81', 'Japan']
# ['Buick Century', '22.4', '6', '231.0', '110.0', '3415.', '15.8', '81', 'US']
# ['Oldsmobile Cutlass LS', '26.6', '8', '350.0', '105.0', '3725.', '19.0', '81', 'US']
# ['Ford Grenada gl', '20.2', '6', '200.0', '88.00', '3060.', '17.1', '81', 'US']
# ['Chrysler Lebaron Salon', '17.6', '6', '225.0', '85.00', '3465.', '16.6', '81', 'US']
# ['Chevrolet Cavalier', '28.0', '4', '112.0', '88.00', '2605.', '19.6', '82', 'US']
# ['Chevrolet Cavalier Wagon', '27.0', '4', '112.0', '88.00', '2640.', '18.6', '82', 'US']
# ['Chevrolet Cavalier 2-door', '34.0', '4', '112.0', '88.00', '2395.', '18.0', '82', 'US']
# ['Pontiac J2000 SE Hatchback', '31.0', '4', '112.0', '85.00', '2575.', '16.2', '82', 'US']
# ['Dodge Aries SE', '29.0', '4', '135.0', '84.00', '2525.', '16.0', '82', 'US']
# ['Pontiac Phoenix', '27.0', '4', '151.0', '90.00', '2735.', '18.0', '82', 'US']
# ['Ford Fairmont Futura', '24.0', '4', '140.0', '92.00', '2865.', '16.4', '82', 'US']
# ['AMC Concord DL', '23.0', '4', '151.0', '0', '3035.', '20.5', '82', 'US']
# ['Volkswagen Rabbit l', '36.0', '4', '105.0', '74.00', '1980.', '15.3', '82', 'Europe']
# ['Mazda GLC Custom l', '37.0', '4', '91.00', '68.00', '2025.', '18.2', '82', 'Japan']
# ['Mazda GLC Custom', '31.0', '4', '91.00', '68.00', '1970.', '17.6', '82', 'Japan']
# ['Plymouth Horizon Miser', '38.0', '4', '105.0', '63.00', '2125.', '14.7', '82', 'US']
# ['Mercury Lynx l', '36.0', '4', '98.00', '70.00', '2125.', '17.3', '82', 'US']
# ['Nissan Stanza XE', '36.0', '4', '120.0', '88.00', '2160.', '14.5', '82', 'Japan']
# ['Honda Accord', '36.0', '4', '107.0', '75.00', '2205.', '14.5', '82', 'Japan']
# ['Toyota Corolla', '34.0', '4', '108.0', '70.00', '2245', '16.9', '82', 'Japan']
# ['Honda Civic', '38.0', '4', '91.00', '67.00', '1965.', '15.0', '82', 'Japan']
# ['Honda Civic (auto)', '32.0', '4', '91.00', '67.00', '1965.', '15.7', '82', 'Japan']
# ['Datsun 310 GX', '38.0', '4', '91.00', '67.00', '1995.', '16.2', '82', 'Japan']
# ['Buick Century Limited', '25.0', '6', '181.0', '110.0', '2945.', '16.4', '82', 'US']
# ['Oldsmobile Cutlass Ciera (diesel)', '38.0', '6', '262.0', '85.00', '3015.', '17.0', '82', 'US']
# ['Chrysler Lebaron Medallion', '26.0', '4', '156.0', '92.00', '2585.', '14.5', '82', 'US']
# ['Ford Grenada l', '22.0', '6', '232.0', '112.0', '2835', '14.7', '82', 'US']
# ['Toyota Celica GT', '32.0', '4', '144.0', '96.00', '2665.', '13.9', '82', 'Japan']
# ['Dodge Charger 2.2', '36.0', '4', '135.0', '84.00', '2370.', '13.0', '82', 'US']
# ['Chevrolet Camaro', '27.0', '4', '151.0', '90.00', '2950.', '17.3', '82', 'US']
# ['Ford Mustang GL', '27.0', '4', '140.0', '86.00', '2790.', '15.6', '82', 'US']
# ['Volkswagen Pickup', '44.0', '4', '97.00', '52.00', '2130.', '24.6', '82', 'Europe']
# ['Dodge Rampage', '32.0', '4', '135.0', '84.00', '2295.', '11.6', '82', 'US']
# ['Ford Ranger', '28.0', '4', '120.0', '79.00', '2625.', '18.6', '82', 'US']
# ['Chevy S-10', '31.0', '4', '119.0', '82.00', '2720.', '19.4', '82', 'US']

# %%
from contextlib import contextmanager

@contextmanager
def csv_file_reader(fname: str):
    dialect = get_csv_dialect(fname)
    try:
        f = open(fname)
        csv_reader = csv.reader(f, dialect)
        DataRow = get_data_row_factory(fname)
        next(csv_reader)  # ignore headers as they are handles by DataRow
        def iter_():
            for row in csv_reader:
                yield DataRow(*row)
        yield iter_()
    finally:
        f.close()

# %%
fname = "cars.csv"
DataRow = get_data_row_factory(fname)
with csv_file_reader(fname) as file:
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    for row in file:
        print(row)
# Out:
# DataRow(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# DataRow(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# DataRow(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
# DataRow(car='Ford Galaxie 500', mpg='15.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4341.', acceleration='10.0', model='70', origin='US')
# DataRow(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='454.0', horsepower='220.0', weight='4354.', acceleration='9.0', model='70', origin='US')
# DataRow(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4312.', acceleration='8.5', model='70', origin='US')
# DataRow(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4425.', acceleration='10.0', model='70', origin='US')
# DataRow(car='AMC Ambassador DPL', mpg='15.0', cylinders='8', displacement='390.0', horsepower='190.0', weight='3850.', acceleration='8.5', model='70', origin='US')
# DataRow(car='Citroen DS-21 Pallas', mpg='0', cylinders='4', displacement='133.0', horsepower='115.0', weight='3090.', acceleration='17.5', model='70', origin='Europe')
# DataRow(car='Chevrolet Chevelle Concours (sw)', mpg='0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4142.', acceleration='11.5', model='70', origin='US')
# DataRow(car='Ford Torino (sw)', mpg='0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4034.', acceleration='11.0', model='70', origin='US')
# DataRow(car='Plymouth Satellite (sw)', mpg='0', cylinders='8', displacement='383.0', horsepower='175.0', weight='4166.', acceleration='10.5', model='70', origin='US')
# DataRow(car='AMC Rebel SST (sw)', mpg='0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3850.', acceleration='11.0', model='70', origin='US')
# DataRow(car='Dodge Challenger SE', mpg='15.0', cylinders='8', displacement='383.0', horsepower='170.0', weight='3563.', acceleration='10.0', model='70', origin='US')
# DataRow(car="Plymouth 'Cuda 340", mpg='14.0', cylinders='8', displacement='340.0', horsepower='160.0', weight='3609.', acceleration='8.0', model='70', origin='US')
# DataRow(car='Ford Mustang Boss 302', mpg='0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3353.', acceleration='8.0', model='70', origin='US')
# DataRow(car='Chevrolet Monte Carlo', mpg='15.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='3761.', acceleration='9.5', model='70', origin='US')
# DataRow(car='Buick Estate Wagon (sw)', mpg='14.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='3086.', acceleration='10.0', model='70', origin='US')
# DataRow(car='Toyota Corolla Mark ii', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2372.', acceleration='15.0', model='70', origin='Japan')
# DataRow(car='Plymouth Duster', mpg='22.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2833.', acceleration='15.5', model='70', origin='US')
# DataRow(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='199.0', horsepower='97.00', weight='2774.', acceleration='15.5', model='70', origin='US')
# DataRow(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='85.00', weight='2587.', acceleration='16.0', model='70', origin='US')
# DataRow(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='70', origin='Japan')
# DataRow(car='Volkswagen 1131 Deluxe Sedan', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1835.', acceleration='20.5', model='70', origin='Europe')
# DataRow(car='Peugeot 504', mpg='25.0', cylinders='4', displacement='110.0', horsepower='87.00', weight='2672.', acceleration='17.5', model='70', origin='Europe')
# DataRow(car='Audi 100 LS', mpg='24.0', cylinders='4', displacement='107.0', horsepower='90.00', weight='2430.', acceleration='14.5', model='70', origin='Europe')
# DataRow(car='Saab 99e', mpg='25.0', cylinders='4', displacement='104.0', horsepower='95.00', weight='2375.', acceleration='17.5', model='70', origin='Europe')
# DataRow(car='BMW 2002', mpg='26.0', cylinders='4', displacement='121.0', horsepower='113.0', weight='2234.', acceleration='12.5', model='70', origin='Europe')
# DataRow(car='AMC Gremlin', mpg='21.0', cylinders='6', displacement='199.0', horsepower='90.00', weight='2648.', acceleration='15.0', model='70', origin='US')
# DataRow(car='Ford F250', mpg='10.0', cylinders='8', displacement='360.0', horsepower='215.0', weight='4615.', acceleration='14.0', model='70', origin='US')
# DataRow(car='Chevy C20', mpg='10.0', cylinders='8', displacement='307.0', horsepower='200.0', weight='4376.', acceleration='15.0', model='70', origin='US')
# DataRow(car='Dodge D200', mpg='11.0', cylinders='8', displacement='318.0', horsepower='210.0', weight='4382.', acceleration='13.5', model='70', origin='US')
# DataRow(car='Hi 1200D', mpg='9.0', cylinders='8', displacement='304.0', horsepower='193.0', weight='4732.', acceleration='18.5', model='70', origin='US')
# DataRow(car='Datsun PL510', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2130.', acceleration='14.5', model='71', origin='Japan')
# DataRow(car='Chevrolet Vega 2300', mpg='28.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2264.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Toyota Corolla', mpg='25.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2228.', acceleration='14.0', model='71', origin='Japan')
# DataRow(car='Ford Pinto', mpg='25.0', cylinders='4', displacement='98.00', horsepower='0', weight='2046.', acceleration='19.0', model='71', origin='US')
# DataRow(car='Volkswagen Super Beetle 117', mpg='0', cylinders='4', displacement='97.00', horsepower='48.00', weight='1978.', acceleration='20.0', model='71', origin='Europe')
# DataRow(car='AMC Gremlin', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2634.', acceleration='13.0', model='71', origin='US')
# DataRow(car='Plymouth Satellite Custom', mpg='16.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3439.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Chevrolet Chevelle Malibu', mpg='17.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3329.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Ford Torino 500', mpg='19.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3302.', acceleration='15.5', model='71', origin='US')
# DataRow(car='AMC Matador', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='3288.', acceleration='15.5', model='71', origin='US')
# DataRow(car='Chevrolet Impala', mpg='14.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4209.', acceleration='12.0', model='71', origin='US')
# DataRow(car='Pontiac Catalina Brougham', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4464.', acceleration='11.5', model='71', origin='US')
# DataRow(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4154.', acceleration='13.5', model='71', origin='US')
# DataRow(car='Plymouth Fury iii', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4096.', acceleration='13.0', model='71', origin='US')
# DataRow(car='Dodge Monaco (sw)', mpg='12.0', cylinders='8', displacement='383.0', horsepower='180.0', weight='4955.', acceleration='11.5', model='71', origin='US')
# DataRow(car='Ford Country Squire (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4746.', acceleration='12.0', model='71', origin='US')
# DataRow(car='Pontiac Safari (sw)', mpg='13.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='5140.', acceleration='12.0', model='71', origin='US')
# DataRow(car='AMC Hornet Sportabout (sw)', mpg='18.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='2962.', acceleration='13.5', model='71', origin='US')
# DataRow(car='Chevrolet Vega (sw)', mpg='22.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2408.', acceleration='19.0', model='71', origin='US')
# DataRow(car='Pontiac Firebird', mpg='19.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3282.', acceleration='15.0', model='71', origin='US')
# DataRow(car='Ford Mustang', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3139.', acceleration='14.5', model='71', origin='US')
# DataRow(car='Mercury Capri 2000', mpg='23.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2220.', acceleration='14.0', model='71', origin='US')
# DataRow(car='Opel 1900', mpg='28.0', cylinders='4', displacement='116.0', horsepower='90.00', weight='2123.', acceleration='14.0', model='71', origin='Europe')
# DataRow(car='Peugeot 304', mpg='30.0', cylinders='4', displacement='79.00', horsepower='70.00', weight='2074.', acceleration='19.5', model='71', origin='Europe')
# DataRow(car='Fiat 124B', mpg='30.0', cylinders='4', displacement='88.00', horsepower='76.00', weight='2065.', acceleration='14.5', model='71', origin='Europe')
# DataRow(car='Toyota Corolla 1200', mpg='31.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1773.', acceleration='19.0', model='71', origin='Japan')
# DataRow(car='Datsun 1200', mpg='35.0', cylinders='4', displacement='72.00', horsepower='69.00', weight='1613.', acceleration='18.0', model='71', origin='Japan')
# DataRow(car='Volkswagen Model 111', mpg='27.0', cylinders='4', displacement='97.00', horsepower='60.00', weight='1834.', acceleration='19.0', model='71', origin='Europe')
# DataRow(car='Plymouth Cricket', mpg='26.0', cylinders='4', displacement='91.00', horsepower='70.00', weight='1955.', acceleration='20.5', model='71', origin='US')
# DataRow(car='Toyota Corolla Hardtop', mpg='24.0', cylinders='4', displacement='113.0', horsepower='95.00', weight='2278.', acceleration='15.5', model='72', origin='Japan')
# DataRow(car='Dodge Colt Hardtop', mpg='25.0', cylinders='4', displacement='97.50', horsepower='80.00', weight='2126.', acceleration='17.0', model='72', origin='US')
# DataRow(car='Volkswagen Type 3', mpg='23.0', cylinders='4', displacement='97.00', horsepower='54.00', weight='2254.', acceleration='23.5', model='72', origin='Europe')
# DataRow(car='Chevrolet Vega', mpg='20.0', cylinders='4', displacement='140.0', horsepower='90.00', weight='2408.', acceleration='19.5', model='72', origin='US')
# DataRow(car='Ford Pinto Runabout', mpg='21.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2226.', acceleration='16.5', model='72', origin='US')
# DataRow(car='Chevrolet Impala', mpg='13.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='4274.', acceleration='12.0', model='72', origin='US')
# DataRow(car='Pontiac Catalina', mpg='14.0', cylinders='8', displacement='400.0', horsepower='175.0', weight='4385.', acceleration='12.0', model='72', origin='US')
# DataRow(car='Plymouth Fury III', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4135.', acceleration='13.5', model='72', origin='US')
# DataRow(car='Ford Galaxie 500', mpg='14.0', cylinders='8', displacement='351.0', horsepower='153.0', weight='4129.', acceleration='13.0', model='72', origin='US')
# DataRow(car='AMC Ambassador SST', mpg='17.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='72', origin='US')
# DataRow(car='Mercury Marquis', mpg='11.0', cylinders='8', displacement='429.0', horsepower='208.0', weight='4633.', acceleration='11.0', model='72', origin='US')
# DataRow(car='Buick LeSabre Custom', mpg='13.0', cylinders='8', displacement='350.0', horsepower='155.0', weight='4502.', acceleration='13.5', model='72', origin='US')
# DataRow(car='Oldsmobile Delta 88 Royale', mpg='12.0', cylinders='8', displacement='350.0', horsepower='160.0', weight='4456.', acceleration='13.5', model='72', origin='US')
# DataRow(car='Chrysler Newport Royal', mpg='13.0', cylinders='8', displacement='400.0', horsepower='190.0', weight='4422.', acceleration='12.5', model='72', origin='US')
# DataRow(car='Mazda RX2 Coupe', mpg='19.0', cylinders='3', displacement='70.00', horsepower='97.00', weight='2330.', acceleration='13.5', model='72', origin='Japan')
# DataRow(car='AMC Matador (sw)', mpg='15.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3892.', acceleration='12.5', model='72', origin='US')
# DataRow(car='Chevrolet Chevelle Concours (sw)', mpg='13.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='4098.', acceleration='14.0', model='72', origin='US')
# DataRow(car='Ford Gran Torino (sw)', mpg='13.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4294.', acceleration='16.0', model='72', origin='US')
# DataRow(car='Plymouth Satellite Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4077.', acceleration='14.0', model='72', origin='US')
# DataRow(car='Volvo 145e (sw)', mpg='18.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2933.', acceleration='14.5', model='72', origin='Europe')
# DataRow(car='Volkswagen 411 (sw)', mpg='22.0', cylinders='4', displacement='121.0', horsepower='76.00', weight='2511.', acceleration='18.0', model='72', origin='Europe')
# DataRow(car='Peugeot 504 (sw)', mpg='21.0', cylinders='4', displacement='120.0', horsepower='87.00', weight='2979.', acceleration='19.5', model='72', origin='Europe')
# DataRow(car='Renault 12 (sw)', mpg='26.0', cylinders='4', displacement='96.00', horsepower='69.00', weight='2189.', acceleration='18.0', model='72', origin='Europe')
# DataRow(car='Ford Pinto (sw)', mpg='22.0', cylinders='4', displacement='122.0', horsepower='86.00', weight='2395.', acceleration='16.0', model='72', origin='US')
# DataRow(car='Datsun 510 (sw)', mpg='28.0', cylinders='4', displacement='97.00', horsepower='92.00', weight='2288.', acceleration='17.0', model='72', origin='Japan')
# DataRow(car='Toyota Corolla Mark II (sw)', mpg='23.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2506.', acceleration='14.5', model='72', origin='Japan')
# DataRow(car='Dodge Colt (sw)', mpg='28.0', cylinders='4', displacement='98.00', horsepower='80.00', weight='2164.', acceleration='15.0', model='72', origin='US')
# DataRow(car='Toyota Corolla 1600 (sw)', mpg='27.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2100.', acceleration='16.5', model='72', origin='Japan')
# DataRow(car='Buick Century 350', mpg='13.0', cylinders='8', displacement='350.0', horsepower='175.0', weight='4100.', acceleration='13.0', model='73', origin='US')
# DataRow(car='AMC Matador', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3672.', acceleration='11.5', model='73', origin='US')
# DataRow(car='Chevrolet Malibu', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='3988.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Ford Gran Torino', mpg='14.0', cylinders='8', displacement='302.0', horsepower='137.0', weight='4042.', acceleration='14.5', model='73', origin='US')
# DataRow(car='Dodge Coronet Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3777.', acceleration='12.5', model='73', origin='US')
# DataRow(car='Mercury Marquis Brougham', mpg='12.0', cylinders='8', displacement='429.0', horsepower='198.0', weight='4952.', acceleration='11.5', model='73', origin='US')
# DataRow(car='Chevrolet Caprice Classic', mpg='13.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4464.', acceleration='12.0', model='73', origin='US')
# DataRow(car='Ford LTD', mpg='13.0', cylinders='8', displacement='351.0', horsepower='158.0', weight='4363.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Plymouth Fury Gran Sedan', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4237.', acceleration='14.5', model='73', origin='US')
# DataRow(car='Chrysler New Yorker Brougham', mpg='13.0', cylinders='8', displacement='440.0', horsepower='215.0', weight='4735.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Buick Electra 225 Custom', mpg='12.0', cylinders='8', displacement='455.0', horsepower='225.0', weight='4951.', acceleration='11.0', model='73', origin='US')
# DataRow(car='AMC Ambassador Brougham', mpg='13.0', cylinders='8', displacement='360.0', horsepower='175.0', weight='3821.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Plymouth Valiant', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3121.', acceleration='16.5', model='73', origin='US')
# DataRow(car='Chevrolet Nova Custom', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3278.', acceleration='18.0', model='73', origin='US')
# DataRow(car='AMC Hornet', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2945.', acceleration='16.0', model='73', origin='US')
# DataRow(car='Ford Maverick', mpg='18.0', cylinders='6', displacement='250.0', horsepower='88.00', weight='3021.', acceleration='16.5', model='73', origin='US')
# DataRow(car='Plymouth Duster', mpg='23.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='2904.', acceleration='16.0', model='73', origin='US')
# DataRow(car='Volkswagen Super Beetle', mpg='26.0', cylinders='4', displacement='97.00', horsepower='46.00', weight='1950.', acceleration='21.0', model='73', origin='Europe')
# DataRow(car='Chevrolet Impala', mpg='11.0', cylinders='8', displacement='400.0', horsepower='150.0', weight='4997.', acceleration='14.0', model='73', origin='US')
# DataRow(car='Ford Country', mpg='12.0', cylinders='8', displacement='400.0', horsepower='167.0', weight='4906.', acceleration='12.5', model='73', origin='US')
# DataRow(car='Plymouth Custom Suburb', mpg='13.0', cylinders='8', displacement='360.0', horsepower='170.0', weight='4654.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Oldsmobile Vista Cruiser', mpg='12.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='4499.', acceleration='12.5', model='73', origin='US')
# DataRow(car='AMC Gremlin', mpg='18.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2789.', acceleration='15.0', model='73', origin='US')
# DataRow(car='Toyota Camry', mpg='20.0', cylinders='4', displacement='97.00', horsepower='88.00', weight='2279.', acceleration='19.0', model='73', origin='Japan')
# DataRow(car='Chevrolet Vega', mpg='21.0', cylinders='4', displacement='140.0', horsepower='72.00', weight='2401.', acceleration='19.5', model='73', origin='US')
# DataRow(car='Datsun 610', mpg='22.0', cylinders='4', displacement='108.0', horsepower='94.00', weight='2379.', acceleration='16.5', model='73', origin='Japan')
# DataRow(car='Mazda RX3', mpg='18.0', cylinders='3', displacement='70.00', horsepower='90.00', weight='2124.', acceleration='13.5', model='73', origin='Japan')
# DataRow(car='Ford Pinto', mpg='19.0', cylinders='4', displacement='122.0', horsepower='85.00', weight='2310.', acceleration='18.5', model='73', origin='US')
# DataRow(car='Mercury Capri v6', mpg='21.0', cylinders='6', displacement='155.0', horsepower='107.0', weight='2472.', acceleration='14.0', model='73', origin='US')
# DataRow(car='Fiat 124 Sport Coupe', mpg='26.0', cylinders='4', displacement='98.00', horsepower='90.00', weight='2265.', acceleration='15.5', model='73', origin='Europe')
# DataRow(car='Chevrolet Monte Carlo S', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4082.', acceleration='13.0', model='73', origin='US')
# DataRow(car='Pontiac Grand Prix', mpg='16.0', cylinders='8', displacement='400.0', horsepower='230.0', weight='4278.', acceleration='9.50', model='73', origin='US')
# DataRow(car='Fiat 128', mpg='29.0', cylinders='4', displacement='68.00', horsepower='49.00', weight='1867.', acceleration='19.5', model='73', origin='Europe')
# DataRow(car='Opel Manta', mpg='24.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2158.', acceleration='15.5', model='73', origin='Europe')
# DataRow(car='Audi 100LS', mpg='20.0', cylinders='4', displacement='114.0', horsepower='91.00', weight='2582.', acceleration='14.0', model='73', origin='Europe')
# DataRow(car='Volvo 144ea', mpg='19.0', cylinders='4', displacement='121.0', horsepower='112.0', weight='2868.', acceleration='15.5', model='73', origin='Europe')
# DataRow(car='Dodge Dart Custom', mpg='15.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3399.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Saab 99le', mpg='24.0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2660.', acceleration='14.0', model='73', origin='Europe')
# DataRow(car='Toyota Mark II', mpg='20.0', cylinders='6', displacement='156.0', horsepower='122.0', weight='2807.', acceleration='13.5', model='73', origin='Japan')
# DataRow(car='Oldsmobile Omega', mpg='11.0', cylinders='8', displacement='350.0', horsepower='180.0', weight='3664.', acceleration='11.0', model='73', origin='US')
# DataRow(car='Plymouth Duster', mpg='20.0', cylinders='6', displacement='198.0', horsepower='95.00', weight='3102.', acceleration='16.5', model='74', origin='US')
# DataRow(car='Ford Maverick', mpg='21.0', cylinders='6', displacement='200.0', horsepower='0', weight='2875.', acceleration='17.0', model='74', origin='US')
# DataRow(car='AMC Hornet', mpg='19.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2901.', acceleration='16.0', model='74', origin='US')
# DataRow(car='Chevrolet Nova', mpg='15.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3336.', acceleration='17.0', model='74', origin='US')
# DataRow(car='Datsun B210', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1950.', acceleration='19.0', model='74', origin='Japan')
# DataRow(car='Ford Pinto', mpg='26.0', cylinders='4', displacement='122.0', horsepower='80.00', weight='2451.', acceleration='16.5', model='74', origin='US')
# DataRow(car='Toyota Corolla 1200', mpg='32.0', cylinders='4', displacement='71.00', horsepower='65.00', weight='1836.', acceleration='21.0', model='74', origin='Japan')
# DataRow(car='Chevrolet Vega', mpg='25.0', cylinders='4', displacement='140.0', horsepower='75.00', weight='2542.', acceleration='17.0', model='74', origin='US')
# DataRow(car='Chevrolet Chevelle Malibu Classic', mpg='16.0', cylinders='6', displacement='250.0', horsepower='100.0', weight='3781.', acceleration='17.0', model='74', origin='US')
# DataRow(car='AMC Matador', mpg='16.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3632.', acceleration='18.0', model='74', origin='US')
# DataRow(car='Plymouth Satellite Sebring', mpg='18.0', cylinders='6', displacement='225.0', horsepower='105.0', weight='3613.', acceleration='16.5', model='74', origin='US')
# DataRow(car='Ford Gran Torino', mpg='16.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4141.', acceleration='14.0', model='74', origin='US')
# DataRow(car='Buick Century Luxus (sw)', mpg='13.0', cylinders='8', displacement='350.0', horsepower='150.0', weight='4699.', acceleration='14.5', model='74', origin='US')
# DataRow(car='Dodge Coronet Custom (sw)', mpg='14.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4457.', acceleration='13.5', model='74', origin='US')
# DataRow(car='Ford Gran Torino (sw)', mpg='14.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='4638.', acceleration='16.0', model='74', origin='US')
# DataRow(car='AMC Matador (sw)', mpg='14.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='4257.', acceleration='15.5', model='74', origin='US')
# DataRow(car='Audi Fox', mpg='29.0', cylinders='4', displacement='98.00', horsepower='83.00', weight='2219.', acceleration='16.5', model='74', origin='Europe')
# DataRow(car='Volkswagen Dasher', mpg='26.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='1963.', acceleration='15.5', model='74', origin='Europe')
# DataRow(car='Opel Manta', mpg='26.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='2300.', acceleration='14.5', model='74', origin='Europe')
# DataRow(car='Toyota Corolla', mpg='31.0', cylinders='4', displacement='76.00', horsepower='52.00', weight='1649.', acceleration='16.5', model='74', origin='Japan')
# DataRow(car='Datsun 710', mpg='32.0', cylinders='4', displacement='83.00', horsepower='61.00', weight='2003.', acceleration='19.0', model='74', origin='Japan')
# DataRow(car='Dodge Colt', mpg='28.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2125.', acceleration='14.5', model='74', origin='US')
# DataRow(car='Fiat 128', mpg='24.0', cylinders='4', displacement='90.00', horsepower='75.00', weight='2108.', acceleration='15.5', model='74', origin='Europe')
# DataRow(car='Fiat 124 TC', mpg='26.0', cylinders='4', displacement='116.0', horsepower='75.00', weight='2246.', acceleration='14.0', model='74', origin='Europe')
# DataRow(car='Honda Civic', mpg='24.0', cylinders='4', displacement='120.0', horsepower='97.00', weight='2489.', acceleration='15.0', model='74', origin='Japan')
# DataRow(car='Subaru', mpg='26.0', cylinders='4', displacement='108.0', horsepower='93.00', weight='2391.', acceleration='15.5', model='74', origin='Japan')
# DataRow(car='Fiat x1.9', mpg='31.0', cylinders='4', displacement='79.00', horsepower='67.00', weight='2000.', acceleration='16.0', model='74', origin='Europe')
# DataRow(car='Plymouth Valiant Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3264.', acceleration='16.0', model='75', origin='US')
# DataRow(car='Chevrolet Nova', mpg='18.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3459.', acceleration='16.0', model='75', origin='US')
# DataRow(car='Mercury Monarch', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3432.', acceleration='21.0', model='75', origin='US')
# DataRow(car='Ford Maverick', mpg='15.0', cylinders='6', displacement='250.0', horsepower='72.00', weight='3158.', acceleration='19.5', model='75', origin='US')
# DataRow(car='Pontiac Catalina', mpg='16.0', cylinders='8', displacement='400.0', horsepower='170.0', weight='4668.', acceleration='11.5', model='75', origin='US')
# DataRow(car='Chevrolet Bel Air', mpg='15.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4440.', acceleration='14.0', model='75', origin='US')
# DataRow(car='Plymouth Grand Fury', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4498.', acceleration='14.5', model='75', origin='US')
# DataRow(car='Ford LTD', mpg='14.0', cylinders='8', displacement='351.0', horsepower='148.0', weight='4657.', acceleration='13.5', model='75', origin='US')
# DataRow(car='Buick Century', mpg='17.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3907.', acceleration='21.0', model='75', origin='US')
# DataRow(car='Chevrolete Chevelle Malibu', mpg='16.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3897.', acceleration='18.5', model='75', origin='US')
# DataRow(car='AMC Matador', mpg='15.0', cylinders='6', displacement='258.0', horsepower='110.0', weight='3730.', acceleration='19.0', model='75', origin='US')
# DataRow(car='Plymouth Fury', mpg='18.0', cylinders='6', displacement='225.0', horsepower='95.00', weight='3785.', acceleration='19.0', model='75', origin='US')
# DataRow(car='Buick Skyhawk', mpg='21.0', cylinders='6', displacement='231.0', horsepower='110.0', weight='3039.', acceleration='15.0', model='75', origin='US')
# DataRow(car='Chevrolet Monza 2+2', mpg='20.0', cylinders='8', displacement='262.0', horsepower='110.0', weight='3221.', acceleration='13.5', model='75', origin='US')
# DataRow(car='Ford Mustang II', mpg='13.0', cylinders='8', displacement='302.0', horsepower='129.0', weight='3169.', acceleration='12.0', model='75', origin='US')
# DataRow(car='Toyota Corolla', mpg='29.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2171.', acceleration='16.0', model='75', origin='Japan')
# DataRow(car='Ford Pinto', mpg='23.0', cylinders='4', displacement='140.0', horsepower='83.00', weight='2639.', acceleration='17.0', model='75', origin='US')
# DataRow(car='AMC Gremlin', mpg='20.0', cylinders='6', displacement='232.0', horsepower='100.0', weight='2914.', acceleration='16.0', model='75', origin='US')
# DataRow(car='Pontiac Astro', mpg='23.0', cylinders='4', displacement='140.0', horsepower='78.00', weight='2592.', acceleration='18.5', model='75', origin='US')
# DataRow(car='Toyota Corolla', mpg='24.0', cylinders='4', displacement='134.0', horsepower='96.00', weight='2702.', acceleration='13.5', model='75', origin='Japan')
# DataRow(car='Volkswagen Dasher', mpg='25.0', cylinders='4', displacement='90.00', horsepower='71.00', weight='2223.', acceleration='16.5', model='75', origin='Europe')
# DataRow(car='Datsun 710', mpg='24.0', cylinders='4', displacement='119.0', horsepower='97.00', weight='2545.', acceleration='17.0', model='75', origin='Japan')
# DataRow(car='Ford Pinto', mpg='18.0', cylinders='6', displacement='171.0', horsepower='97.00', weight='2984.', acceleration='14.5', model='75', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.0', model='75', origin='Europe')
# DataRow(car='AMC Pacer', mpg='19.0', cylinders='6', displacement='232.0', horsepower='90.00', weight='3211.', acceleration='17.0', model='75', origin='US')
# DataRow(car='Audi 100LS', mpg='23.0', cylinders='4', displacement='115.0', horsepower='95.00', weight='2694.', acceleration='15.0', model='75', origin='Europe')
# DataRow(car='Peugeot 504', mpg='23.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2957.', acceleration='17.0', model='75', origin='Europe')
# DataRow(car='Volvo 244DL', mpg='22.0', cylinders='4', displacement='121.0', horsepower='98.00', weight='2945.', acceleration='14.5', model='75', origin='Europe')
# DataRow(car='Saab 99LE', mpg='25.0', cylinders='4', displacement='121.0', horsepower='115.0', weight='2671.', acceleration='13.5', model='75', origin='Europe')
# DataRow(car='Honda Civic CVCC', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.5', model='75', origin='Japan')
# DataRow(car='Fiat 131', mpg='28.0', cylinders='4', displacement='107.0', horsepower='86.00', weight='2464.', acceleration='15.5', model='76', origin='Europe')
# DataRow(car='Opel 1900', mpg='25.0', cylinders='4', displacement='116.0', horsepower='81.00', weight='2220.', acceleration='16.9', model='76', origin='Europe')
# DataRow(car='Capri ii', mpg='25.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2572.', acceleration='14.9', model='76', origin='US')
# DataRow(car='Dodge Colt', mpg='26.0', cylinders='4', displacement='98.00', horsepower='79.00', weight='2255.', acceleration='17.7', model='76', origin='US')
# DataRow(car='Renault 12tl', mpg='27.0', cylinders='4', displacement='101.0', horsepower='83.00', weight='2202.', acceleration='15.3', model='76', origin='Europe')
# DataRow(car='Chevrolet Chevelle Malibu Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='140.0', weight='4215.', acceleration='13.0', model='76', origin='US')
# DataRow(car='Dodge Coronet Brougham', mpg='16.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='4190.', acceleration='13.0', model='76', origin='US')
# DataRow(car='AMC Matador', mpg='15.5', cylinders='8', displacement='304.0', horsepower='120.0', weight='3962.', acceleration='13.9', model='76', origin='US')
# DataRow(car='Ford Gran Torino', mpg='14.5', cylinders='8', displacement='351.0', horsepower='152.0', weight='4215.', acceleration='12.8', model='76', origin='US')
# DataRow(car='Plymouth Valiant', mpg='22.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3233.', acceleration='15.4', model='76', origin='US')
# DataRow(car='Chevrolet Nova', mpg='22.0', cylinders='6', displacement='250.0', horsepower='105.0', weight='3353.', acceleration='14.5', model='76', origin='US')
# DataRow(car='Ford Maverick', mpg='24.0', cylinders='6', displacement='200.0', horsepower='81.00', weight='3012.', acceleration='17.6', model='76', origin='US')
# DataRow(car='AMC Hornet', mpg='22.5', cylinders='6', displacement='232.0', horsepower='90.00', weight='3085.', acceleration='17.6', model='76', origin='US')
# DataRow(car='Chevrolet Chevette', mpg='29.0', cylinders='4', displacement='85.00', horsepower='52.00', weight='2035.', acceleration='22.2', model='76', origin='US')
# DataRow(car='Chevrolet Woody', mpg='24.5', cylinders='4', displacement='98.00', horsepower='60.00', weight='2164.', acceleration='22.1', model='76', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='29.0', cylinders='4', displacement='90.00', horsepower='70.00', weight='1937.', acceleration='14.2', model='76', origin='Europe')
# DataRow(car='Honda Civic', mpg='33.0', cylinders='4', displacement='91.00', horsepower='53.00', weight='1795.', acceleration='17.4', model='76', origin='Japan')
# DataRow(car='Dodge Aspen SE', mpg='20.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3651.', acceleration='17.7', model='76', origin='US')
# DataRow(car='Ford Grenada ghia', mpg='18.0', cylinders='6', displacement='250.0', horsepower='78.00', weight='3574.', acceleration='21.0', model='76', origin='US')
# DataRow(car='Pontiac Ventura SJ', mpg='18.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3645.', acceleration='16.2', model='76', origin='US')
# DataRow(car='AMC Pacer d/l', mpg='17.5', cylinders='6', displacement='258.0', horsepower='95.00', weight='3193.', acceleration='17.8', model='76', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='29.5', cylinders='4', displacement='97.00', horsepower='71.00', weight='1825.', acceleration='12.2', model='76', origin='Europe')
# DataRow(car='Datsun B-210', mpg='32.0', cylinders='4', displacement='85.00', horsepower='70.00', weight='1990.', acceleration='17.0', model='76', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='28.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2155.', acceleration='16.4', model='76', origin='Japan')
# DataRow(car='Ford Pinto', mpg='26.5', cylinders='4', displacement='140.0', horsepower='72.00', weight='2565.', acceleration='13.6', model='76', origin='US')
# DataRow(car='Volvo 245', mpg='20.0', cylinders='4', displacement='130.0', horsepower='102.0', weight='3150.', acceleration='15.7', model='76', origin='Europe')
# DataRow(car='Plymouth Volare Premier v8', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3940.', acceleration='13.2', model='76', origin='US')
# DataRow(car='Peugeot 504', mpg='19.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='3270.', acceleration='21.9', model='76', origin='Europe')
# DataRow(car='Toyota Mark II', mpg='19.0', cylinders='6', displacement='156.0', horsepower='108.0', weight='2930.', acceleration='15.5', model='76', origin='Japan')
# DataRow(car='Mercedes-Benz 280s', mpg='16.5', cylinders='6', displacement='168.0', horsepower='120.0', weight='3820.', acceleration='16.7', model='76', origin='Europe')
# DataRow(car='Cadillac Seville', mpg='16.5', cylinders='8', displacement='350.0', horsepower='180.0', weight='4380.', acceleration='12.1', model='76', origin='US')
# DataRow(car='Chevrolet C10', mpg='13.0', cylinders='8', displacement='350.0', horsepower='145.0', weight='4055.', acceleration='12.0', model='76', origin='US')
# DataRow(car='Ford F108', mpg='13.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='3870.', acceleration='15.0', model='76', origin='US')
# DataRow(car='Dodge D100', mpg='13.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3755.', acceleration='14.0', model='76', origin='US')
# DataRow(car='Honda Accord CVCC', mpg='31.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2045.', acceleration='18.5', model='77', origin='Japan')
# DataRow(car='Buick Opel Isuzu Deluxe', mpg='30.0', cylinders='4', displacement='111.0', horsepower='80.00', weight='2155.', acceleration='14.8', model='77', origin='US')
# DataRow(car='Renault 5 GTL', mpg='36.0', cylinders='4', displacement='79.00', horsepower='58.00', weight='1825.', acceleration='18.6', model='77', origin='Europe')
# DataRow(car='Plymouth Arrow GS', mpg='25.5', cylinders='4', displacement='122.0', horsepower='96.00', weight='2300.', acceleration='15.5', model='77', origin='US')
# DataRow(car='Datsun F-10 Hatchback', mpg='33.5', cylinders='4', displacement='85.00', horsepower='70.00', weight='1945.', acceleration='16.8', model='77', origin='Japan')
# DataRow(car='Chevrolet Caprice Classic', mpg='17.5', cylinders='8', displacement='305.0', horsepower='145.0', weight='3880.', acceleration='12.5', model='77', origin='US')
# DataRow(car='Oldsmobile Cutlass Supreme', mpg='17.0', cylinders='8', displacement='260.0', horsepower='110.0', weight='4060.', acceleration='19.0', model='77', origin='US')
# DataRow(car='Dodge Monaco Brougham', mpg='15.5', cylinders='8', displacement='318.0', horsepower='145.0', weight='4140.', acceleration='13.7', model='77', origin='US')
# DataRow(car='Mercury Cougar Brougham', mpg='15.0', cylinders='8', displacement='302.0', horsepower='130.0', weight='4295.', acceleration='14.9', model='77', origin='US')
# DataRow(car='Chevrolet Concours', mpg='17.5', cylinders='6', displacement='250.0', horsepower='110.0', weight='3520.', acceleration='16.4', model='77', origin='US')
# DataRow(car='Buick Skylark', mpg='20.5', cylinders='6', displacement='231.0', horsepower='105.0', weight='3425.', acceleration='16.9', model='77', origin='US')
# DataRow(car='Plymouth Volare Custom', mpg='19.0', cylinders='6', displacement='225.0', horsepower='100.0', weight='3630.', acceleration='17.7', model='77', origin='US')
# DataRow(car='Ford Grenada', mpg='18.5', cylinders='6', displacement='250.0', horsepower='98.00', weight='3525.', acceleration='19.0', model='77', origin='US')
# DataRow(car='Pontiac Grand Prix LJ', mpg='16.0', cylinders='8', displacement='400.0', horsepower='180.0', weight='4220.', acceleration='11.1', model='77', origin='US')
# DataRow(car='Chevrolet Monte Carlo Landau', mpg='15.5', cylinders='8', displacement='350.0', horsepower='170.0', weight='4165.', acceleration='11.4', model='77', origin='US')
# DataRow(car='Chrysler Cordoba', mpg='15.5', cylinders='8', displacement='400.0', horsepower='190.0', weight='4325.', acceleration='12.2', model='77', origin='US')
# DataRow(car='Ford Thunderbird', mpg='16.0', cylinders='8', displacement='351.0', horsepower='149.0', weight='4335.', acceleration='14.5', model='77', origin='US')
# DataRow(car='Volkswagen Rabbit Custom', mpg='29.0', cylinders='4', displacement='97.00', horsepower='78.00', weight='1940.', acceleration='14.5', model='77', origin='Europe')
# DataRow(car='Pontiac Sunbird Coupe', mpg='24.5', cylinders='4', displacement='151.0', horsepower='88.00', weight='2740.', acceleration='16.0', model='77', origin='US')
# DataRow(car='Toyota Corolla Liftback', mpg='26.0', cylinders='4', displacement='97.00', horsepower='75.00', weight='2265.', acceleration='18.2', model='77', origin='Japan')
# DataRow(car='Ford Mustang II 2+2', mpg='25.5', cylinders='4', displacement='140.0', horsepower='89.00', weight='2755.', acceleration='15.8', model='77', origin='US')
# DataRow(car='Chevrolet Chevette', mpg='30.5', cylinders='4', displacement='98.00', horsepower='63.00', weight='2051.', acceleration='17.0', model='77', origin='US')
# DataRow(car='Dodge Colt m/m', mpg='33.5', cylinders='4', displacement='98.00', horsepower='83.00', weight='2075.', acceleration='15.9', model='77', origin='US')
# DataRow(car='Subaru DL', mpg='30.0', cylinders='4', displacement='97.00', horsepower='67.00', weight='1985.', acceleration='16.4', model='77', origin='Japan')
# DataRow(car='Volkswagen Dasher', mpg='30.5', cylinders='4', displacement='97.00', horsepower='78.00', weight='2190.', acceleration='14.1', model='77', origin='Europe')
# DataRow(car='Datsun 810', mpg='22.0', cylinders='6', displacement='146.0', horsepower='97.00', weight='2815.', acceleration='14.5', model='77', origin='Japan')
# DataRow(car='BMW 320i', mpg='21.5', cylinders='4', displacement='121.0', horsepower='110.0', weight='2600.', acceleration='12.8', model='77', origin='Europe')
# DataRow(car='Mazda RX-4', mpg='21.5', cylinders='3', displacement='80.00', horsepower='110.0', weight='2720.', acceleration='13.5', model='77', origin='Japan')
# DataRow(car='Volkswagen Rabbit Custom Diesel', mpg='43.1', cylinders='4', displacement='90.00', horsepower='48.00', weight='1985.', acceleration='21.5', model='78', origin='Europe')
# DataRow(car='Ford Fiesta', mpg='36.1', cylinders='4', displacement='98.00', horsepower='66.00', weight='1800.', acceleration='14.4', model='78', origin='US')
# DataRow(car='Mazda GLC Deluxe', mpg='32.8', cylinders='4', displacement='78.00', horsepower='52.00', weight='1985.', acceleration='19.4', model='78', origin='Japan')
# DataRow(car='Datsun B210 GX', mpg='39.4', cylinders='4', displacement='85.00', horsepower='70.00', weight='2070.', acceleration='18.6', model='78', origin='Japan')
# DataRow(car='Honda Civic CVCC', mpg='36.1', cylinders='4', displacement='91.00', horsepower='60.00', weight='1800.', acceleration='16.4', model='78', origin='Japan')
# DataRow(car='Oldsmobile Cutlass Salon Brougham', mpg='19.9', cylinders='8', displacement='260.0', horsepower='110.0', weight='3365.', acceleration='15.5', model='78', origin='US')
# DataRow(car='Dodge Diplomat', mpg='19.4', cylinders='8', displacement='318.0', horsepower='140.0', weight='3735.', acceleration='13.2', model='78', origin='US')
# DataRow(car='Mercury Monarch ghia', mpg='20.2', cylinders='8', displacement='302.0', horsepower='139.0', weight='3570.', acceleration='12.8', model='78', origin='US')
# DataRow(car='Pontiac Phoenix LJ', mpg='19.2', cylinders='6', displacement='231.0', horsepower='105.0', weight='3535.', acceleration='19.2', model='78', origin='US')
# DataRow(car='Chevrolet Malibu', mpg='20.5', cylinders='6', displacement='200.0', horsepower='95.00', weight='3155.', acceleration='18.2', model='78', origin='US')
# DataRow(car='Ford Fairmont (auto)', mpg='20.2', cylinders='6', displacement='200.0', horsepower='85.00', weight='2965.', acceleration='15.8', model='78', origin='US')
# DataRow(car='Ford Fairmont (man)', mpg='25.1', cylinders='4', displacement='140.0', horsepower='88.00', weight='2720.', acceleration='15.4', model='78', origin='US')
# DataRow(car='Plymouth Volare', mpg='20.5', cylinders='6', displacement='225.0', horsepower='100.0', weight='3430.', acceleration='17.2', model='78', origin='US')
# DataRow(car='AMC Concord', mpg='19.4', cylinders='6', displacement='232.0', horsepower='90.00', weight='3210.', acceleration='17.2', model='78', origin='US')
# DataRow(car='Buick Century Special', mpg='20.6', cylinders='6', displacement='231.0', horsepower='105.0', weight='3380.', acceleration='15.8', model='78', origin='US')
# DataRow(car='Mercury Zephyr', mpg='20.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='3070.', acceleration='16.7', model='78', origin='US')
# DataRow(car='Dodge Aspen', mpg='18.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3620.', acceleration='18.7', model='78', origin='US')
# DataRow(car='AMC Concord d/l', mpg='18.1', cylinders='6', displacement='258.0', horsepower='120.0', weight='3410.', acceleration='15.1', model='78', origin='US')
# DataRow(car='Chevrolet Monte Carlo Landau', mpg='19.2', cylinders='8', displacement='305.0', horsepower='145.0', weight='3425.', acceleration='13.2', model='78', origin='US')
# DataRow(car='Buick Regal Sport Coupe (turbo)', mpg='17.7', cylinders='6', displacement='231.0', horsepower='165.0', weight='3445.', acceleration='13.4', model='78', origin='US')
# DataRow(car='Ford Futura', mpg='18.1', cylinders='8', displacement='302.0', horsepower='139.0', weight='3205.', acceleration='11.2', model='78', origin='US')
# DataRow(car='Dodge Magnum XE', mpg='17.5', cylinders='8', displacement='318.0', horsepower='140.0', weight='4080.', acceleration='13.7', model='78', origin='US')
# DataRow(car='Chevrolet Chevette', mpg='30.0', cylinders='4', displacement='98.00', horsepower='68.00', weight='2155.', acceleration='16.5', model='78', origin='US')
# DataRow(car='Toyota Corolla', mpg='27.5', cylinders='4', displacement='134.0', horsepower='95.00', weight='2560.', acceleration='14.2', model='78', origin='Japan')
# DataRow(car='Datsun 510', mpg='27.2', cylinders='4', displacement='119.0', horsepower='97.00', weight='2300.', acceleration='14.7', model='78', origin='Japan')
# DataRow(car='Dodge Omni', mpg='30.9', cylinders='4', displacement='105.0', horsepower='75.00', weight='2230.', acceleration='14.5', model='78', origin='US')
# DataRow(car='Toyota Celica GT Liftback', mpg='21.1', cylinders='4', displacement='134.0', horsepower='95.00', weight='2515.', acceleration='14.8', model='78', origin='Japan')
# DataRow(car='Plymouth Sapporo', mpg='23.2', cylinders='4', displacement='156.0', horsepower='105.0', weight='2745.', acceleration='16.7', model='78', origin='US')
# DataRow(car='Oldsmobile Starfire SX', mpg='23.8', cylinders='4', displacement='151.0', horsepower='85.00', weight='2855.', acceleration='17.6', model='78', origin='US')
# DataRow(car='Datsun 200-SX', mpg='23.9', cylinders='4', displacement='119.0', horsepower='97.00', weight='2405.', acceleration='14.9', model='78', origin='Japan')
# DataRow(car='Audi 5000', mpg='20.3', cylinders='5', displacement='131.0', horsepower='103.0', weight='2830.', acceleration='15.9', model='78', origin='Europe')
# DataRow(car='Volvo 264gl', mpg='17.0', cylinders='6', displacement='163.0', horsepower='125.0', weight='3140.', acceleration='13.6', model='78', origin='Europe')
# DataRow(car='Saab 99gle', mpg='21.6', cylinders='4', displacement='121.0', horsepower='115.0', weight='2795.', acceleration='15.7', model='78', origin='Europe')
# DataRow(car='Peugeot 604sl', mpg='16.2', cylinders='6', displacement='163.0', horsepower='133.0', weight='3410.', acceleration='15.8', model='78', origin='Europe')
# DataRow(car='Volkswagen Scirocco', mpg='31.5', cylinders='4', displacement='89.00', horsepower='71.00', weight='1990.', acceleration='14.9', model='78', origin='Europe')
# DataRow(car='Honda Accord LX', mpg='29.5', cylinders='4', displacement='98.00', horsepower='68.00', weight='2135.', acceleration='16.6', model='78', origin='Japan')
# DataRow(car='Pontiac Lemans V6', mpg='21.5', cylinders='6', displacement='231.0', horsepower='115.0', weight='3245.', acceleration='15.4', model='79', origin='US')
# DataRow(car='Mercury Zephyr 6', mpg='19.8', cylinders='6', displacement='200.0', horsepower='85.00', weight='2990.', acceleration='18.2', model='79', origin='US')
# DataRow(car='Ford Fairmont 4', mpg='22.3', cylinders='4', displacement='140.0', horsepower='88.00', weight='2890.', acceleration='17.3', model='79', origin='US')
# DataRow(car='AMC Concord DL 6', mpg='20.2', cylinders='6', displacement='232.0', horsepower='90.00', weight='3265.', acceleration='18.2', model='79', origin='US')
# DataRow(car='Dodge Aspen 6', mpg='20.6', cylinders='6', displacement='225.0', horsepower='110.0', weight='3360.', acceleration='16.6', model='79', origin='US')
# ...
# DataRow(car='Plymouth Horizon TC3', mpg='34.5', cylinders='4', displacement='105.0', horsepower='70.00', weight='2150.', acceleration='14.9', model='79', origin='US')
# DataRow(car='Datsun 210', mpg='31.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2020.', acceleration='19.2', model='79', origin='Japan')
# DataRow(car='Fiat Strada Custom', mpg='37.3', cylinders='4', displacement='91.00', horsepower='69.00', weight='2130.', acceleration='14.7', model='79', origin='Europe')
# DataRow(car='Buick Skylark Limited', mpg='28.4', cylinders='4', displacement='151.0', horsepower='90.00', weight='2670.', acceleration='16.0', model='79', origin='US')
# DataRow(car='Chevrolet Citation', mpg='28.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2595.', acceleration='11.3', model='79', origin='US')
# DataRow(car='Oldsmobile Omega Brougham', mpg='26.8', cylinders='6', displacement='173.0', horsepower='115.0', weight='2700.', acceleration='12.9', model='79', origin='US')
# DataRow(car='Pontiac Phoenix', mpg='33.5', cylinders='4', displacement='151.0', horsepower='90.00', weight='2556.', acceleration='13.2', model='79', origin='US')
# DataRow(car='Volkswagen Rabbit', mpg='41.5', cylinders='4', displacement='98.00', horsepower='76.00', weight='2144.', acceleration='14.7', model='80', origin='Europe')
# DataRow(car='Toyota Corolla Tercel', mpg='38.1', cylinders='4', displacement='89.00', horsepower='60.00', weight='1968.', acceleration='18.8', model='80', origin='Japan')
# DataRow(car='Chevrolet Chevette', mpg='32.1', cylinders='4', displacement='98.00', horsepower='70.00', weight='2120.', acceleration='15.5', model='80', origin='US')
# DataRow(car='Datsun 310', mpg='37.2', cylinders='4', displacement='86.00', horsepower='65.00', weight='2019.', acceleration='16.4', model='80', origin='Japan')
# DataRow(car='Chevrolet Citation', mpg='28.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2678.', acceleration='16.5', model='80', origin='US')
# DataRow(car='Ford Fairmont', mpg='26.4', cylinders='4', displacement='140.0', horsepower='88.00', weight='2870.', acceleration='18.1', model='80', origin='US')
# DataRow(car='AMC Concord', mpg='24.3', cylinders='4', displacement='151.0', horsepower='90.00', weight='3003.', acceleration='20.1', model='80', origin='US')
# DataRow(car='Dodge Aspen', mpg='19.1', cylinders='6', displacement='225.0', horsepower='90.00', weight='3381.', acceleration='18.7', model='80', origin='US')
# DataRow(car='Audi 4000', mpg='34.3', cylinders='4', displacement='97.00', horsepower='78.00', weight='2188.', acceleration='15.8', model='80', origin='Europe')
# DataRow(car='Toyota Corolla Liftback', mpg='29.8', cylinders='4', displacement='134.0', horsepower='90.00', weight='2711.', acceleration='15.5', model='80', origin='Japan')
# DataRow(car='Mazda 626', mpg='31.3', cylinders='4', displacement='120.0', horsepower='75.00', weight='2542.', acceleration='17.5', model='80', origin='Japan')
# DataRow(car='Datsun 510 Hatchback', mpg='37.0', cylinders='4', displacement='119.0', horsepower='92.00', weight='2434.', acceleration='15.0', model='80', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='32.2', cylinders='4', displacement='108.0', horsepower='75.00', weight='2265.', acceleration='15.2', model='80', origin='Japan')
# DataRow(car='Mazda GLC', mpg='46.6', cylinders='4', displacement='86.00', horsepower='65.00', weight='2110.', acceleration='17.9', model='80', origin='Japan')
# DataRow(car='Dodge Colt', mpg='27.9', cylinders='4', displacement='156.0', horsepower='105.0', weight='2800.', acceleration='14.4', model='80', origin='US')
# DataRow(car='Datsun 210', mpg='40.8', cylinders='4', displacement='85.00', horsepower='65.00', weight='2110.', acceleration='19.2', model='80', origin='Japan')
# DataRow(car='Volkswagen Rabbit C (Diesel)', mpg='44.3', cylinders='4', displacement='90.00', horsepower='48.00', weight='2085.', acceleration='21.7', model='80', origin='Europe')
# DataRow(car='Volkswagen Dasher (diesel)', mpg='43.4', cylinders='4', displacement='90.00', horsepower='48.00', weight='2335.', acceleration='23.7', model='80', origin='Europe')
# DataRow(car='Audi 5000s (diesel)', mpg='36.4', cylinders='5', displacement='121.0', horsepower='67.00', weight='2950.', acceleration='19.9', model='80', origin='Europe')
# DataRow(car='Mercedes-Benz 240d', mpg='30.0', cylinders='4', displacement='146.0', horsepower='67.00', weight='3250.', acceleration='21.8', model='80', origin='Europe')
# DataRow(car='Honda Civic 1500 gl', mpg='44.6', cylinders='4', displacement='91.00', horsepower='67.00', weight='1850.', acceleration='13.8', model='80', origin='Japan')
# DataRow(car='Renault Lecar Deluxe', mpg='40.9', cylinders='4', displacement='85.00', horsepower='0', weight='1835.', acceleration='17.3', model='80', origin='Europe')
# DataRow(car='Subaru DL', mpg='33.8', cylinders='4', displacement='97.00', horsepower='67.00', weight='2145.', acceleration='18.0', model='80', origin='Japan')
# DataRow(car='Volkswagen Rabbit', mpg='29.8', cylinders='4', displacement='89.00', horsepower='62.00', weight='1845.', acceleration='15.3', model='80', origin='Europe')
# DataRow(car='Datsun 280-ZX', mpg='32.7', cylinders='6', displacement='168.0', horsepower='132.0', weight='2910.', acceleration='11.4', model='80', origin='Japan')
# DataRow(car='Mazda RX-7 GS', mpg='23.7', cylinders='3', displacement='70.00', horsepower='100.0', weight='2420.', acceleration='12.5', model='80', origin='Japan')
# DataRow(car='Triumph TR7 Coupe', mpg='35.0', cylinders='4', displacement='122.0', horsepower='88.00', weight='2500.', acceleration='15.1', model='80', origin='Europe')
# DataRow(car='Ford Mustang Cobra', mpg='23.6', cylinders='4', displacement='140.0', horsepower='0', weight='2905.', acceleration='14.3', model='80', origin='US')
# DataRow(car='Honda Accord', mpg='32.4', cylinders='4', displacement='107.0', horsepower='72.00', weight='2290.', acceleration='17.0', model='80', origin='Japan')
# DataRow(car='Plymouth Reliant', mpg='27.2', cylinders='4', displacement='135.0', horsepower='84.00', weight='2490.', acceleration='15.7', model='81', origin='US')
# DataRow(car='Buick Skylark', mpg='26.6', cylinders='4', displacement='151.0', horsepower='84.00', weight='2635.', acceleration='16.4', model='81', origin='US')
# DataRow(car='Dodge Aries Wagon (sw)', mpg='25.8', cylinders='4', displacement='156.0', horsepower='92.00', weight='2620.', acceleration='14.4', model='81', origin='US')
# DataRow(car='Chevrolet Citation', mpg='23.5', cylinders='6', displacement='173.0', horsepower='110.0', weight='2725.', acceleration='12.6', model='81', origin='US')
# DataRow(car='Plymouth Reliant', mpg='30.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2385.', acceleration='12.9', model='81', origin='US')
# DataRow(car='Toyota Starlet', mpg='39.1', cylinders='4', displacement='79.00', horsepower='58.00', weight='1755.', acceleration='16.9', model='81', origin='Japan')
# DataRow(car='Plymouth Champ', mpg='39.0', cylinders='4', displacement='86.00', horsepower='64.00', weight='1875.', acceleration='16.4', model='81', origin='US')
# DataRow(car='Honda Civic 1300', mpg='35.1', cylinders='4', displacement='81.00', horsepower='60.00', weight='1760.', acceleration='16.1', model='81', origin='Japan')
# DataRow(car='Subaru', mpg='32.3', cylinders='4', displacement='97.00', horsepower='67.00', weight='2065.', acceleration='17.8', model='81', origin='Japan')
# DataRow(car='Datsun 210 MPG', mpg='37.0', cylinders='4', displacement='85.00', horsepower='65.00', weight='1975.', acceleration='19.4', model='81', origin='Japan')
# DataRow(car='Toyota Tercel', mpg='37.7', cylinders='4', displacement='89.00', horsepower='62.00', weight='2050.', acceleration='17.3', model='81', origin='Japan')
# DataRow(car='Mazda GLC 4', mpg='34.1', cylinders='4', displacement='91.00', horsepower='68.00', weight='1985.', acceleration='16.0', model='81', origin='Japan')
# DataRow(car='Plymouth Horizon 4', mpg='34.7', cylinders='4', displacement='105.0', horsepower='63.00', weight='2215.', acceleration='14.9', model='81', origin='US')
# DataRow(car='Ford Escort 4W', mpg='34.4', cylinders='4', displacement='98.00', horsepower='65.00', weight='2045.', acceleration='16.2', model='81', origin='US')
# DataRow(car='Ford Escort 2H', mpg='29.9', cylinders='4', displacement='98.00', horsepower='65.00', weight='2380.', acceleration='20.7', model='81', origin='US')
# DataRow(car='Volkswagen Jetta', mpg='33.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='2190.', acceleration='14.2', model='81', origin='Europe')
# DataRow(car='Renault 18i', mpg='34.5', cylinders='4', displacement='100.0', horsepower='0', weight='2320.', acceleration='15.8', model='81', origin='Europe')
# DataRow(car='Honda Prelude', mpg='33.7', cylinders='4', displacement='107.0', horsepower='75.00', weight='2210.', acceleration='14.4', model='81', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='32.4', cylinders='4', displacement='108.0', horsepower='75.00', weight='2350.', acceleration='16.8', model='81', origin='Japan')
# DataRow(car='Datsun 200SX', mpg='32.9', cylinders='4', displacement='119.0', horsepower='100.0', weight='2615.', acceleration='14.8', model='81', origin='Japan')
# DataRow(car='Mazda 626', mpg='31.6', cylinders='4', displacement='120.0', horsepower='74.00', weight='2635.', acceleration='18.3', model='81', origin='Japan')
# DataRow(car='Peugeot 505s Turbo Diesel', mpg='28.1', cylinders='4', displacement='141.0', horsepower='80.00', weight='3230.', acceleration='20.4', model='81', origin='Europe')
# DataRow(car='Saab 900s', mpg='0', cylinders='4', displacement='121.0', horsepower='110.0', weight='2800.', acceleration='15.4', model='81', origin='Europe')
# DataRow(car='Volvo Diesel', mpg='30.7', cylinders='6', displacement='145.0', horsepower='76.00', weight='3160.', acceleration='19.6', model='81', origin='Europe')
# DataRow(car='Toyota Cressida', mpg='25.4', cylinders='6', displacement='168.0', horsepower='116.0', weight='2900.', acceleration='12.6', model='81', origin='Japan')
# DataRow(car='Datsun 810 Maxima', mpg='24.2', cylinders='6', displacement='146.0', horsepower='120.0', weight='2930.', acceleration='13.8', model='81', origin='Japan')
# DataRow(car='Buick Century', mpg='22.4', cylinders='6', displacement='231.0', horsepower='110.0', weight='3415.', acceleration='15.8', model='81', origin='US')
# DataRow(car='Oldsmobile Cutlass LS', mpg='26.6', cylinders='8', displacement='350.0', horsepower='105.0', weight='3725.', acceleration='19.0', model='81', origin='US')
# DataRow(car='Ford Grenada gl', mpg='20.2', cylinders='6', displacement='200.0', horsepower='88.00', weight='3060.', acceleration='17.1', model='81', origin='US')
# DataRow(car='Chrysler Lebaron Salon', mpg='17.6', cylinders='6', displacement='225.0', horsepower='85.00', weight='3465.', acceleration='16.6', model='81', origin='US')
# DataRow(car='Chevrolet Cavalier', mpg='28.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2605.', acceleration='19.6', model='82', origin='US')
# DataRow(car='Chevrolet Cavalier Wagon', mpg='27.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2640.', acceleration='18.6', model='82', origin='US')
# DataRow(car='Chevrolet Cavalier 2-door', mpg='34.0', cylinders='4', displacement='112.0', horsepower='88.00', weight='2395.', acceleration='18.0', model='82', origin='US')
# DataRow(car='Pontiac J2000 SE Hatchback', mpg='31.0', cylinders='4', displacement='112.0', horsepower='85.00', weight='2575.', acceleration='16.2', model='82', origin='US')
# DataRow(car='Dodge Aries SE', mpg='29.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2525.', acceleration='16.0', model='82', origin='US')
# DataRow(car='Pontiac Phoenix', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2735.', acceleration='18.0', model='82', origin='US')
# DataRow(car='Ford Fairmont Futura', mpg='24.0', cylinders='4', displacement='140.0', horsepower='92.00', weight='2865.', acceleration='16.4', model='82', origin='US')
# DataRow(car='AMC Concord DL', mpg='23.0', cylinders='4', displacement='151.0', horsepower='0', weight='3035.', acceleration='20.5', model='82', origin='US')
# DataRow(car='Volkswagen Rabbit l', mpg='36.0', cylinders='4', displacement='105.0', horsepower='74.00', weight='1980.', acceleration='15.3', model='82', origin='Europe')
# DataRow(car='Mazda GLC Custom l', mpg='37.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='2025.', acceleration='18.2', model='82', origin='Japan')
# DataRow(car='Mazda GLC Custom', mpg='31.0', cylinders='4', displacement='91.00', horsepower='68.00', weight='1970.', acceleration='17.6', model='82', origin='Japan')
# DataRow(car='Plymouth Horizon Miser', mpg='38.0', cylinders='4', displacement='105.0', horsepower='63.00', weight='2125.', acceleration='14.7', model='82', origin='US')
# DataRow(car='Mercury Lynx l', mpg='36.0', cylinders='4', displacement='98.00', horsepower='70.00', weight='2125.', acceleration='17.3', model='82', origin='US')
# DataRow(car='Nissan Stanza XE', mpg='36.0', cylinders='4', displacement='120.0', horsepower='88.00', weight='2160.', acceleration='14.5', model='82', origin='Japan')
# DataRow(car='Honda Accord', mpg='36.0', cylinders='4', displacement='107.0', horsepower='75.00', weight='2205.', acceleration='14.5', model='82', origin='Japan')
# DataRow(car='Toyota Corolla', mpg='34.0', cylinders='4', displacement='108.0', horsepower='70.00', weight='2245', acceleration='16.9', model='82', origin='Japan')
# DataRow(car='Honda Civic', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.0', model='82', origin='Japan')
# DataRow(car='Honda Civic (auto)', mpg='32.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1965.', acceleration='15.7', model='82', origin='Japan')
# DataRow(car='Datsun 310 GX', mpg='38.0', cylinders='4', displacement='91.00', horsepower='67.00', weight='1995.', acceleration='16.2', model='82', origin='Japan')
# DataRow(car='Buick Century Limited', mpg='25.0', cylinders='6', displacement='181.0', horsepower='110.0', weight='2945.', acceleration='16.4', model='82', origin='US')
# DataRow(car='Oldsmobile Cutlass Ciera (diesel)', mpg='38.0', cylinders='6', displacement='262.0', horsepower='85.00', weight='3015.', acceleration='17.0', model='82', origin='US')
# DataRow(car='Chrysler Lebaron Medallion', mpg='26.0', cylinders='4', displacement='156.0', horsepower='92.00', weight='2585.', acceleration='14.5', model='82', origin='US')
# DataRow(car='Ford Grenada l', mpg='22.0', cylinders='6', displacement='232.0', horsepower='112.0', weight='2835', acceleration='14.7', model='82', origin='US')
# DataRow(car='Toyota Celica GT', mpg='32.0', cylinders='4', displacement='144.0', horsepower='96.00', weight='2665.', acceleration='13.9', model='82', origin='Japan')
# DataRow(car='Dodge Charger 2.2', mpg='36.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2370.', acceleration='13.0', model='82', origin='US')
# DataRow(car='Chevrolet Camaro', mpg='27.0', cylinders='4', displacement='151.0', horsepower='90.00', weight='2950.', acceleration='17.3', model='82', origin='US')
# DataRow(car='Ford Mustang GL', mpg='27.0', cylinders='4', displacement='140.0', horsepower='86.00', weight='2790.', acceleration='15.6', model='82', origin='US')
# DataRow(car='Volkswagen Pickup', mpg='44.0', cylinders='4', displacement='97.00', horsepower='52.00', weight='2130.', acceleration='24.6', model='82', origin='Europe')
# DataRow(car='Dodge Rampage', mpg='32.0', cylinders='4', displacement='135.0', horsepower='84.00', weight='2295.', acceleration='11.6', model='82', origin='US')
# DataRow(car='Ford Ranger', mpg='28.0', cylinders='4', displacement='120.0', horsepower='79.00', weight='2625.', acceleration='18.6', model='82', origin='US')
# DataRow(car='Chevy S-10', mpg='31.0', cylinders='4', displacement='119.0', horsepower='82.00', weight='2720.', acceleration='19.4', model='82', origin='US')

# %%
from contextlib import contextmanager

@contextmanager
def csv_file_reader(fname: str):
    dialect = get_csv_dialect(fname)
    try:
        f = open(fname)
        csv_reader = csv.reader(f, dialect)
        DataRow = get_data_row_factory(fname)
        next(csv_reader)  # ignore headers as they are handles by DataRow
        yield (DataRow(*row) for row in csv_reader)
    finally:
        f.close()

with csv_file_reader(fname) as file:
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
    print(DataRow(*next(file)))
# Out:
# DataRow(car='Chevrolet Chevelle Malibu', mpg='18.0', cylinders='8', displacement='307.0', horsepower='130.0', weight='3504.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Buick Skylark 320', mpg='15.0', cylinders='8', displacement='350.0', horsepower='165.0', weight='3693.', acceleration='11.5', model='70', origin='US')
# DataRow(car='Plymouth Satellite', mpg='18.0', cylinders='8', displacement='318.0', horsepower='150.0', weight='3436.', acceleration='11.0', model='70', origin='US')
# DataRow(car='AMC Rebel SST', mpg='16.0', cylinders='8', displacement='304.0', horsepower='150.0', weight='3433.', acceleration='12.0', model='70', origin='US')
# DataRow(car='Ford Torino', mpg='17.0', cylinders='8', displacement='302.0', horsepower='140.0', weight='3449.', acceleration='10.5', model='70', origin='US')
